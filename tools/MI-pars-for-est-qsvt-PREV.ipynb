# %%
# %matplotlib widget
import numpy as np
import cmath
import matplotlib.pyplot as plt
import os
print(os.getpid())
# %cd ../

import pylib.mix as mix
import pylib.measurement as mse
import est_qsvt as eqsvt
# Out:
# 13655
# /media/work/docs/codes/QuCF/scripts-py

# %%
for i in range(100):
    plt.close()

# %%
# ----------------------------------------------------------------------
# Compute coefficients for the estimation of the QSVT angles necessary
# for the inversion of a matrix with an arbitrary condition number.
# ----------------------------------------------------------------------

# %%
# -----------------------------------------
# --- Read data ----
# -----------------------------------------
mix.reload_module(eqsvt)

flag_save_gl_ = False

id_case_ = 8
Ncoefs_ = 20
dds_, id_comp_, fname_, path_root_, path_save_plots_ = eqsvt.read_ref_QSVT_angles(id_case_, Ncoefs_)
# Out:
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k10_eps8.hdf5
# when simulated:  03-14-2024 17:54:35
#
# function-type: 		inversion
# function-parity: 		1
# param: 			10.000000
# absolute error: 	1.040e-08
# norm. factor: 		1.250e-01
# Number of angles: 	382
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k20_eps8.hdf5
# when simulated:  03-14-2024 17:54:37
#
# function-type: 		inversion
# function-parity: 		1
# param: 			20.000000
# absolute error: 	1.067e-08
# norm. factor: 		1.250e-01
# Number of angles: 	762
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k30_eps8.hdf5
# when simulated:  03-14-2024 17:54:44
#
# function-type: 		inversion
# function-parity: 		1
# param: 			30.000000
# absolute error: 	1.059e-08
# norm. factor: 		1.250e-01
# Number of angles: 	1144
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k40_eps8.hdf5
# when simulated:  03-14-2024 17:54:59
#
# function-type: 		inversion
# function-parity: 		1
# param: 			40.000000
# absolute error: 	1.061e-08
# norm. factor: 		1.250e-01
# Number of angles: 	1524
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k50_eps8.hdf5
# when simulated:  03-14-2024 17:55:27
#
# function-type: 		inversion
# function-parity: 		1
# param: 			50.000000
# absolute error: 	1.046e-08
# norm. factor: 		1.250e-01
# Number of angles: 	1908
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k60_eps8.hdf5
# when simulated:  03-14-2024 17:56:10
#
# function-type: 		inversion
# function-parity: 		1
# param: 			60.000000
# absolute error: 	1.026e-08
# norm. factor: 		1.250e-01
# Number of angles: 	2288
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k70_eps8.hdf5
# when simulated:  03-14-2024 17:57:11
#
# function-type: 		inversion
# function-parity: 		1
# param: 			70.000000
# absolute error: 	1.057e-08
# norm. factor: 		1.250e-01
# Number of angles: 	2664
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k80_eps8.hdf5
# when simulated:  03-14-2024 17:58:35
#
# function-type: 		inversion
# function-parity: 		1
# param: 			80.000000
# absolute error: 	1.038e-08
# norm. factor: 		1.250e-01
# Number of angles: 	3050
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k90_eps8.hdf5
# when simulated:  03-14-2024 18:00:24
#
# function-type: 		inversion
# function-parity: 		1
# param: 			90.000000
# absolute error: 	1.028e-08
# norm. factor: 		1.250e-01
# Number of angles: 	3430
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k100_eps8.hdf5
# when simulated:  02-21-2024 22:39:56
#
# function-type: 		inversion
# function-parity: 		1
# param: 			100.000000
# absolute error: 	1.079e-08
# norm. factor: 		1.250e-01
# Number of angles: 	3760
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k110_eps8.hdf5
# when simulated:  03-14-2024 18:02:43
#
# function-type: 		inversion
# function-parity: 		1
# param: 			110.000000
# absolute error: 	1.067e-08
# norm. factor: 		1.250e-01
# Number of angles: 	4170
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k120_eps8.hdf5
# when simulated:  03-14-2024 18:06:07
#
# function-type: 		inversion
# function-parity: 		1
# param: 			120.000000
# absolute error: 	1.052e-08
# norm. factor: 		1.250e-01
# Number of angles: 	4570
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k130_eps8.hdf5
# when simulated:  03-14-2024 18:10:17
#
# function-type: 		inversion
# function-parity: 		1
# param: 			130.000000
# absolute error: 	1.007e-08
# norm. factor: 		1.250e-01
# Number of angles: 	4960
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k140_eps8.hdf5
# when simulated:  03-14-2024 18:15:06
#
# function-type: 		inversion
# function-parity: 		1
# param: 			140.000000
# absolute error: 	1.029e-08
# norm. factor: 		1.250e-01
# Number of angles: 	5330
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k150_eps8.hdf5
# when simulated:  02-21-2024 22:47:23
#
# function-type: 		inversion
# function-parity: 		1
# param: 			150.000000
# absolute error: 	1.056e-08
# norm. factor: 		1.250e-01
# Number of angles: 	5720
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k160_eps8.hdf5
# when simulated:  03-14-2024 18:20:40
#
# function-type: 		inversion
# function-parity: 		1
# param: 			160.000000
# absolute error: 	1.038e-08
# norm. factor: 		1.250e-01
# Number of angles: 	6100
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k170_eps8.hdf5
# when simulated:  03-14-2024 18:27:57
#
# function-type: 		inversion
# function-parity: 		1
# param: 			170.000000
# absolute error: 	1.021e-08
# norm. factor: 		1.250e-01
# Number of angles: 	6460
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k180_eps8.hdf5
# when simulated:  03-14-2024 18:36:07
#
# function-type: 		inversion
# function-parity: 		1
# param: 			180.000000
# absolute error: 	1.027e-08
# norm. factor: 		1.250e-01
# Number of angles: 	6860
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k190_eps8.hdf5
# when simulated:  03-14-2024 18:45:19
#
# function-type: 		inversion
# function-parity: 		1
# param: 			190.000000
# absolute error: 	1.025e-08
# norm. factor: 		1.250e-01
# Number of angles: 	7220
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k200_eps8.hdf5
# when simulated:  02-21-2024 22:54:25
#
# function-type: 		inversion
# function-parity: 		1
# param: 			200.000000
# absolute error: 	1.070e-08
# norm. factor: 		1.250e-01
# Number of angles: 	7520
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k210_eps8.hdf5
# when simulated:  03-14-2024 18:55:30
#
# function-type: 		inversion
# function-parity: 		1
# param: 			210.000000
# absolute error: 	1.056e-08
# norm. factor: 		1.250e-01
# Number of angles: 	7740
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k220_eps8.hdf5
# when simulated:  03-14-2024 19:07:13
#
# function-type: 		inversion
# function-parity: 		1
# param: 			220.000000
# absolute error: 	1.001e-08
# norm. factor: 		1.250e-01
# Number of angles: 	8360
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k230_eps8.hdf5
# when simulated:  03-14-2024 19:20:52
#
# function-type: 		inversion
# function-parity: 		1
# param: 			230.000000
# absolute error: 	1.021e-08
# norm. factor: 		1.250e-01
# Number of angles: 	8760
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k240_eps8.hdf5
# when simulated:  03-14-2024 19:35:55
#
# function-type: 		inversion
# function-parity: 		1
# param: 			240.000000
# absolute error: 	1.037e-08
# norm. factor: 		1.250e-01
# Number of angles: 	9120
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k250_eps8.hdf5
# when simulated:  03-14-2024 19:52:17
#
# function-type: 		inversion
# function-parity: 		1
# param: 			250.000000
# absolute error: 	1.011e-08
# norm. factor: 		1.250e-01
# Number of angles: 	9540
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k260_eps8.hdf5
# when simulated:  03-14-2024 20:10:06
#
# function-type: 		inversion
# function-parity: 		1
# param: 			260.000000
# absolute error: 	1.007e-08
# norm. factor: 		1.250e-01
# Number of angles: 	9920
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k270_eps8.hdf5
# when simulated:  03-14-2024 20:29:24
#
# function-type: 		inversion
# function-parity: 		1
# param: 			270.000000
# absolute error: 	1.039e-08
# norm. factor: 		1.250e-01
# Number of angles: 	10260
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k280_eps8.hdf5
# when simulated:  03-14-2024 20:50:00
#
# function-type: 		inversion
# function-parity: 		1
# param: 			280.000000
# absolute error: 	1.053e-08
# norm. factor: 		1.250e-01
# Number of angles: 	10640
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k290_eps8.hdf5
# when simulated:  03-14-2024 21:12:10
#
# function-type: 		inversion
# function-parity: 		1
# param: 			290.000000
# absolute error: 	1.042e-08
# norm. factor: 		1.250e-01
# Number of angles: 	10980
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k300_eps8.hdf5
# when simulated:  02-21-2024 23:06:19
#
# function-type: 		inversion
# function-parity: 		1
# param: 			300.000000
# absolute error: 	9.971e-09
# norm. factor: 		1.250e-01
# Number of angles: 	11300
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k310_eps8.hdf5
# when simulated:  03-10-2024 20:46:39
#
# function-type: 		inversion
# function-parity: 		1
# param: 			310.000000
# absolute error: 	1.045e-08
# norm. factor: 		1.250e-01
# Number of angles: 	11520
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k320_eps8.hdf5
# when simulated:  03-10-2024 21:12:37
#
# function-type: 		inversion
# function-parity: 		1
# param: 			320.000000
# absolute error: 	1.055e-08
# norm. factor: 		1.250e-01
# Number of angles: 	11690
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k330_eps8.hdf5
# when simulated:  03-10-2024 21:37:03
#
# function-type: 		inversion
# function-parity: 		1
# param: 			330.000000
# absolute error: 	1.001e-08
# norm. factor: 		1.250e-01
# Number of angles: 	12540
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k340_eps8.hdf5
# when simulated:  03-10-2024 22:07:48
#
# function-type: 		inversion
# function-parity: 		1
# param: 			340.000000
# absolute error: 	1.013e-08
# norm. factor: 		1.250e-01
# Number of angles: 	12900
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k350_eps8.hdf5
# when simulated:  03-01-2024 17:18:08
#
# function-type: 		inversion
# function-parity: 		1
# param: 			350.000000
# absolute error: 	1.013e-08
# norm. factor: 		1.250e-01
# Number of angles: 	13340
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k360_eps8.hdf5
# when simulated:  03-10-2024 22:40:13
#
# function-type: 		inversion
# function-parity: 		1
# param: 			360.000000
# absolute error: 	1.027e-08
# norm. factor: 		1.250e-01
# Number of angles: 	13720
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k370_eps8.hdf5
# when simulated:  03-10-2024 23:16:35
#
# function-type: 		inversion
# function-parity: 		1
# param: 			370.000000
# absolute error: 	1.020e-08
# norm. factor: 		1.250e-01
# Number of angles: 	14070
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k380_eps8.hdf5
# when simulated:  03-10-2024 23:55:15
#
# function-type: 		inversion
# function-parity: 		1
# param: 			380.000000
# absolute error: 	1.036e-08
# norm. factor: 		1.250e-01
# Number of angles: 	14380
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k390_eps8.hdf5
# when simulated:  03-11-2024 00:35:05
#
# function-type: 		inversion
# function-parity: 		1
# param: 			390.000000
# absolute error: 	9.990e-09
# norm. factor: 		1.250e-01
# Number of angles: 	14780
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k400_eps8.hdf5
# when simulated:  03-01-2024 17:52:59
#
# function-type: 		inversion
# function-parity: 		1
# param: 			400.000000
# absolute error: 	1.064e-08
# norm. factor: 		1.250e-01
# Number of angles: 	15040
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k410_eps8.hdf5
# when simulated:  03-11-2024 01:17:12
#
# function-type: 		inversion
# function-parity: 		1
# param: 			410.000000
# absolute error: 	1.016e-08
# norm. factor: 		1.250e-01
# Number of angles: 	15300
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k420_eps8.hdf5
# when simulated:  03-11-2024 02:02:20
#
# function-type: 		inversion
# function-parity: 		1
# param: 			420.000000
# absolute error: 	1.053e-08
# norm. factor: 		1.250e-01
# Number of angles: 	15480
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k430_eps8.hdf5
# when simulated:  03-11-2024 02:48:35
#
# function-type: 		inversion
# function-parity: 		1
# param: 			430.000000
# absolute error: 	1.054e-08
# norm. factor: 		1.250e-01
# Number of angles: 	15880
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k440_eps8.hdf5
# when simulated:  03-11-2024 03:37:19
#
# function-type: 		inversion
# function-parity: 		1
# param: 			440.000000
# absolute error: 	1.009e-08
# norm. factor: 		1.250e-01
# Number of angles: 	16660
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k450_eps8.hdf5
# when simulated:  03-01-2024 18:37:22
#
# function-type: 		inversion
# function-parity: 		1
# param: 			450.000000
# absolute error: 	1.048e-08
# norm. factor: 		1.250e-01
# Number of angles: 	17100
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k460_eps8.hdf5
# when simulated:  03-11-2024 04:30:50
#
# function-type: 		inversion
# function-parity: 		1
# param: 			460.000000
# absolute error: 	1.058e-08
# norm. factor: 		1.250e-01
# Number of angles: 	17500
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k470_eps8.hdf5
# when simulated:  03-11-2024 05:29:53
#
# function-type: 		inversion
# function-parity: 		1
# param: 			470.000000
# absolute error: 	1.040e-08
# norm. factor: 		1.250e-01
# Number of angles: 	17860
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k480_eps8.hdf5
# when simulated:  03-11-2024 06:31:29
#
# function-type: 		inversion
# function-parity: 		1
# param: 			480.000000
# absolute error: 	1.058e-08
# norm. factor: 		1.250e-01
# Number of angles: 	18160
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k490_eps8.hdf5
# when simulated:  03-11-2024 07:35:35
#
# function-type: 		inversion
# function-parity: 		1
# param: 			490.000000
# absolute error: 	9.959e-09
# norm. factor: 		1.250e-01
# Number of angles: 	18540
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k500_eps8.hdf5
# when simulated:  03-01-2024 19:35:19
#
# function-type: 		inversion
# function-parity: 		1
# param: 			500.000000
# absolute error: 	1.070e-08
# norm. factor: 		1.250e-01
# Number of angles: 	18800
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k510_eps8.hdf5
# when simulated:  03-11-2024 08:42:20
#
# function-type: 		inversion
# function-parity: 		1
# param: 			510.000000
# absolute error: 	1.017e-08
# norm. factor: 		1.250e-01
# Number of angles: 	19070
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k520_eps8.hdf5
# when simulated:  03-11-2024 09:52:59
#
# function-type: 		inversion
# function-parity: 		1
# param: 			520.000000
# absolute error: 	1.057e-08
# norm. factor: 		1.250e-01
# Number of angles: 	19260
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k530_eps8.hdf5
# when simulated:  03-11-2024 11:05:01
#
# function-type: 		inversion
# function-parity: 		1
# param: 			530.000000
# absolute error: 	1.017e-08
# norm. factor: 		1.250e-01
# Number of angles: 	19440
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k540_eps8.hdf5
# when simulated:  03-11-2024 12:18:38
#
# function-type: 		inversion
# function-parity: 		1
# param: 			540.000000
# absolute error: 	1.022e-08
# norm. factor: 		1.250e-01
# Number of angles: 	19580
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k550_eps8.hdf5
# when simulated:  03-01-2024 20:45:42
#
# function-type: 		inversion
# function-parity: 		1
# param: 			550.000000
# absolute error: 	1.099e-08
# norm. factor: 		1.250e-01
# Number of angles: 	20800
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k560_eps8.hdf5
# when simulated:  03-11-2024 13:26:34
#
# function-type: 		inversion
# function-parity: 		1
# param: 			560.000000
# absolute error: 	1.024e-08
# norm. factor: 		1.250e-01
# Number of angles: 	21300
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k570_eps8.hdf5
# when simulated:  03-11-2024 14:54:41
#
# function-type: 		inversion
# function-parity: 		1
# param: 			570.000000
# absolute error: 	1.058e-08
# norm. factor: 		1.250e-01
# Number of angles: 	21640
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k580_eps8.hdf5
# when simulated:  03-11-2024 16:25:44
#
# function-type: 		inversion
# function-parity: 		1
# param: 			580.000000
# absolute error: 	1.042e-08
# norm. factor: 		1.250e-01
# Number of angles: 	21960
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k590_eps8.hdf5
# when simulated:  03-11-2024 17:59:37
#
# function-type: 		inversion
# function-parity: 		1
# param: 			590.000000
# absolute error: 	1.018e-08
# norm. factor: 		1.250e-01
# Number of angles: 	22240
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k600_eps8.hdf5
# when simulated:  02-21-2024 20:49:26
#
# function-type: 		inversion
# function-parity: 		1
# param: 			600.000000
# absolute error: 	9.971e-09
# norm. factor: 		1.250e-01
# Number of angles: 	22600
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k610_eps8.hdf5
# when simulated:  03-11-2024 19:35:55
#
# function-type: 		inversion
# function-parity: 		1
# param: 			610.000000
# absolute error: 	1.033e-08
# norm. factor: 		1.250e-01
# Number of angles: 	22820
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k620_eps8.hdf5
# when simulated:  03-11-2024 21:17:09
#
# function-type: 		inversion
# function-parity: 		1
# param: 			620.000000
# absolute error: 	1.045e-08
# norm. factor: 		1.250e-01
# Number of angles: 	23040
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k630_eps8.hdf5
# when simulated:  03-11-2024 23:00:29
#
# function-type: 		inversion
# function-parity: 		1
# param: 			630.000000
# absolute error: 	1.029e-08
# norm. factor: 		1.250e-01
# Number of angles: 	23230
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k640_eps8.hdf5
# when simulated:  03-12-2024 00:45:18
#
# function-type: 		inversion
# function-parity: 		1
# param: 			640.000000
# absolute error: 	1.025e-08
# norm. factor: 		1.250e-01
# Number of angles: 	23390
#
# ----------------------------------------
# Reading angles from the file
# ./tools/QSVT-angles/inversion/ref-angles-5/k650_eps8.hdf5
# when simulated:  03-12-2024 02:22:09
#
# function-type: 		inversion
# function-parity: 		1
# param: 			650.000000
# absolute error: 	1.026e-08
# norm. factor: 		1.250e-01
# Number of angles: 	23520

# %%
# -----------------------------------------
# --- PLOT angles ----
# -----------------------------------------
mix.reload_module(eqsvt)

eqsvt.plot_angles(
    dds_, 
    [1, 2, 3], 
    flag_save = True & flag_save_gl_,
    path_save_plots = path_save_plots_,
    flag_shifted = True
) 

# --- Plot maximum values of the angles ----
eqsvt.plot_max(
    dds_,
    flag_save = True & flag_save_gl_,
    path_save_plots = path_save_plots_
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# maximum difference between pos. and neg. max angles: 2.480e-04
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# -------------------------------------------------------------------------
# --- COMPUTE coefficients: angles' max & min AMPLITUDES ---
mix.reload_module(eqsvt)
coefs_ampl_neg_, coefs_ampl_pos_ = eqsvt.compute_coefs_amplitudes(
    dds_,
    Ncoefs = 5,
    flag_save = False & flag_save_gl_,
    path_save_plots = path_save_plots_
)
# Out:
# --- Estimation coefs for neg amplitudes ---
# max. abs. err: 9.013e-13
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# --- Estimation coefs for pos amplitudes ---
# max. abs. err: 1.810e-12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ---------------------------------------------------------------------------------------------------
# --- COMPUTE coefficients: NUMBER of angles ---
mix.reload_module(eqsvt)
coefs_Na_neg_, coefs_Na_pos_ = eqsvt.compute_coefs_Na(
    dds_,
    Ncoefs = 2,
    flag_save = True & flag_save_gl_,
    path_save_plots = path_save_plots_
)
print(coefs_Na_neg_)
print(coefs_Na_pos_)
# Out:
# --- Estimation coefs for neg Na ---
# max. abs. err: 1.910e+02
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# --- Estimation coefs for pos Na ---
# max. abs. err: 1.910e+02
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# write data to a file: ./tools/QSVT-angles/inversion//saved-plots//Na_kappa.dat
# [33.013  9.289]
# [32.696  9.29 ]

# %%
# ----------------------------------------------------------------------------------------
# --- COMPUTE coefficients: ENVELOP (SHAPE) of angles (using a single reference case)---
# ----------------------------------------------------------------------------------------
mix.reload_module(eqsvt)
coefs_shape_neg_, coefs_shape_pos_, N_half_env_neg_, N_half_env_pos_, phis_appr_ = \
    eqsvt.compute_coefs_envelop(
        dds_[id_comp_],
        Ncoefs = Ncoefs_, 
        # Ncoefs = 160, 
        flag_plot_envelop = True, 
        flag_plot_shape   = True,
        flag_reconstruct  = True
    )
# Out:
# full number of angles: 23520
# N of NEG. peaks: 11760
# N of POS. peaks: 11760
#
# N_env-half-NEG: 5880
# N_env-half-POS: 5880
# The envelope for the kappa = 650 is taken.
# Normalized POS. ENV: max. absolute error: 1.242e-07
# Normalized NEG. ENV: max. absolute error: 1.244e-07
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# --- Reconstructing the QSVT angles for the same kappa ---
# 1. The envelope of the QSVT angles are approximated by the computed coefs.
# 2. The number of the QSVT angles and their absolute amplitudes are taken from the reference QSVT case.
#
# max-abs-err in final (non-normalized) reconstructed QSVT angles: 2.392e-11
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ------------------------------------------------------
# --- PLOT the coefficients for the envelop ---
# ------------------------------------------------------
mix.reload_module(eqsvt)
eqsvt.plot_env_coefs(
    dds_[id_comp_], 
    # Ncoefs_arrs = [40, 30, 20, 10],
    Ncoefs_arrs = [160, 80, 40, 20],
    flag_save = True & flag_save_gl_,
    path_save_plots = path_save_plots_
)
# Out:
# --------------------------------------------------------------------
# N-coefs = 160
#
# full number of angles: 23520
# N of NEG. peaks: 11760
# N of POS. peaks: 11760
#
# N_env-half-NEG: 5880
# N_env-half-POS: 5880
# The envelope for the kappa = 650 is taken.
# Normalized POS. ENV: max. absolute error: 1.704e-08
# Normalized NEG. ENV: max. absolute error: 1.707e-08
#
# --------------------------------------------------------------------
# N-coefs = 80
#
# full number of angles: 23520
# N of NEG. peaks: 11760
# N of POS. peaks: 11760
#
# N_env-half-NEG: 5880
# N_env-half-POS: 5880
# The envelope for the kappa = 650 is taken.
# Normalized POS. ENV: max. absolute error: 3.422e-08
# Normalized NEG. ENV: max. absolute error: 3.429e-08
#
# --------------------------------------------------------------------
# N-coefs = 40
#
# full number of angles: 23520
# N of NEG. peaks: 11760
# N of POS. peaks: 11760
#
# N_env-half-NEG: 5880
# N_env-half-POS: 5880
# The envelope for the kappa = 650 is taken.
# Normalized POS. ENV: max. absolute error: 6.727e-08
# Normalized NEG. ENV: max. absolute error: 6.740e-08
#
# --------------------------------------------------------------------
# N-coefs = 20
#
# full number of angles: 23520
# N of NEG. peaks: 11760
# N of POS. peaks: 11760
#
# N_env-half-NEG: 5880
# N_env-half-POS: 5880
# The envelope for the kappa = 650 is taken.
# Normalized POS. ENV: max. absolute error: 1.242e-07
# Normalized NEG. ENV: max. absolute error: 1.244e-07
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ----------------------------------------------------------------------------------------
# --- SAVE the computed coefficients ---
# ----------------------------------------------------------------------------------------
mix.reload_module(eqsvt)
eqsvt.store_estimation(
    dds_[id_comp_], fname_, path_root_,
    coefs_ampl_neg_, coefs_ampl_pos_,
    coefs_Na_neg_, coefs_Na_pos_,
    coefs_shape_neg_, coefs_shape_pos_,
    N_half_env_neg_, N_half_env_pos_
)
# Out:
# Storing the coefficients to:
#  ./tools/QSVT-angles/inversion//QSVT-MI-estimation-coefs-case6-Nc40.hdf5

# %%
# ------------------------------------------------------------------
# --- Construct 1/x function for an arbitrary kappa ---
# ------------------------------------------------------------------
mix.reload_module(eqsvt)
def reco_inv_x(
    kappa_target, 
    flag_extrapolation_env, 
    flag_adv = False,
    fname_save = None,
    opt_domain = None
):
    dd = {}
    if flag_extrapolation_env:
        coefs_env_neg, coefs_env_pos = eqsvt.extrapolate_CEs(
            kappa_target, cns_, cps_, kappas_
        )
        dd["coefs-env-neg"] = coefs_env_neg
        dd["coefs-env-pos"] = coefs_env_pos
        dd["N-env-half-neg"] = N_half_env_neg_, 
        dd["N-env-half-pos"] = N_half_env_pos_
        dd["kappa"] = dds_[id_comp_]['function-parameter']
    else:
        dd["coefs-env-neg"] = coefs_shape_neg_
        dd["coefs-env-pos"] = coefs_shape_pos_
        dd["N-env-half-neg"] = N_half_env_neg_, 
        dd["N-env-half-pos"] = N_half_env_pos_
        dd["kappa"] = dds_[id_comp_]['function-parameter']
    dd["coefs-Na-neg"] = coefs_Na_neg_
    dd["coefs-Na-pos"] = coefs_Na_pos_
    dd["coefs-ampl-neg"] = coefs_ampl_neg_
    dd["coefs-ampl-pos"] = coefs_ampl_pos_
    dd["factor-norm"] = dds_[0]["factor-norm"]

    print()
    if not flag_adv:
        print("--- Standard estimation of the QSVT angles. ---")
        phis_appr_, coef_norm_ = eqsvt.estimate_angles(dd, kappa_target)
    else:
        print("--- Advanced estimation of the QSVT angles. ---")
        phis_appr_, coef_norm_ = eqsvt.estimate_angles(
            dd, kappa_target,
            flag_variation = True,
            # ---
            N_iter_Na = 22,
            dN_env = int(kappa_target / 10.),
            # ---
            N_iter_c = 0,
            coef_dc_init = 0.2
        )

    eqsvt.construct_inverse_function_GPU(
        phis_appr_,
        kappa     = kappa_target, 
        coef_norm = coef_norm_,
        opt_domain = opt_domain,
        flag_save = False & flag_save_gl_,
        path_save_ = path_save_plots_,
        fname_save = fname_save
    )
    print("Done.")
    return
# ---------------------------------------------------------
# kappa_target, opt_domain = 100, 0
# kappa_target, opt_domain = 1000, 0
# kappa_target, opt_domain = 10000, 0

# kappa_target, opt_domain = 1e2, 2
# kappa_target, opt_domain = 1e3, 2
# kappa_target, opt_domain = 5e3, 2
kappa_target, opt_domain = 1e4, 2
# kappa_target, opt_domain = 5e4, 2
# kappa_target, opt_domain = 1e5, 2
# kappa_target, opt_domain = 5e5, 2
# kappa_target, opt_domain = 8e5, 2
# kappa_target, opt_domain = 1e6, 2
# kappa_target, opt_domain = 2e6, 2
# kappa_target, opt_domain = 5e6, 2

fname_save = "k{:d}_x{:d}".format(int(kappa_target), opt_domain)
reco_inv_x(
    kappa_target = kappa_target, 
    flag_extrapolation_env = False, 
    flag_adv = True,
    fname_save = fname_save,
    opt_domain = opt_domain
)
del fname_save
# Out:
# --- Advanced estimation of the QSVT angles. ---
#
# --- Use the variation of estimation parameters ---
# N-iter: 22
# dN-env: -1000
#
# iter, Na, N-env, err:   0, 361844, 90461, 1.317e-05
#
# ------------------------------------------
# --- Variation of Na ---
# iter, Na, N-env, err:   1, 357844, 89461, 1.539e-04 ... reduce step
# iter, Na, N-env, err:   2, 359844, 89961, 6.972e-05 ... reduce step
# iter, Na, N-env, err:   3, 360844, 90211, 2.812e-05 ... reduce step
# iter, Na, N-env, err:   4, 361344, 90336, 7.439e-06 >>> new phis
# iter, Na, N-env, err:   5, 360844, 90211, 2.812e-05 ... reduce step
# iter, Na, N-env, err:   6, 361092, 90273, 1.785e-05 ... reduce step
# iter, Na, N-env, err:   7, 361216, 90304, 1.273e-05 ... reduce step
# iter, Na, N-env, err:   8, 361280, 90320, 1.008e-05 ... reduce step
# iter, Na, N-env, err:   9, 361312, 90328, 8.760e-06 ... reduce step
# iter, Na, N-env, err:  10, 361328, 90332, 8.099e-06 ... reduce step
# iter, Na, N-env, err:  11, 361336, 90334, 7.769e-06 ... reduce step
# iter, Na, N-env, err:  12, 361340, 90335, 7.604e-06 ... change direction
# iter, Na, N-env, err:  13, 361472, 90368, 2.157e-06 >>> new phis
# iter, Na, N-env, err:  14, 361600, 90400, 3.121e-06 ... reduce step
# iter, Na, N-env, err:  15, 361536, 90384, 4.827e-07 >>> new phis
# iter, Na, N-env, err:  16, 361600, 90400, 3.121e-06 ... reduce step
# iter, Na, N-env, err:  17, 361568, 90392, 1.802e-06 ... reduce step
# iter, Na, N-env, err:  18, 361552, 90388, 1.142e-06 ... reduce step
# iter, Na, N-env, err:  19, 361544, 90386, 8.125e-07 ... reduce step
# iter, Na, N-env, err:  20, 361540, 90385, 6.476e-07
# ------------------------------------------
# --- Variation of coefficients ---
# -- err-init:      4.827e-07 --
#
# *** Results ***
# err: 4.827e-07
# N-env: 90384
# Na: 361536
# Done.
# kappa: 10000.0
# Na: 361536
# max-abs-err: 5.549e-07
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Done.

# %%
# -------------------------------------------------
# --- Scan: eps versus kappa ---
# -------------------------------------------------
def scan_kappa():

    # --- case = 6, Nc = 20 ---
    kappa_array = \
    [      
              1e2,       1e3,       5e3,       1e4,       5e4,       
              1e5,       5e5,       8e5,       
              1e6,       2e6,       5e6
    ]
    error_array = \
    [
        3.389e-05, 2.042e-06, 5.204e-06, 5.493e-06, 5.272e-06, 
        4.630e-06, 8.765e-07, 4.917e-06,
        7.617e-06, 2.109e-05, 6.140e-05,
    ]

    log_kappa = np.log10(kappa_array)
    log_err = np.log10(error_array)

    mix.save_dat_plot_1d_file(
        path_save_plots_ + "/direct_scan_err_Nc20.dat", 
        log_kappa, log_err
    )
    return
# --------------------------
scan_kappa()
del scan_kappa
# Out:
# write data to a file: ./tools/QSVT-angles/inversion//saved-plots//direct_scan_err_Nc20.dat

# %%
# -------------------------------------------------------
# --- Compute 1/x using a sequence of rotations ---
# -------------------------------------------------------
mix.reload_module(eqsvt)

phi_comp = np.array(phis_appr_)
# phi_comp = np.array(dds_[id_comp_]["phis"])

# padding_array = np.array([np.pi/2.] * 10001)
# phi_comp = np.concatenate(
#     (padding_array, phi_comp, padding_array)
# )

eqsvt.construct_inverse_function(
    phi_comp,
    kappa = dds_[id_comp_]["function-parameter"], 
    coef_norm = dds_[id_comp_]["factor-norm"]
)
# Out:
# N-angles: 22600
# kappa: 600.0
# coef-norm: 1.250e-01
#
# max. angle - np.pi/2: 2.082e-04
# min. angle - np.pi/2: -2.083e-04
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# max-abs-err: 1.346e-08
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ---------------------------------------------------------------------------------------------
# --- Compute coefficients-envelop (CEs) for various reference kappa ---
# ---------------------------------------------------------------------------------------------
mix.reload_module(eqsvt)
cns_, cps_, kappas_ = eqsvt.compute_coefs_var_kappa(
    dds_, 
    Ncoefs = Ncoefs_
)
# Out:
# full number of angles: 382
# N of NEG. peaks: 192
# N of POS. peaks: 190
#
# N_env-half-NEG: 96
# N_env-half-POS: 95
# The envelope for the kappa = 10 is taken.
# Normalized POS. ENV: max. absolute error: 3.225e-08
# Normalized NEG. ENV: max. absolute error: 2.743e-08
#
# full number of angles: 762
# N of NEG. peaks: 382
# N of POS. peaks: 380
#
# N_env-half-NEG: 191
# N_env-half-POS: 190
# The envelope for the kappa = 20 is taken.
# Normalized POS. ENV: max. absolute error: 3.264e-08
# Normalized NEG. ENV: max. absolute error: 3.009e-08
#
# full number of angles: 1144
# N of NEG. peaks: 572
# N of POS. peaks: 572
#
# N_env-half-NEG: 286
# N_env-half-POS: 286
# The envelope for the kappa = 30 is taken.
# Normalized POS. ENV: max. absolute error: 2.970e-08
# Normalized NEG. ENV: max. absolute error: 3.103e-08
#
# full number of angles: 1524
# N of NEG. peaks: 762
# N of POS. peaks: 762
#
# N_env-half-NEG: 381
# N_env-half-POS: 381
# The envelope for the kappa = 40 is taken.
# Normalized POS. ENV: max. absolute error: 3.052e-08
# Normalized NEG. ENV: max. absolute error: 3.154e-08
#
# full number of angles: 1908
# N of NEG. peaks: 954
# N of POS. peaks: 954
#
# N_env-half-NEG: 477
# N_env-half-POS: 477
# The envelope for the kappa = 50 is taken.
# Normalized POS. ENV: max. absolute error: 2.921e-08
# Normalized NEG. ENV: max. absolute error: 3.000e-08
#
# full number of angles: 2288
# N of NEG. peaks: 1144
# N of POS. peaks: 1144
#
# N_env-half-NEG: 572
# N_env-half-POS: 572
# The envelope for the kappa = 60 is taken.
# Normalized POS. ENV: max. absolute error: 2.983e-08
# Normalized NEG. ENV: max. absolute error: 3.049e-08
#
# full number of angles: 2664
# N of NEG. peaks: 1332
# N of POS. peaks: 1332
#
# N_env-half-NEG: 666
# N_env-half-POS: 666
# The envelope for the kappa = 70 is taken.
# Normalized POS. ENV: max. absolute error: 3.160e-08
# Normalized NEG. ENV: max. absolute error: 3.220e-08
#
# full number of angles: 3050
# N of NEG. peaks: 1526
# N of POS. peaks: 1524
#
# N_env-half-NEG: 763
# N_env-half-POS: 762
# The envelope for the kappa = 80 is taken.
# Normalized POS. ENV: max. absolute error: 3.061e-08
# Normalized NEG. ENV: max. absolute error: 2.999e-08
#
# full number of angles: 3430
# N of NEG. peaks: 1716
# N of POS. peaks: 1714
#
# N_env-half-NEG: 858
# N_env-half-POS: 857
# The envelope for the kappa = 90 is taken.
# Normalized POS. ENV: max. absolute error: 3.088e-08
# Normalized NEG. ENV: max. absolute error: 3.033e-08
#
# full number of angles: 3760
# N of NEG. peaks: 1880
# N of POS. peaks: 1880
#
# N_env-half-NEG: 940
# N_env-half-POS: 940
# The envelope for the kappa = 100 is taken.
# Normalized POS. ENV: max. absolute error: 4.444e-08
# Normalized NEG. ENV: max. absolute error: 4.503e-08
#
# full number of angles: 4170
# N of NEG. peaks: 2086
# N of POS. peaks: 2084
#
# N_env-half-NEG: 1043
# N_env-half-POS: 1042
# The envelope for the kappa = 110 is taken.
# Normalized POS. ENV: max. absolute error: 3.582e-08
# Normalized NEG. ENV: max. absolute error: 3.530e-08
#
# full number of angles: 4570
# N of NEG. peaks: 2286
# N of POS. peaks: 2284
#
# N_env-half-NEG: 1143
# N_env-half-POS: 1142
# The envelope for the kappa = 120 is taken.
# Normalized POS. ENV: max. absolute error: 3.143e-08
# Normalized NEG. ENV: max. absolute error: 3.100e-08
#
# full number of angles: 4960
# N of NEG. peaks: 2480
# N of POS. peaks: 2480
#
# N_env-half-NEG: 1240
# N_env-half-POS: 1240
# The envelope for the kappa = 130 is taken.
# Normalized POS. ENV: max. absolute error: 2.945e-08
# Normalized NEG. ENV: max. absolute error: 2.975e-08
#
# full number of angles: 5330
# N of NEG. peaks: 2666
# N of POS. peaks: 2664
#
# N_env-half-NEG: 1333
# N_env-half-POS: 1332
# The envelope for the kappa = 140 is taken.
# Normalized POS. ENV: max. absolute error: 3.166e-08
# Normalized NEG. ENV: max. absolute error: 3.130e-08
#
# full number of angles: 5720
# N of NEG. peaks: 2860
# N of POS. peaks: 2860
#
# N_env-half-NEG: 1430
# N_env-half-POS: 1430
# The envelope for the kappa = 150 is taken.
# Normalized POS. ENV: max. absolute error: 2.992e-08
# Normalized NEG. ENV: max. absolute error: 3.018e-08
#
# full number of angles: 6100
# N of NEG. peaks: 3050
# N of POS. peaks: 3050
#
# N_env-half-NEG: 1525
# N_env-half-POS: 1525
# The envelope for the kappa = 160 is taken.
# Normalized POS. ENV: max. absolute error: 3.011e-08
# Normalized NEG. ENV: max. absolute error: 3.036e-08
#
# full number of angles: 6460
# N of NEG. peaks: 3230
# N of POS. peaks: 3230
#
# N_env-half-NEG: 1615
# N_env-half-POS: 1615
# The envelope for the kappa = 170 is taken.
# Normalized POS. ENV: max. absolute error: 3.306e-08
# Normalized NEG. ENV: max. absolute error: 3.332e-08
#
# full number of angles: 6860
# N of NEG. peaks: 3430
# N of POS. peaks: 3430
#
# N_env-half-NEG: 1715
# N_env-half-POS: 1715
# The envelope for the kappa = 180 is taken.
# Normalized POS. ENV: max. absolute error: 3.043e-08
# Normalized NEG. ENV: max. absolute error: 3.065e-08
#
# full number of angles: 7220
# N of NEG. peaks: 3610
# N of POS. peaks: 3610
#
# N_env-half-NEG: 1805
# N_env-half-POS: 1805
# The envelope for the kappa = 190 is taken.
# Normalized POS. ENV: max. absolute error: 3.307e-08
# Normalized NEG. ENV: max. absolute error: 3.330e-08
#
# full number of angles: 7520
# N of NEG. peaks: 3760
# N of POS. peaks: 3760
#
# N_env-half-NEG: 1880
# N_env-half-POS: 1880
# The envelope for the kappa = 200 is taken.
# Normalized POS. ENV: max. absolute error: 4.452e-08
# Normalized NEG. ENV: max. absolute error: 4.481e-08
#
# full number of angles: 7740
# N of NEG. peaks: 3870
# N of POS. peaks: 3870
#
# N_env-half-NEG: 1935
# N_env-half-POS: 1935
# The envelope for the kappa = 210 is taken.
# Normalized POS. ENV: max. absolute error: 7.662e-08
# Normalized NEG. ENV: max. absolute error: 7.708e-08
#
# full number of angles: 8360
# N of NEG. peaks: 4180
# N of POS. peaks: 4180
#
# N_env-half-NEG: 2090
# N_env-half-POS: 2090
# The envelope for the kappa = 220 is taken.
# Normalized POS. ENV: max. absolute error: 3.308e-08
# Normalized NEG. ENV: max. absolute error: 3.328e-08
#
# full number of angles: 8760
# N of NEG. peaks: 4380
# N of POS. peaks: 4380
#
# N_env-half-NEG: 2190
# N_env-half-POS: 2190
# The envelope for the kappa = 230 is taken.
# Normalized POS. ENV: max. absolute error: 3.099e-08
# Normalized NEG. ENV: max. absolute error: 3.117e-08
#
# full number of angles: 9120
# N of NEG. peaks: 4560
# N of POS. peaks: 4560
#
# N_env-half-NEG: 2280
# N_env-half-POS: 2280
# The envelope for the kappa = 240 is taken.
# Normalized POS. ENV: max. absolute error: 3.308e-08
# Normalized NEG. ENV: max. absolute error: 3.326e-08
#
# full number of angles: 9540
# N of NEG. peaks: 4770
# N of POS. peaks: 4770
#
# N_env-half-NEG: 2385
# N_env-half-POS: 2385
# The envelope for the kappa = 250 is taken.
# Normalized POS. ENV: max. absolute error: 2.935e-08
# Normalized NEG. ENV: max. absolute error: 2.950e-08
#
# full number of angles: 9920
# N of NEG. peaks: 4960
# N of POS. peaks: 4960
#
# N_env-half-NEG: 2480
# N_env-half-POS: 2480
# The envelope for the kappa = 260 is taken.
# Normalized POS. ENV: max. absolute error: 2.948e-08
# Normalized NEG. ENV: max. absolute error: 2.963e-08
#
# full number of angles: 10260
# N of NEG. peaks: 5130
# N of POS. peaks: 5130
#
# N_env-half-NEG: 2565
# N_env-half-POS: 2565
# The envelope for the kappa = 270 is taken.
# Normalized POS. ENV: max. absolute error: 3.308e-08
# Normalized NEG. ENV: max. absolute error: 3.325e-08
#
# full number of angles: 10640
# N of NEG. peaks: 5320
# N of POS. peaks: 5320
#
# N_env-half-NEG: 2660
# N_env-half-POS: 2660
# The envelope for the kappa = 280 is taken.
# Normalized POS. ENV: max. absolute error: 3.309e-08
# Normalized NEG. ENV: max. absolute error: 3.324e-08
#
# full number of angles: 10980
# N of NEG. peaks: 5490
# N of POS. peaks: 5490
#
# N_env-half-NEG: 2745
# N_env-half-POS: 2745
# The envelope for the kappa = 290 is taken.
# Normalized POS. ENV: max. absolute error: 3.667e-08
# Normalized NEG. ENV: max. absolute error: 3.684e-08
#
# full number of angles: 11300
# N of NEG. peaks: 5650
# N of POS. peaks: 5650
#
# N_env-half-NEG: 2825
# N_env-half-POS: 2825
# The envelope for the kappa = 300 is taken.
# Normalized POS. ENV: max. absolute error: 4.240e-08
# Normalized NEG. ENV: max. absolute error: 4.258e-08
#
# full number of angles: 11520
# N of NEG. peaks: 5760
# N of POS. peaks: 5760
#
# N_env-half-NEG: 2880
# N_env-half-POS: 2880
# The envelope for the kappa = 310 is taken.
# Normalized POS. ENV: max. absolute error: 6.147e-08
# Normalized NEG. ENV: max. absolute error: 6.172e-08
#
# full number of angles: 11690
# N of NEG. peaks: 5846
# N of POS. peaks: 5844
#
# N_env-half-NEG: 2923
# N_env-half-POS: 2922
# The envelope for the kappa = 320 is taken.
# Normalized POS. ENV: max. absolute error: 9.735e-08
# Normalized NEG. ENV: max. absolute error: 9.688e-08
#
# full number of angles: 12540
# N of NEG. peaks: 6270
# N of POS. peaks: 6270
#
# N_env-half-NEG: 3135
# N_env-half-POS: 3135
# The envelope for the kappa = 330 is taken.
# Normalized POS. ENV: max. absolute error: 3.309e-08
# Normalized NEG. ENV: max. absolute error: 3.322e-08
#
# full number of angles: 12900
# N of NEG. peaks: 6450
# N of POS. peaks: 6450
#
# N_env-half-NEG: 3225
# N_env-half-POS: 3225
# The envelope for the kappa = 340 is taken.
# Normalized POS. ENV: max. absolute error: 3.458e-08
# Normalized NEG. ENV: max. absolute error: 3.471e-08
#
# full number of angles: 13340
# N of NEG. peaks: 6670
# N of POS. peaks: 6670
#
# N_env-half-NEG: 3335
# N_env-half-POS: 3335
# The envelope for the kappa = 350 is taken.
# Normalized POS. ENV: max. absolute error: 3.038e-08
# Normalized NEG. ENV: max. absolute error: 3.050e-08
#
# full number of angles: 13720
# N of NEG. peaks: 6860
# N of POS. peaks: 6860
#
# N_env-half-NEG: 3430
# N_env-half-POS: 3430
# The envelope for the kappa = 360 is taken.
# Normalized POS. ENV: max. absolute error: 3.045e-08
# Normalized NEG. ENV: max. absolute error: 3.057e-08
#
# full number of angles: 14070
# N of NEG. peaks: 7036
# N of POS. peaks: 7034
#
# N_env-half-NEG: 3518
# N_env-half-POS: 3517
# The envelope for the kappa = 370 is taken.
# Normalized POS. ENV: max. absolute error: 3.256e-08
# Normalized NEG. ENV: max. absolute error: 3.242e-08
#
# full number of angles: 14380
# N of NEG. peaks: 7190
# N of POS. peaks: 7190
#
# N_env-half-NEG: 3595
# N_env-half-POS: 3595
# The envelope for the kappa = 380 is taken.
# Normalized POS. ENV: max. absolute error: 3.723e-08
# Normalized NEG. ENV: max. absolute error: 3.736e-08
#
# full number of angles: 14780
# N of NEG. peaks: 7390
# N of POS. peaks: 7390
#
# N_env-half-NEG: 3695
# N_env-half-POS: 3695
# The envelope for the kappa = 390 is taken.
# Normalized POS. ENV: max. absolute error: 3.573e-08
# Normalized NEG. ENV: max. absolute error: 3.585e-08
#
# full number of angles: 15040
# N of NEG. peaks: 7520
# N of POS. peaks: 7520
#
# N_env-half-NEG: 3760
# N_env-half-POS: 3760
# The envelope for the kappa = 400 is taken.
# Normalized POS. ENV: max. absolute error: 4.455e-08
# Normalized NEG. ENV: max. absolute error: 4.470e-08
#
# full number of angles: 15300
# N of NEG. peaks: 7650
# N of POS. peaks: 7650
#
# N_env-half-NEG: 3825
# N_env-half-POS: 3825
# The envelope for the kappa = 410 is taken.
# Normalized POS. ENV: max. absolute error: 5.487e-08
# Normalized NEG. ENV: max. absolute error: 5.504e-08
#
# full number of angles: 15480
# N of NEG. peaks: 7740
# N of POS. peaks: 7740
#
# N_env-half-NEG: 3870
# N_env-half-POS: 3870
# The envelope for the kappa = 420 is taken.
# Normalized POS. ENV: max. absolute error: 7.669e-08
# Normalized NEG. ENV: max. absolute error: 7.692e-08
#
# full number of angles: 15880
# N of NEG. peaks: 7940
# N of POS. peaks: 7940
#
# N_env-half-NEG: 3970
# N_env-half-POS: 3970
# The envelope for the kappa = 430 is taken.
# Normalized POS. ENV: max. absolute error: 7.274e-08
# Normalized NEG. ENV: max. absolute error: 7.295e-08
#
# full number of angles: 16660
# N of NEG. peaks: 8330
# N of POS. peaks: 8330
#
# N_env-half-NEG: 4165
# N_env-half-POS: 4165
# The envelope for the kappa = 440 is taken.
# Normalized POS. ENV: max. absolute error: 3.664e-08
# Normalized NEG. ENV: max. absolute error: 3.675e-08
#
# full number of angles: 17100
# N of NEG. peaks: 8550
# N of POS. peaks: 8550
#
# N_env-half-NEG: 4275
# N_env-half-POS: 4275
# The envelope for the kappa = 450 is taken.
# Normalized POS. ENV: max. absolute error: 3.310e-08
# Normalized NEG. ENV: max. absolute error: 3.320e-08
#
# full number of angles: 17500
# N of NEG. peaks: 8750
# N of POS. peaks: 8750
#
# N_env-half-NEG: 4375
# N_env-half-POS: 4375
# The envelope for the kappa = 460 is taken.
# Normalized POS. ENV: max. absolute error: 3.204e-08
# Normalized NEG. ENV: max. absolute error: 3.213e-08
#
# full number of angles: 17860
# N of NEG. peaks: 8930
# N of POS. peaks: 8930
#
# N_env-half-NEG: 4465
# N_env-half-POS: 4465
# The envelope for the kappa = 470 is taken.
# Normalized POS. ENV: max. absolute error: 3.310e-08
# Normalized NEG. ENV: max. absolute error: 3.319e-08
#
# full number of angles: 18160
# N of NEG. peaks: 9080
# N of POS. peaks: 9080
#
# N_env-half-NEG: 4540
# N_env-half-POS: 4540
# The envelope for the kappa = 480 is taken.
# Normalized POS. ENV: max. absolute error: 3.748e-08
# Normalized NEG. ENV: max. absolute error: 3.758e-08
#
# full number of angles: 18540
# N of NEG. peaks: 9270
# N of POS. peaks: 9270
#
# N_env-half-NEG: 4635
# N_env-half-POS: 4635
# The envelope for the kappa = 490 is taken.
# Normalized POS. ENV: max. absolute error: 3.739e-08
# Normalized NEG. ENV: max. absolute error: 3.749e-08
#
# full number of angles: 18800
# N of NEG. peaks: 9400
# N of POS. peaks: 9400
#
# N_env-half-NEG: 4700
# N_env-half-POS: 4700
# The envelope for the kappa = 500 is taken.
# Normalized POS. ENV: max. absolute error: 4.456e-08
# Normalized NEG. ENV: max. absolute error: 4.468e-08
#
# full number of angles: 19070
# N of NEG. peaks: 9536
# N of POS. peaks: 9534
#
# N_env-half-NEG: 4768
# N_env-half-POS: 4767
# The envelope for the kappa = 510 is taken.
# Normalized POS. ENV: max. absolute error: 5.208e-08
# Normalized NEG. ENV: max. absolute error: 5.192e-08
#
# full number of angles: 19260
# N of NEG. peaks: 9630
# N of POS. peaks: 9630
#
# N_env-half-NEG: 4815
# N_env-half-POS: 4815
# The envelope for the kappa = 520 is taken.
# Normalized POS. ENV: max. absolute error: 6.725e-08
# Normalized NEG. ENV: max. absolute error: 6.742e-08
#
# full number of angles: 19440
# N of NEG. peaks: 9720
# N of POS. peaks: 9720
#
# N_env-half-NEG: 4860
# N_env-half-POS: 4860
# The envelope for the kappa = 530 is taken.
# Normalized POS. ENV: max. absolute error: 8.720e-08
# Normalized NEG. ENV: max. absolute error: 8.741e-08
#
# full number of angles: 19580
# N of NEG. peaks: 9790
# N of POS. peaks: 9790
#
# N_env-half-NEG: 4895
# N_env-half-POS: 4895
# The envelope for the kappa = 540 is taken.
# Normalized POS. ENV: max. absolute error: 1.177e-07
# Normalized NEG. ENV: max. absolute error: 1.180e-07
#
# full number of angles: 20800
# N of NEG. peaks: 10400
# N of POS. peaks: 10400
#
# N_env-half-NEG: 5200
# N_env-half-POS: 5200
# The envelope for the kappa = 550 is taken.
# Normalized POS. ENV: max. absolute error: 3.791e-08
# Normalized NEG. ENV: max. absolute error: 3.800e-08
#
# full number of angles: 21300
# N of NEG. peaks: 10650
# N of POS. peaks: 10650
#
# N_env-half-NEG: 5325
# N_env-half-POS: 5325
# The envelope for the kappa = 560 is taken.
# Normalized POS. ENV: max. absolute error: 3.223e-08
# Normalized NEG. ENV: max. absolute error: 3.231e-08
#
# full number of angles: 21640
# N of NEG. peaks: 10820
# N of POS. peaks: 10820
#
# N_env-half-NEG: 5410
# N_env-half-POS: 5410
# The envelope for the kappa = 570 is taken.
# Normalized POS. ENV: max. absolute error: 3.398e-08
# Normalized NEG. ENV: max. absolute error: 3.406e-08
#
# full number of angles: 21960
# N of NEG. peaks: 10980
# N of POS. peaks: 10980
#
# N_env-half-NEG: 5490
# N_env-half-POS: 5490
# The envelope for the kappa = 580 is taken.
# Normalized POS. ENV: max. absolute error: 3.669e-08
# Normalized NEG. ENV: max. absolute error: 3.678e-08
#
# full number of angles: 22240
# N of NEG. peaks: 11120
# N of POS. peaks: 11120
#
# N_env-half-NEG: 5560
# N_env-half-POS: 5560
# The envelope for the kappa = 590 is taken.
# Normalized POS. ENV: max. absolute error: 4.154e-08
# Normalized NEG. ENV: max. absolute error: 4.164e-08
#
# full number of angles: 22600
# N of NEG. peaks: 11300
# N of POS. peaks: 11300
#
# N_env-half-NEG: 5650
# N_env-half-POS: 5650
# The envelope for the kappa = 600 is taken.
# Normalized POS. ENV: max. absolute error: 4.242e-08
# Normalized NEG. ENV: max. absolute error: 4.251e-08
#
# full number of angles: 22820
# N of NEG. peaks: 11410
# N of POS. peaks: 11410
#
# N_env-half-NEG: 5705
# N_env-half-POS: 5705
# The envelope for the kappa = 610 is taken.
# Normalized POS. ENV: max. absolute error: 5.127e-08
# Normalized NEG. ENV: max. absolute error: 5.138e-08
#
# full number of angles: 23040
# N of NEG. peaks: 11520
# N of POS. peaks: 11520
#
# N_env-half-NEG: 5760
# N_env-half-POS: 5760
# The envelope for the kappa = 620 is taken.
# Normalized POS. ENV: max. absolute error: 6.150e-08
# Normalized NEG. ENV: max. absolute error: 6.163e-08
#
# full number of angles: 23230
# N of NEG. peaks: 11616
# N of POS. peaks: 11614
#
# N_env-half-NEG: 5808
# N_env-half-POS: 5807
# The envelope for the kappa = 630 is taken.
# Normalized POS. ENV: max. absolute error: 7.600e-08
# Normalized NEG. ENV: max. absolute error: 7.581e-08
#
# full number of angles: 23390
# N of NEG. peaks: 11696
# N of POS. peaks: 11694
#
# N_env-half-NEG: 5848
# N_env-half-POS: 5847
# The envelope for the kappa = 640 is taken.
# Normalized POS. ENV: max. absolute error: 9.612e-08
# Normalized NEG. ENV: max. absolute error: 9.588e-08
#
# full number of angles: 23520
# N of NEG. peaks: 11760
# N of POS. peaks: 11760
#
# N_env-half-NEG: 5880
# N_env-half-POS: 5880
# The envelope for the kappa = 650 is taken.
# Normalized POS. ENV: max. absolute error: 1.242e-07
# Normalized NEG. ENV: max. absolute error: 1.244e-07

# %%
# ---------------------------------------------------------------------------------------------
# --- PLOT CEs for various reference kappa ---
# ---------------------------------------------------------------------------------------------
mix.reload_module(eqsvt)
eqsvt.plot_coefs_var_kappa(
    cns_, cps_, kappas_,
    ids_ch_coef = [0,1,2,3,4,5], # which coefficients to plot;
    path_save_plots = path_save_plots_,
    flag_save = False,
    flag_shifted = False
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ---------------------------------------------------------------------------------
# --- Reconstruct CEs for a particular kappa (just interpolation) ---
# ---------------------------------------------------------------------------------
mix.reload_module(eqsvt)
eqsvt.reconstruct_CEs_kappa(1, dds_, cns_, cps_, kappas_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 # ---------------------------------------------------------------------------------
#       2 # --- Reconstruct CEs for a particular kappa (just interpolation) ---
#       3 # ---------------------------------------------------------------------------------
#       4 mix.reload_module(eqsvt)
# ----> 5 eqsvt.reconstruct_CEs_kappa(1, dds_, cns_, cps_, kappas_)
#
# NameError: name 'cns_' is not defined

# %%
# ---------------------------------------------------------------------------------
# --- Approximate the dependence of each CE on kappa by a Chebyschev series ---
# ---------------------------------------------------------------------------------
mix.reload_module(eqsvt)

Ncoefs_coefs_ = 2

ccns_, ccps_ = eqsvt.compute_env_coefs_dependence_kappa(
    Ncoefs_coefs_, cns_, cps_, kappas_,
    flag_reco = True
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ---------------------------------------------------------------------------------------------
# --- Compare the reference QSVT angles and the reconstructed angles ---
# ---------------------------------------------------------------------------------------------
# Here the QSVT angles are reconstructed without using any parameters from the reference case.
mix.reload_module(eqsvt)

def compare_reconstructed_and_known_angles(dds, ids_ch, flag_save, path_save_plots):
    def compare_angles(phis_ref, phis_rec):
        phis_ch = np.array(phis_ref)

        print("N-ref: {:d}".format(len(phis_ref)))
        print("N-rec: {:d}".format(len(phis_rec)))

        print()
        print("diff in max, min: {:0.3e}, {:0.3e}".format(
            np.max(phis_rec) - np.max(phis_ref),
            np.min(phis_rec) - np.min(phis_ref),
        ))

        max_abs_err = np.max(np.abs(phis_ch - phis_rec))
        print("max. abs. err: {:0.3e}".format(max_abs_err))
        return
    # -------------------------------------------------------------------------

    for id_ch in ids_ch:
        kappa_ch = dds[id_ch]["function-parameter"]
        phis_ref = np.array(dds[id_ch]["phis"])
        Na = len(dds[id_ch]["phis"])

        temp = eqsvt.extract_env(
            np.array(phis_ref- np.pi/2.),
            np.mod(Na//2,2)
        )

        N_neg = len(temp["neg-i"])
        N_pos = len(temp["pos-i"])

        print("------------------")
        print("Chosen kappa: {:0.1f}".format(kappa_ch))
        print("Na: {:d}".format(Na))
        print("ref: N-neg: {:d}".format(N_neg))
        print("ref: N-pos: {:d}".format(N_pos))
        print("------------------")

        Nh_neg = N_neg//2
        if(np.mod(N_neg, 2) == 1):
            Nh_neg += 1
            

        phis_appr_fully, _ = eqsvt.estimate_angles(
            eqsvt.read_estimation(id_case_, Ncoefs_), 
            kappa_goal = kappa_ch,
            # # --- comment to compute the actual number of the QSVT estimated angles ---
            Nh_neg_ref = Nh_neg,
            Nh_pos_ref = N_pos//2
        )

        # --- Compare angles ---
        compare_angles(phis_ref, phis_appr_fully)

        # --- Compute the difference ---
        array_ids =  np.array(range(Na)) - Na//2
        log_diff = np.zeros(Na)
        for ii in range(Na):
            temp = np.abs(phis_appr_fully[ii] - phis_ref[ii])
            if temp <= 1e-16:
                temp = 1e-16
            log_diff[ii] = np.log10(temp)

        # --- Plot the difference ---
        fig = plt.figure(figsize=(eqsvt.FIG_SIZE_W_,eqsvt.FIG_SIZE_H_))
        ax = fig.add_subplot(111)
        ax.plot(
            array_ids, 
            log_diff, 
            color="b", linewidth = 2, linestyle='-', 
            label = "kappa = {:d}".format(int(kappa_ch))
        )
        plt.xlabel('i')
        plt.ylabel("log10|phis_ref - phis_recon|")
        plt.legend()
        plt.grid(True)
        plt.show()

        # --- Saving data ---
        if flag_save_gl_:
            mix.save_dat_plot_1d_file(
                path_save_plots + "/env_err_k{:d}.dat".format(int(kappa_ch)), 
                array_ids, 
                log_diff
            )
# --------------------------------------------------------------

compare_reconstructed_and_known_angles(
    dds_,
    ids_ch = [2, 3, 4],
    flag_save = True & flag_save_gl_, 
    path_save_plots = path_save_plots_
)
# Out:
# ------------------
# Chosen kappa: 60.0
# Na: 4156
# ref: N-neg: 2078
# ref: N-pos: 2078
# ------------------
# Reading the coefficients from:
#  ./tools/QSVT-angles/inversion//QSVT-MI-estimation-coefs-case3-Nc40.hdf5
# When simulated:  02/08/2024: 14:50:39
# Data for-inversion
# kappa: 80.000
# factor-norm: 0.125
# N-env-half-neg: 1483
# N-env-half-pos: 1482
# N-coefs-envelop-neg: 40
# N-coefs-envelop-pos: 40
# Na_rec-rec: 4156
# Done.
# N-ref: 4156
# N-rec: 4156
#
# diff in max, min: -9.260e-12, 4.707e-14
# max. abs. err: 7.097e-05
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# write data to a file: ./tools/QSVT-angles/inversion//saved-plots//env_err_k60.dat
# ------------------
# Chosen kappa: 80.0
# Na: 5930
# ref: N-neg: 2966
# ref: N-pos: 2964
# ------------------
# Reading the coefficients from:
#  ./tools/QSVT-angles/inversion//QSVT-MI-estimation-coefs-case3-Nc40.hdf5
# When simulated:  02/08/2024: 14:50:39
# Data for-inversion
# kappa: 80.000
# factor-norm: 0.125
# N-env-half-neg: 1483
# N-env-half-pos: 1482
# N-coefs-envelop-neg: 40
# N-coefs-envelop-pos: 40
# Na_rec-rec: 5930
# Done.
# N-ref: 5930
# N-rec: 5930
#
# diff in max, min: 7.811e-12, 1.710e-14
# max. abs. err: 7.811e-12
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# write data to a file: ./tools/QSVT-angles/inversion//saved-plots//env_err_k80.dat
# ------------------
# Chosen kappa: 100.0
# Na: 7794
# ref: N-neg: 3898
# ref: N-pos: 3896
# ------------------
# Reading the coefficients from:
#  ./tools/QSVT-angles/inversion//QSVT-MI-estimation-coefs-case3-Nc40.hdf5
# When simulated:  02/08/2024: 14:50:39
# Data for-inversion
# kappa: 80.000
# factor-norm: 0.125
# N-env-half-neg: 1483
# N-env-half-pos: 1482
# N-coefs-envelop-neg: 40
# N-coefs-envelop-pos: 40
# Na_rec-rec: 7794
# Done.
# N-ref: 7794
# N-rec: 7794
#
# diff in max, min: 6.044e-12, -9.326e-15
# max. abs. err: 3.134e-05
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# write data to a file: ./tools/QSVT-angles/inversion//saved-plots//env_err_k100.dat
