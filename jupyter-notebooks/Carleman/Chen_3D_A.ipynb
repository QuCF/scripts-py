# %%
# %matplotlib widget
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
import h5py

import os
import sys
sys.path.append(os.path.abspath("./"))

print(os.getpid())
# %cd ../../

import pylib.mix as mix
import carleman as ca
from matplotlib import colors
plt.rcParams.update({
    "text.usetex": True,
    'text.latex.preamble': r"\usepackage{amsmath} \boldmath"
})
# Out:
# 33220
# c:\Users\ivan9\Documents\work\codes\QuCF\scripts-py

# %%
path_save_ = "./jupyter-notebooks/Carleman/results/"
for i in range(100):
    plt.close()

colors_     = ["blue", "red", "green", "gray", "black"]
linestyles_ = ["-", "--", "--", ":"]

# %%
# ---------------------------------------------------------------
# --- Prepare the system: Chen attractor ---
# ---------------------------------------------------------------
mix.reload_module(ca)
mix.reload_module(mix)
def choose_case(N_nl, sel_case):
    Nx = 3  # the number of degrees of freedom
    F_terms, sys_coefs, return_sys, shift_coefs = None, None, None, None
    if sel_case == 0:
        tmax, nt = 10, 11

        ss, rr, bb = 40., 28., 6.
        xi_x, xi_y, xi_z = 0., 0., 0.
        x_init = np.array([0.1, 0.0, 0.0])

        sys_coefs = {}
        sys_coefs["ss"]   = ss
        sys_coefs["rr"]   = rr
        sys_coefs["bb"]   = bb
        sys_coefs["xi_x"] = xi_x
        sys_coefs["xi_y"] = xi_y
        sys_coefs["xi_z"] = xi_z

        # -------------------------------------------------------------
        def return_sys(ss_coefs):
            ss   = ss_coefs["ss"]    
            rr   = ss_coefs["rr"]    
            bb   = ss_coefs["bb"]    
            xi_x = ss_coefs["xi_x"]  
            xi_y = ss_coefs["xi_y"]  
            xi_z = ss_coefs["xi_z"]  

            F_terms = [None] * (N_nl + 1)
            for ii_nl in range(N_nl + 1):
                F_terms[ii_nl] = np.zeros((Nx,int(Nx**ii_nl)))

            # *** matrix F0 ***
            F_terms[0][0,0] = ss * (xi_y - xi_x)
            F_terms[0][1,0] = (rr - ss) * xi_x + rr * xi_y - (2.*rr - ss) * xi_x * xi_z
            F_terms[0][2,0] = -bb * xi_z + bb * xi_x * xi_y

            # *** matrix F1 ***
            F_terms[1][0,0], F_terms[1][0,1] = -ss, ss
            F_terms[1][1,0], F_terms[1][1,1], F_terms[1][1,2] = (rr - ss) - (2.*rr - ss) * xi_z, rr, - (2.*rr - ss) * xi_x
            F_terms[1][2,0], F_terms[1][2,1], F_terms[1][2,2] = bb * xi_y, bb * xi_x, -bb 

            # *** matrix F2 ***
            F_terms[2][1,2] = - (2.*rr - ss)
            F_terms[2][2,1] = bb

            return F_terms
        
        # -------------------------------------------------------------
        def shift_coefs(ss, zeta):
            ss_new = dict(ss)
            ss_new["xi_x"] = ss_new["xi_x"] + zeta[0]
            ss_new["xi_y"] = ss_new["xi_y"] + zeta[1]
            if "xi_z" in ss_new:
                ss_new["xi_z"] = ss_new["xi_z"] + zeta[2]
            return ss_new

        # --- construct the system ---
        F_terms = return_sys(sys_coefs)
        F = [
            lambda x: F_terms[0][0,0] + F_terms[1][0,0] * x[0] + F_terms[1][0,1] * x[1],
            lambda x: F_terms[0][1,0] + F_terms[1][1,0] * x[0] + F_terms[1][1,1] * x[1] + F_terms[1][1,2] * x[2] + F_terms[2][1,2] * x[0] * x[2],
            lambda x: F_terms[0][2,0] + F_terms[1][2,0] * x[0] + F_terms[1][2,1] * x[1] + F_terms[1][2,2] * x[2] + F_terms[2][2,1] * x[0] * x[1]
        ]

    # ----------------------------------------------------
    return F, tmax, nt, Nx, x_init, F_terms, sys_coefs, return_sys, shift_coefs
# ------------------------------------------------------------------------------
sel_case_ = 0

N_nl_orig_ = 2
F_, tmax_, nt_, Nx_, x_init_ref_, F_terms_, sys_coefs_, return_sys_, shift_coefs_ = choose_case(N_nl_orig_, sel_case = sel_case_)
Nt_ = 1 << nt_
t_ = np.linspace(0, tmax_, Nt_)
dt_ = np.diff(t_)[0]

print("init. cond.: ", end = "")
mix.print_array(x_init_ref_, ff = [6, 2, "f"])

# --- Standard method (for reference) ---
sol_ref_, t_ref_ = ca.analyse_classical(x_init_ref_, t_, F_)
# Out:
# init. cond.:   0.10   0.00   0.00
#
# WARNING: increase arrays: counter_t = 2048
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# --------------------------------------------------------------------
# --- Carleman linearization ---
# --------------------------------------------------------------------
mix.reload_module(ca)
N_nl = 6   # should be >= N_nl_orig_

# --- Standard embedding ---
# sol_emb_, t_emb_, case_emb_ = ca.solve_carleman_orig(x_init_ref_, N_nl, N_nl_orig_, t_, return_sys_(sys_coefs_))

# # --- Piecewise embedding ---
# zeta_th = 0.1
# sol_emb_, t_emb_, case_emb_ = ca.solve_carleman_global(
#     x_init_ref_, N_nl, N_nl_orig_, t_, 
#     sys_coefs_, return_sys_, shift_coefs_,
#     zeta_th = zeta_th
# )
# radii_emb_ = np.full(len(t_emb_), zeta_th)
# case_sim_ = "Chen"
# step_t_ = 40
# del zeta_th

# --- Piecewise adaptive embedding ---
# err_tol, zeta_max, zeta_init, step_xi = 1.e-6, 0.6, 0.6, 0.02
# err_tol, zeta_max, zeta_init, step_xi = 1.e-8, 0.6, 0.6, 0.02
err_tol, zeta_max, zeta_init, step_xi = 1.e-8, 1.0, 1.0, 0.3
sol_emb_, t_emb_, case_emb_, radii_emb_ = ca.solve_carleman_global_adaptive(
    x_init_ref_, N_nl, N_nl_orig_, t_, 
    sys_coefs_, return_sys_, shift_coefs_,
    zeta_init_ = zeta_init, 
    err_tolerance_ = err_tol,
    zeta_min_    = 1e-3,
    zeta_step_   = step_xi,
    zeta_thresh_ = step_xi + 0.2,
    zeta_max_ = zeta_max
)
case_sim_ = "Chen_max{:0.2f}_tol{:0.3e}_dx{:0.2f}".format(zeta_max, err_tol, step_xi)
step_t_ = 4
del err_tol, zeta_max, zeta_init
# Out:
# --- t, zeta: 1.721e-01, 1.000e+00 ---
# Take a smaller chart: new zeta = 7.000e-01
#
# --- t, zeta: 2.025e-01, 7.000e-01 ---
#
# --- t, zeta: 2.231e-01, 7.000e-01 ---
#
# --- t, zeta: 2.386e-01, 7.000e-01 ---
# Take a smaller chart: new zeta = 4.000e-01
#
# --- t, zeta: 2.446e-01, 4.000e-01 ---
#
# --- t, zeta: 2.555e-01, 4.000e-01 ---
#
# --- t, zeta: 2.614e-01, 4.000e-01 ---
#
# --- t, zeta: 2.674e-01, 4.000e-01 ---
# Take a smaller chart: new zeta = 2.000e-01
#
# --- t, zeta: 2.685e-01, 2.000e-01 ---
# Take a larger chart: new zeta = 4.000e-01
#
# --- t, zeta: 2.745e-01, 4.000e-01 ---
# Take a smaller chart: new zeta = 2.000e-01
#
# --- t, zeta: 2.756e-01, 2.000e-01 ---
# Take a larger chart: new zeta = 4.000e-01
#
# --- t, zeta: 2.816e-01, 4.000e-01 ---
# Take a larger chart: new zeta = 8.000e-01
#
# --- t, zeta: 2.974e-01, 8.000e-01 ---
#
# --- t, zeta: 3.042e-01, 8.000e-01 ---
#
# --- t, zeta: 3.105e-01, 8.000e-01 ---
#
# --- t, zeta: 3.164e-01, 8.000e-01 ---
#
# --- t, zeta: 3.221e-01, 8.000e-01 ---
#
# --- t, zeta: 3.278e-01, 8.000e-01 ---
#
# --- t, zeta: 3.335e-01, 8.000e-01 ---
#
# --- t, zeta: 3.444e-01, 8.000e-01 ---
#
# --- t, zeta: 3.558e-01, 8.000e-01 ---
#
# --- t, zeta: 3.731e-01, 8.000e-01 ---
# Take a smaller chart: new zeta = 5.000e-01
#
# --- t, zeta: 3.883e-01, 5.000e-01 ---
# Take a smaller chart: new zeta = 2.500e-01
#
# --- t, zeta: 3.992e-01, 2.500e-01 ---
# Take a smaller chart: new zeta = 1.250e-01
#
# --- t, zeta: 4.052e-01, 1.250e-01 ---
#
# --- t, zeta: 4.161e-01, 1.250e-01 ---
# Take a larger chart: new zeta = 2.500e-01
# Take a larger chart: new zeta = 5.000e-01
# Take a larger chart: new zeta = 1.000e+00
#
# --- t, zeta: 4.513e-01, 1.000e+00 ---
#
# --- t, zeta: 4.818e-01, 1.000e+00 ---
#
# --- t, zeta: 5.219e-01, 1.000e+00 ---
#
# --- t, zeta: 6.159e-01, 1.000e+00 ---
#
# --- t, zeta: 1.052e+00, 1.000e+00 ---
#
# --- t, zeta: 1.111e+00, 1.000e+00 ---
#
# --- t, zeta: 1.142e+00, 1.000e+00 ---
#
# --- t, zeta: 1.177e+00, 1.000e+00 ---
#
# --- t, zeta: 1.237e+00, 1.000e+00 ---
#
# --- t, zeta: 1.331e+00, 1.000e+00 ---
#
# --- t, zeta: 1.449e+00, 1.000e+00 ---
#
# --- t, zeta: 1.533e+00, 1.000e+00 ---
#
# --- t, zeta: 1.715e+00, 1.000e+00 ---
#
# --- t, zeta: 1.765e+00, 1.000e+00 ---
#
# --- t, zeta: 1.796e+00, 1.000e+00 ---
# Take a smaller chart: new zeta = 7.000e-01
#
# --- t, zeta: 1.816e+00, 7.000e-01 ---
# Take a smaller chart: new zeta = 4.000e-01
#
# --- t, zeta: 1.827e+00, 4.000e-01 ---
#
# --- t, zeta: 1.853e+00, 4.000e-01 ---
#
# --- t, zeta: 1.863e+00, 4.000e-01 ---
# Take a larger chart: new zeta = 8.000e-01
#
# --- t, zeta: 1.874e+00, 8.000e-01 ---
#
# --- t, zeta: 1.887e+00, 8.000e-01 ---
#
# --- t, zeta: 1.899e+00, 8.000e-01 ---
#
# --- t, zeta: 1.912e+00, 8.000e-01 ---
#
# --- t, zeta: 1.930e+00, 8.000e-01 ---
#
# --- t, zeta: 1.955e+00, 8.000e-01 ---
#
# --- t, zeta: 2.078e+00, 8.000e-01 ---
#
# --- t, zeta: 2.138e+00, 8.000e-01 ---
#
# --- t, zeta: 2.271e+00, 8.000e-01 ---
#
# --- t, zeta: 2.340e+00, 8.000e-01 ---
#
# --- t, zeta: 2.371e+00, 8.000e-01 ---
#
# --- t, zeta: 2.396e+00, 8.000e-01 ---
# Take a smaller chart: new zeta = 5.000e-01
#
# --- t, zeta: 2.412e+00, 5.000e-01 ---
# Take a smaller chart: new zeta = 2.500e-01
#
# --- t, zeta: 2.418e+00, 2.500e-01 ---
# Take a larger chart: new zeta = 5.000e-01
#
# --- t, zeta: 2.444e+00, 5.000e-01 ---
# Take a larger chart: new zeta = 1.000e+00
#
# --- t, zeta: 2.464e+00, 1.000e+00 ---
#
# --- t, zeta: 2.482e+00, 1.000e+00 ---
#
# --- t, zeta: 2.499e+00, 1.000e+00 ---
#
# --- t, zeta: 2.521e+00, 1.000e+00 ---
#
# --- t, zeta: 2.556e+00, 1.000e+00 ---
#
# --- t, zeta: 2.738e+00, 1.000e+00 ---
#
# --- t, zeta: 2.954e+00, 1.000e+00 ---
#
# --- t, zeta: 2.994e+00, 1.000e+00 ---
# Take a smaller chart: new zeta = 7.000e-01
#
# --- t, zeta: 3.014e+00, 7.000e-01 ---
# Take a smaller chart: new zeta = 4.000e-01
#
# --- t, zeta: 3.025e+00, 4.000e-01 ---
# Take a smaller chart: new zeta = 2.000e-01
#
# --- t, zeta: 3.031e+00, 2.000e-01 ---
# Take a larger chart: new zeta = 4.000e-01
#
# --- t, zeta: 3.057e+00, 4.000e-01 ---
#
# --- t, zeta: 3.077e+00, 4.000e-01 ---
# Take a larger chart: new zeta = 8.000e-01
#
# --- t, zeta: 3.093e+00, 8.000e-01 ---
#
# --- t, zeta: 3.106e+00, 8.000e-01 ---
#
# --- t, zeta: 3.119e+00, 8.000e-01 ---
#
# --- t, zeta: 3.138e+00, 8.000e-01 ---
#
# --- t, zeta: 3.163e+00, 8.000e-01 ---
#
# --- t, zeta: 3.340e+00, 8.000e-01 ---
#
# --- t, zeta: 3.551e+00, 8.000e-01 ---
#
# --- t, zeta: 3.591e+00, 8.000e-01 ---
#
# --- t, zeta: 3.617e+00, 8.000e-01 ---
# Take a smaller chart: new zeta = 5.000e-01
#
# --- t, zeta: 3.633e+00, 5.000e-01 ---
# Take a smaller chart: new zeta = 2.500e-01
#
# --- t, zeta: 3.639e+00, 2.500e-01 ---
#
# --- t, zeta: 3.654e+00, 2.500e-01 ---
# Take a larger chart: new zeta = 5.000e-01
#
# --- t, zeta: 3.675e+00, 5.000e-01 ---
# Take a larger chart: new zeta = 1.000e+00
#
# --- t, zeta: 3.695e+00, 1.000e+00 ---
#
# --- t, zeta: 3.713e+00, 1.000e+00 ---
#
# --- t, zeta: 3.730e+00, 1.000e+00 ---
#
# --- t, zeta: 3.753e+00, 1.000e+00 ---
#
# --- t, zeta: 3.793e+00, 1.000e+00 ---
#
# --- t, zeta: 3.960e+00, 1.000e+00 ---
#
# --- t, zeta: 4.171e+00, 1.000e+00 ---
#
# --- t, zeta: 4.212e+00, 1.000e+00 ---
# Take a smaller chart: new zeta = 7.000e-01
# Take a smaller chart: new zeta = 4.000e-01
#
# --- t, zeta: 4.222e+00, 4.000e-01 ---
#
# --- t, zeta: 4.243e+00, 4.000e-01 ---
#
# --- t, zeta: 4.269e+00, 4.000e-01 ---
# Take a larger chart: new zeta = 8.000e-01
#
# --- t, zeta: 4.289e+00, 8.000e-01 ---
#
# --- t, zeta: 4.304e+00, 8.000e-01 ---
#
# --- t, zeta: 4.318e+00, 8.000e-01 ---
#
# --- t, zeta: 4.331e+00, 8.000e-01 ---
#
# --- t, zeta: 4.350e+00, 8.000e-01 ---
#
# --- t, zeta: 4.376e+00, 8.000e-01 ---
#
# --- t, zeta: 4.445e+00, 8.000e-01 ---
#
# --- t, zeta: 4.539e+00, 8.000e-01 ---
#
# --- t, zeta: 4.760e+00, 8.000e-01 ---
#
# --- t, zeta: 4.795e+00, 8.000e-01 ---
# Take a smaller chart: new zeta = 5.000e-01
#
# --- t, zeta: 4.816e+00, 5.000e-01 ---
# Take a smaller chart: new zeta = 2.500e-01
#
# --- t, zeta: 4.827e+00, 2.500e-01 ---
#
# --- t, zeta: 4.848e+00, 2.500e-01 ---
# Take a larger chart: new zeta = 5.000e-01
#
# --- t, zeta: 4.883e+00, 5.000e-01 ---
# Take a larger chart: new zeta = 1.000e+00
#
# --- t, zeta: 4.908e+00, 1.000e+00 ---
#
# --- t, zeta: 4.933e+00, 1.000e+00 ---
#
# --- t, zeta: 4.974e+00, 1.000e+00 ---
#
# --- t, zeta: 5.405e+00, 1.000e+00 ---
# Take a smaller chart: new zeta = 7.000e-01
# Take a smaller chart: new zeta = 4.000e-01
#
# --- t, zeta: 5.425e+00, 4.000e-01 ---
#
# --- t, zeta: 5.456e+00, 4.000e-01 ---
# Take a smaller chart: new zeta = 2.000e-01
#
# --- t, zeta: 5.466e+00, 2.000e-01 ---
#
# --- t, zeta: 5.482e+00, 2.000e-01 ---
# Take a larger chart: new zeta = 4.000e-01
#
# --- t, zeta: 5.513e+00, 4.000e-01 ---
# Take a larger chart: new zeta = 8.000e-01
#
# --- t, zeta: 5.533e+00, 8.000e-01 ---
#
# --- t, zeta: 5.554e+00, 8.000e-01 ---
#
# --- t, zeta: 5.579e+00, 8.000e-01 ---
#
# --- t, zeta: 5.620e+00, 8.000e-01 ---
#
# --- t, zeta: 5.689e+00, 8.000e-01 ---
#
# --- t, zeta: 5.856e+00, 8.000e-01 ---
#
# --- t, zeta: 5.940e+00, 8.000e-01 ---
#
# --- t, zeta: 6.127e+00, 8.000e-01 ---
#
# --- t, zeta: 6.167e+00, 8.000e-01 ---
#
# --- t, zeta: 6.193e+00, 8.000e-01 ---
#
# --- t, zeta: 6.214e+00, 8.000e-01 ---
# Take a smaller chart: new zeta = 5.000e-01
#
# --- t, zeta: 6.229e+00, 5.000e-01 ---
#
# --- t, zeta: 6.255e+00, 5.000e-01 ---
# Take a smaller chart: new zeta = 2.500e-01
#
# --- t, zeta: 6.261e+00, 2.500e-01 ---
# Take a larger chart: new zeta = 5.000e-01
# Take a larger chart: new zeta = 1.000e+00
#
# --- t, zeta: 6.277e+00, 1.000e+00 ---
#
# --- t, zeta: 6.293e+00, 1.000e+00 ---
#
# --- t, zeta: 6.309e+00, 1.000e+00 ---
#
# --- t, zeta: 6.330e+00, 1.000e+00 ---
#
# --- t, zeta: 6.365e+00, 1.000e+00 ---
#
# --- t, zeta: 6.488e+00, 1.000e+00 ---
#
# --- t, zeta: 6.587e+00, 1.000e+00 ---
#
# --- t, zeta: 6.720e+00, 1.000e+00 ---
#
# --- t, zeta: 6.765e+00, 1.000e+00 ---
# Take a smaller chart: new zeta = 7.000e-01
#
# --- t, zeta: 6.785e+00, 7.000e-01 ---
# Take a smaller chart: new zeta = 4.000e-01
#
# --- t, zeta: 6.796e+00, 4.000e-01 ---
#
# --- t, zeta: 6.817e+00, 4.000e-01 ---
#
# --- t, zeta: 6.837e+00, 4.000e-01 ---
# Take a larger chart: new zeta = 8.000e-01
#
# --- t, zeta: 6.858e+00, 8.000e-01 ---
#
# --- t, zeta: 6.872e+00, 8.000e-01 ---
#
# --- t, zeta: 6.885e+00, 8.000e-01 ---
#
# --- t, zeta: 6.898e+00, 8.000e-01 ---
#
# --- t, zeta: 6.917e+00, 8.000e-01 ---
#
# --- t, zeta: 6.942e+00, 8.000e-01 ---
#
# --- t, zeta: 7.129e+00, 8.000e-01 ---
#
# --- t, zeta: 7.321e+00, 8.000e-01 ---
#
# --- t, zeta: 7.361e+00, 8.000e-01 ---
# Take a smaller chart: new zeta = 5.000e-01
#
# --- t, zeta: 7.377e+00, 5.000e-01 ---
#
# --- t, zeta: 7.402e+00, 5.000e-01 ---
# Take a smaller chart: new zeta = 2.500e-01
#
# --- t, zeta: 7.408e+00, 2.500e-01 ---
# Take a larger chart: new zeta = 5.000e-01
#
# --- t, zeta: 7.438e+00, 5.000e-01 ---
# >>> The non-shifted chart is unstable
#
# --- t, zeta: 7.464e+00, 5.000e-01 ---
# Take a larger chart: new zeta = 1.000e+00
#
# --- t, zeta: 7.484e+00, 1.000e+00 ---
#
# --- t, zeta: 7.501e+00, 1.000e+00 ---
#
# --- t, zeta: 7.525e+00, 1.000e+00 ---
#
# --- t, zeta: 7.571e+00, 1.000e+00 ---
#
# --- t, zeta: 7.772e+00, 1.000e+00 ---
#
# --- t, zeta: 7.924e+00, 1.000e+00 ---
# Take a smaller chart: new zeta = 7.000e-01
#
# --- t, zeta: 7.960e+00, 7.000e-01 ---
# Take a smaller chart: new zeta = 4.000e-01
#
# --- t, zeta: 7.975e+00, 4.000e-01 ---
# Take a smaller chart: new zeta = 2.000e-01
#
# --- t, zeta: 7.981e+00, 2.000e-01 ---
#
# --- t, zeta: 8.002e+00, 2.000e-01 ---
#
# --- t, zeta: 8.018e+00, 2.000e-01 ---
# Take a larger chart: new zeta = 4.000e-01
# Take a larger chart: new zeta = 8.000e-01
#
# --- t, zeta: 8.043e+00, 8.000e-01 ---
#
# --- t, zeta: 8.064e+00, 8.000e-01 ---
#
# --- t, zeta: 8.084e+00, 8.000e-01 ---
#
# --- t, zeta: 8.105e+00, 8.000e-01 ---
#
# --- t, zeta: 8.135e+00, 8.000e-01 ---
#
# --- t, zeta: 8.195e+00, 8.000e-01 ---
#
# --- t, zeta: 8.396e+00, 8.000e-01 ---
#
# --- t, zeta: 8.559e+00, 8.000e-01 ---
#
# --- t, zeta: 8.599e+00, 8.000e-01 ---
# Take a smaller chart: new zeta = 5.000e-01
# Take a smaller chart: new zeta = 2.500e-01
#
# --- t, zeta: 8.610e+00, 2.500e-01 ---
#
# --- t, zeta: 8.640e+00, 2.500e-01 ---
# Take a smaller chart: new zeta = 1.250e-01
#
# --- t, zeta: 8.646e+00, 1.250e-01 ---
# Take a larger chart: new zeta = 2.500e-01
# Take a larger chart: new zeta = 5.000e-01
#
# --- t, zeta: 8.686e+00, 5.000e-01 ---
# Take a larger chart: new zeta = 1.000e+00
#
# --- t, zeta: 8.712e+00, 1.000e+00 ---
#
# --- t, zeta: 8.742e+00, 1.000e+00 ---
#
# --- t, zeta: 8.787e+00, 1.000e+00 ---
#
# --- t, zeta: 8.881e+00, 1.000e+00 ---
#
# --- t, zeta: 9.034e+00, 1.000e+00 ---
#
# --- t, zeta: 9.279e+00, 1.000e+00 ---
# Take a smaller chart: new zeta = 7.000e-01
#
# --- t, zeta: 9.305e+00, 7.000e-01 ---
#
# --- t, zeta: 9.330e+00, 7.000e-01 ---
# Take a smaller chart: new zeta = 4.000e-01
#
# --- t, zeta: 9.341e+00, 4.000e-01 ---
# Take a smaller chart: new zeta = 2.000e-01
#
# --- t, zeta: 9.347e+00, 2.000e-01 ---
# Take a larger chart: new zeta = 4.000e-01
#
# --- t, zeta: 9.373e+00, 4.000e-01 ---
# Take a larger chart: new zeta = 8.000e-01
#
# --- t, zeta: 9.393e+00, 8.000e-01 ---
#
# --- t, zeta: 9.408e+00, 8.000e-01 ---
#
# --- t, zeta: 9.421e+00, 8.000e-01 ---
#
# --- t, zeta: 9.434e+00, 8.000e-01 ---
#
# --- t, zeta: 9.453e+00, 8.000e-01 ---
#
# --- t, zeta: 9.478e+00, 8.000e-01 ---
#
# --- t, zeta: 9.695e+00, 8.000e-01 ---
#
# --- t, zeta: 9.852e+00, 8.000e-01 ---
#
# --- t, zeta: 9.892e+00, 8.000e-01 ---
# Take a smaller chart: new zeta = 5.000e-01
#
# --- t, zeta: 9.913e+00, 5.000e-01 ---
# Take a smaller chart: new zeta = 2.500e-01
#
# --- t, zeta: 9.919e+00, 2.500e-01 ---
#
# --- t, zeta: 9.939e+00, 2.500e-01 ---
#
# --- t, zeta: 9.960e+00, 2.500e-01 ---
# Take a larger chart: new zeta = 5.000e-01
# >>> The non-shifted chart is unstable
#
# --- t, zeta: 9.990e+00, 5.000e-01 ---
#
# --- t, zeta: 1.000e+01, 5.000e-01 ---
# Done

# %%
step_t_ = 20

# %%
# --------------------------------------------------------------------
# --- Compare trajectories ---
# --------------------------------------------------------------------
mix.reload_module(ca)
ca.compare_trajectory_cl_and_carleman(
    t_ref_, sol_ref_, t_emb_, sol_emb_,
    flag_save = True, 
    path_save=path_save_, 
    case_title = case_sim_, case_emb = case_emb_,
    fontsize = 20, fig_size = (10,9),
    radii_emb = radii_emb_,
    flag_var_semilogy = False,
    step_t = step_t_
)
# Out:
# write data to a file: ./jupyter-notebooks/Carleman/results//REF_Chen_max1.00_tol1.000e-08_dx0.30_xyz.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_Chen_max1.00_tol1.000e-08_dx0.30_PAE_xyz.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//REF_Chen_max1.00_tol1.000e-08_dx0.30_x.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_Chen_max1.00_tol1.000e-08_dx0.30_PAE_x.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//REF_Chen_max1.00_tol1.000e-08_dx0.30_y.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_Chen_max1.00_tol1.000e-08_dx0.30_PAE_y.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//REF_Chen_max1.00_tol1.000e-08_dx0.30_z.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_Chen_max1.00_tol1.000e-08_dx0.30_PAE_z.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_Chen_max1.00_tol1.000e-08_dx0.30_PAE_err_x.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_Chen_max1.00_tol1.000e-08_dx0.30_PAE_err_y.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_Chen_max1.00_tol1.000e-08_dx0.30_PAE_err_z.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_Chen_max1.00_tol1.000e-08_dx0.30_PAE_radius.dat
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
