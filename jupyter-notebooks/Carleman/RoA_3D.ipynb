# %%
# %matplotlib widget
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
import h5py

import os
import sys
sys.path.append(os.path.abspath("./"))

print(os.getpid())
# %cd ../../

import pylib.mix as mix
import carleman as ca
from matplotlib import colors
plt.rcParams.update({
    "text.usetex": True,
    'text.latex.preamble': r"\usepackage{amsmath} \boldmath"
})
# Out:
# 1652
# c:\Users\ivan9\Documents\work\codes\QuCF\scripts-py

# %%
path_save_ = "./jupyter-notebooks/Carleman/results/"
for i in range(100):
    plt.close()

colors_     = ["blue", "red", "green", "gray", "black"]
linestyles_ = ["-", "--", "--", ":"]

# %%
# ---------------------------------------------------------------
# --- Prepare the system: Roessler attractor ---
# ---------------------------------------------------------------
mix.reload_module(ca)
mix.reload_module(mix)
def choose_case(N_nl, sel_case):
    Nx = 3  # the number of degrees of freedom
    F_terms, sys_coefs, return_sys, shift_coefs = None, None, None, None

    # ----------------------------------------------------
    if sel_case == 0:
        F_terms = [None] * (N_nl + 1)
        for ii_nl in range(N_nl + 1):
            F_terms[ii_nl] = np.zeros((Nx,int(Nx**ii_nl)))

        tmax, nt = 80, 12

        # ss, rr, bb = 0.2, 5.7, 0.2
        # ss, rr, bb = 0.4, 6., 0.2
        ss, rr, bb, eta = 0.2, 6., 0.6, 2.

        xi_x, xi_y, xi_z = 0., 0., 0.
        x_init = np.array([0.0, 0.4, 0.0])

        # F = [
        #     lambda x: - x[1] - x[2],
        #     lambda x: x[0] + ss * x[1],
        #     lambda x: bb - rr * x[2] + x[0] * x[2]
        # ]

        F = [
            lambda x: - x[1] - x[2],
            lambda x: x[0] + ss * x[1],
            lambda x: bb/(eta*rr) - rr * x[2] + eta*rr * x[0] * x[2]
        ]

    # ----------------------------------------------------------
    if sel_case == 1:
        tmax, nt = 80, 10
        # tmax, nt = 14, 9

        # ss, rr, bb, eta = 0.2, 6., 0.6, 2.
        ss, rr, bb, eta = 0.2, 6., 0.6, 2.4

        xi_x, xi_y, xi_z = 0., 0., 0.
        x_init = np.array([0.0, 0.4, 0.0])

        sys_coefs = {}
        sys_coefs["ss"]   = ss
        sys_coefs["rr"]   = rr
        sys_coefs["bb"]   = bb
        sys_coefs["eta"]  = eta
        sys_coefs["xi_x"] = xi_x
        sys_coefs["xi_y"] = xi_y
        sys_coefs["xi_z"] = xi_z

        # -------------------------------------------------------------
        def return_sys(ss_coefs):
            ss   = ss_coefs["ss"]    
            rr   = ss_coefs["rr"]    
            bb   = ss_coefs["bb"] 
            eta  = ss_coefs["eta"]   
            xi_x = ss_coefs["xi_x"]  
            xi_y = ss_coefs["xi_y"]  
            xi_z = ss_coefs["xi_z"]  

            F_terms = [None] * (N_nl + 1)
            for ii_nl in range(N_nl + 1):
                F_terms[ii_nl] = np.zeros((Nx,int(Nx**ii_nl)))

            # *** Equation 0 ***
            F_terms[0][0,0] = - (xi_y + xi_z)
            F_terms[1][0,1] = -1.
            F_terms[1][0,2] = -1.

            # *** Equation 1 ***
            F_terms[0][1,0] = xi_x + ss * xi_y
            F_terms[1][1,0] = 1.
            F_terms[1][1,1] = ss

            # *** Equation 2 ***
            F_terms[0][2,0] = bb/(rr * eta) - rr*xi_z + eta * rr * xi_x*xi_z
            F_terms[1][2,0] = eta * rr * xi_z
            F_terms[1][2,2] = eta * rr * xi_x - rr
            F_terms[2][2,2] = eta * rr
            return F_terms
        
        # -------------------------------------------------------------
        def shift_coefs(ss, zeta):
            ss_new = dict(ss)
            ss_new["xi_x"] = ss_new["xi_x"] + zeta[0]
            ss_new["xi_y"] = ss_new["xi_y"] + zeta[1]
            if "xi_z" in ss_new:
                ss_new["xi_z"] = ss_new["xi_z"] + zeta[2]
            return ss_new

        # --- construct the system ---
        F_terms = return_sys(sys_coefs)
        F = [
            lambda x: F_terms[0][0,0] + F_terms[1][0,1] * x[1] + F_terms[1][0,2] * x[2],
            lambda x: F_terms[0][1,0] + F_terms[1][1,0] * x[0] + F_terms[1][1,1] * x[1],
            lambda x: F_terms[0][2,0] + F_terms[1][2,0] * x[0] + F_terms[1][2,2] * x[2] + F_terms[2][2,2] * x[0] * x[2]
        ]

    # ----------------------------------------------------
    return F, tmax, nt, Nx, x_init, F_terms, sys_coefs, return_sys, shift_coefs
# ------------------------------------------------------------------------------
sel_case_ = 1

N_nl_orig_ = 2
F_, tmax_, nt_, Nx_, x_init_ref_, F_terms_, sys_coefs_, return_sys_, shift_coefs_ = choose_case(N_nl_orig_, sel_case = sel_case_)
Nt_ = 1 << nt_
t_ = np.linspace(0, tmax_, Nt_)
dt_ = np.diff(t_)[0]

print("init. cond.: ", end = "")
mix.print_array(x_init_ref_, ff = [6, 2, "f"])

# --- Standard method (for reference) ---
sol_ref_, t_ref_ = ca.analyse_classical(x_init_ref_, t_, F_)
# Out:
# init. cond.:   0.00   0.40   0.00
#
# WARNING: increase arrays: counter_t = 1024
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# --------------------------------------------------------------------
# --- Carleman linearization ---
# --------------------------------------------------------------------
mix.reload_module(ca)
N_nl = 6   # should be >= N_nl_orig_

# sol_emb_, t_emb_, case_emb_ = ca.solve_carleman_orig(x_init_ref_, N_nl, N_nl_orig_, t_, return_sys_(sys_coefs_))

sol_emb_, t_emb_, case_emb_ = ca.solve_carleman_global(
    x_init_ref_, N_nl, N_nl_orig_, t_, 
    sys_coefs_, return_sys_, shift_coefs_,
    zeta_th = 0.1
)
# Out:
# The total number of variables in the embedding: 1092
# --- Shift to another chart, t = 0.005 ---
# radius: 0.4
# zeta_gl:  -0.00   0.40   0.00
# xs:     -1.935e-03      4.004e-01      1.985e-04
#
# WARNING: increase arrays: counter_t = 2
# --- Shift to another chart, t = 0.251 ---
# radius: 0.1
# zeta_gl:  -0.10   0.41   0.00
# xs:     -1.006e-01      7.181e-03      4.698e-03
#
# WARNING: increase arrays: counter_t = 8
# --- Shift to another chart, t = 0.496 ---
# radius: 0.1
# zeta_gl:  -0.20   0.39   0.00
# xs:     -9.971e-02     -1.783e-02      4.145e-05
#
# WARNING: increase arrays: counter_t = 14
# --- Shift to another chart, t = 0.742 ---
# radius: 0.1
# zeta_gl:  -0.29   0.35   0.00
# xs:     -9.212e-02     -4.302e-02     -6.321e-04
#
# WARNING: increase arrays: counter_t = 20
# --- Shift to another chart, t = 0.988 ---
# radius: 0.1
# zeta_gl:  -0.37   0.28   0.00
# xs:     -7.844e-02     -6.680e-02     -4.967e-04
#
# WARNING: increase arrays: counter_t = 26
# --- Shift to another chart, t = 1.233 ---
# radius: 0.1
# zeta_gl:  -0.43   0.19   0.00
# xs:     -5.929e-02     -8.764e-02     -3.185e-04
#
# WARNING: increase arrays: counter_t = 32
# --- Shift to another chart, t = 1.479 ---
# radius: 0.1
# zeta_gl:  -0.47   0.09   0.00
# xs:     -3.557e-02     -1.041e-01     -1.798e-04
#
# WARNING: increase arrays: counter_t = 38
# --- Shift to another chart, t = 1.725 ---
# radius: 0.1
# zeta_gl:  -0.48  -0.03   0.00
# xs:     -8.500e-03     -1.150e-01     -6.566e-05
#
# WARNING: increase arrays: counter_t = 44
# --- Shift to another chart, t = 1.970 ---
# radius: 0.1
# zeta_gl:  -0.46  -0.15   0.00
# xs:      2.043e-02     -1.193e-01      4.101e-05
#
# WARNING: increase arrays: counter_t = 50
# --- Shift to another chart, t = 2.216 ---
# radius: 0.1
# zeta_gl:  -0.41  -0.26   0.00
# xs:      4.953e-02     -1.165e-01      1.554e-04
#
# WARNING: increase arrays: counter_t = 56
# --- Shift to another chart, t = 2.462 ---
# radius: 0.1
# zeta_gl:  -0.33  -0.37   0.00
# xs:      7.702e-02     -1.064e-01      2.949e-04
#
# WARNING: increase arrays: counter_t = 62
# --- Shift to another chart, t = 2.708 ---
# radius: 0.1
# zeta_gl:  -0.23  -0.46   0.00
# xs:      1.011e-01     -8.931e-02      4.856e-04
#
# WARNING: increase arrays: counter_t = 68
# --- Shift to another chart, t = 2.953 ---
# radius: 0.1
# zeta_gl:  -0.11  -0.52   0.00
# xs:      1.201e-01     -6.585e-02      7.730e-04
#
# WARNING: increase arrays: counter_t = 74
# --- Shift to another chart, t = 3.199 ---
# radius: 0.1
# zeta_gl:   0.02  -0.56   0.01
# xs:      1.327e-01     -3.720e-02      1.246e-03
#
# WARNING: increase arrays: counter_t = 80
# --- Shift to another chart, t = 3.445 ---
# radius: 0.1
# zeta_gl:   0.16  -0.57   0.01
# xs:      1.375e-01     -4.890e-03      2.095e-03
#
# WARNING: increase arrays: counter_t = 86
# --- Shift to another chart, t = 3.690 ---
# radius: 0.1
# zeta_gl:   0.30  -0.54   0.01
# xs:      1.338e-01      2.921e-02      3.759e-03
#
# WARNING: increase arrays: counter_t = 92
# --- Shift to another chart, t = 3.936 ---
# radius: 0.1
# zeta_gl:   0.42  -0.47   0.02
# xs:      1.211e-01      6.299e-02      7.319e-03
#
# WARNING: increase arrays: counter_t = 98
# --- Shift to another chart, t = 4.182 ---
# radius: 0.1
# zeta_gl:   0.52  -0.38   0.03
# xs:      9.910e-02      9.413e-02      1.553e-02
#
# WARNING: increase arrays: counter_t = 104
# --- Shift to another chart, t = 4.428 ---
# radius: 0.1
# zeta_gl:   0.58  -0.26   0.07
# xs:      6.678e-02      1.200e-01      3.505e-02
#
# WARNING: increase arrays: counter_t = 110
# --- Shift to another chart, t = 4.595 ---
# radius: 0.1
# zeta_gl:   0.60  -0.17   0.12
# xs:      2.062e-02      9.254e-02      4.647e-02
#
# WARNING: increase arrays: counter_t = 115
# --- Shift to another chart, t = 4.763 ---
# radius: 0.1
# zeta_gl:   0.60  -0.07   0.19
# xs:     -5.400e-03      9.708e-02      7.507e-02
#
# WARNING: increase arrays: counter_t = 120
# --- Shift to another chart, t = 4.930 ---
# radius: 0.1
# zeta_gl:   0.56   0.03   0.29
# xs:     -3.679e-02      9.688e-02      1.029e-01
#
# WARNING: increase arrays: counter_t = 125
# --- Shift to another chart, t = 5.098 ---
# radius: 0.2
# zeta_gl:   0.49   0.12   0.39
# xs:     -7.028e-02      9.106e-02      9.958e-02
#
# WARNING: increase arrays: counter_t = 130
# --- Shift to another chart, t = 5.265 ---
# radius: 0.1
# zeta_gl:   0.39   0.20   0.43
# xs:     -9.676e-02      7.976e-02      3.440e-02
#
# WARNING: increase arrays: counter_t = 135
# --- Shift to another chart, t = 5.433 ---
# radius: 0.1
# zeta_gl:   0.29   0.26   0.36
# xs:     -1.063e-01      6.491e-02     -6.494e-02
#
# WARNING: increase arrays: counter_t = 140
# --- Shift to another chart, t = 5.600 ---
# radius: 0.2
# zeta_gl:   0.19   0.31   0.24
# xs:     -9.921e-02      4.944e-02     -1.219e-01
#
# WARNING: increase arrays: counter_t = 145
# --- Shift to another chart, t = 5.768 ---
# radius: 0.1
# zeta_gl:   0.10   0.35   0.13
# xs:     -8.601e-02      3.534e-02     -1.111e-01
#
# WARNING: increase arrays: counter_t = 150
# --- Shift to another chart, t = 5.935 ---
# radius: 0.1
# zeta_gl:   0.03   0.37   0.06
# xs:     -7.559e-02      2.285e-02     -7.001e-02
#
# WARNING: increase arrays: counter_t = 155
# --- Shift to another chart, t = 6.181 ---
# radius: 0.1
# zeta_gl:  -0.07   0.38   0.02
# xs:     -1.015e-01      1.270e-02     -4.266e-02
#
# WARNING: increase arrays: counter_t = 161
# --- Shift to another chart, t = 6.505 ---
# radius: 0.1
# zeta_gl:  -0.20   0.36   0.01
# xs:     -1.250e-01     -2.016e-02     -1.178e-02
#
# WARNING: increase arrays: counter_t = 168
# --- Shift to another chart, t = 6.829 ---
# radius: 0.1
# zeta_gl:  -0.31   0.30   0.00
# xs:     -1.101e-01     -6.117e-02     -1.734e-03
#
# WARNING: increase arrays: counter_t = 175
# --- Shift to another chart, t = 7.152 ---
# radius: 0.1
# zeta_gl:  -0.39   0.20   0.00
# xs:     -8.386e-02     -9.809e-02     -5.538e-04
#
# WARNING: increase arrays: counter_t = 182
# --- Shift to another chart, t = 7.398 ---
# radius: 0.1
# zeta_gl:  -0.43   0.11   0.00
# xs:     -3.951e-02     -9.419e-02     -2.150e-04
#
# WARNING: increase arrays: counter_t = 188
# --- Shift to another chart, t = 7.644 ---
# radius: 0.1
# zeta_gl:  -0.45   0.00   0.00
# xs:     -1.478e-02     -1.059e-01     -9.535e-05
#
# WARNING: increase arrays: counter_t = 194
# --- Shift to another chart, t = 7.890 ---
# radius: 0.1
# zeta_gl:  -0.44  -0.11   0.00
# xs:      1.207e-02     -1.116e-01      1.219e-05
#
# WARNING: increase arrays: counter_t = 200
# --- Shift to another chart, t = 8.135 ---
# radius: 0.1
# zeta_gl:  -0.40  -0.22   0.00
# xs:      3.950e-02     -1.107e-01      1.232e-04
#
# WARNING: increase arrays: counter_t = 206
# --- Shift to another chart, t = 8.381 ---
# radius: 0.1
# zeta_gl:  -0.33  -0.32   0.00
# xs:      6.586e-02     -1.030e-01      2.532e-04
#
# WARNING: increase arrays: counter_t = 212
# --- Shift to another chart, t = 8.627 ---
# radius: 0.1
# zeta_gl:  -0.24  -0.41   0.00
# xs:      8.945e-02     -8.861e-02      4.240e-04
#
# WARNING: increase arrays: counter_t = 218
# --- Shift to another chart, t = 8.872 ---
# radius: 0.1
# zeta_gl:  -0.13  -0.48   0.00
# xs:      1.087e-01     -6.803e-02      6.710e-04
#
# WARNING: increase arrays: counter_t = 224
# --- Shift to another chart, t = 9.118 ---
# radius: 0.1
# zeta_gl:  -0.01  -0.52   0.01
# xs:      1.221e-01     -4.228e-02      1.060e-03
#
# WARNING: increase arrays: counter_t = 230
# --- Shift to another chart, t = 9.364 ---
# radius: 0.1
# zeta_gl:   0.12  -0.53   0.01
# xs:      1.286e-01     -1.269e-02      1.722e-03
#
# WARNING: increase arrays: counter_t = 236
# --- Shift to another chart, t = 9.609 ---
# radius: 0.1
# zeta_gl:   0.25  -0.51   0.01
# xs:      1.273e-01      1.907e-02      2.940e-03
#
# WARNING: increase arrays: counter_t = 242
# --- Shift to another chart, t = 9.855 ---
# radius: 0.1
# zeta_gl:   0.36  -0.46   0.02
# xs:      1.177e-01      5.106e-02      5.354e-03
#
# WARNING: increase arrays: counter_t = 248
# --- Shift to another chart, t = 10.101 ---
# radius: 0.1
# zeta_gl:   0.46  -0.38   0.03
# xs:      9.950e-02      8.118e-02      1.046e-02
#
# WARNING: increase arrays: counter_t = 254
# --- Shift to another chart, t = 10.347 ---
# radius: 0.1
# zeta_gl:   0.54  -0.28   0.05
# xs:      7.250e-02      1.071e-01      2.154e-02
#
# WARNING: increase arrays: counter_t = 260
# --- Shift to another chart, t = 10.592 ---
# radius: 0.1
# zeta_gl:   0.57  -0.15   0.09
# xs:      3.585e-02      1.264e-01      4.430e-02
#
# WARNING: increase arrays: counter_t = 266
# --- Shift to another chart, t = 10.760 ---
# radius: 0.1
# zeta_gl:   0.57  -0.06   0.14
# xs:     -2.181e-03      9.247e-02      5.058e-02
#
# WARNING: increase arrays: counter_t = 271
# --- Shift to another chart, t = 10.927 ---
# radius: 0.1
# zeta_gl:   0.54   0.04   0.21
# xs:     -2.767e-02      9.312e-02      6.624e-02
#
# WARNING: increase arrays: counter_t = 276
# --- Shift to another chart, t = 11.095 ---
# radius: 0.1
# zeta_gl:   0.49   0.13   0.27
# xs:     -5.438e-02      8.931e-02      6.493e-02
#
# WARNING: increase arrays: counter_t = 281
# --- Shift to another chart, t = 11.262 ---
# radius: 0.1
# zeta_gl:   0.41   0.21   0.30
# xs:     -7.719e-02      8.106e-02      3.041e-02
#
# WARNING: increase arrays: counter_t = 286
# --- Shift to another chart, t = 11.430 ---
# radius: 0.1
# zeta_gl:   0.32   0.28   0.28
# xs:     -9.009e-02      6.941e-02     -2.869e-02
#
# WARNING: increase arrays: counter_t = 291
# --- Shift to another chart, t = 11.597 ---
# radius: 0.1
# zeta_gl:   0.23   0.33   0.20
# xs:     -9.152e-02      5.616e-02     -7.439e-02
#
# WARNING: increase arrays: counter_t = 296
# --- Shift to another chart, t = 11.765 ---
# radius: 0.1
# zeta_gl:   0.14   0.38   0.12
# xs:     -8.625e-02      4.289e-02     -8.092e-02
#
# WARNING: increase arrays: counter_t = 301
# --- Shift to another chart, t = 11.932 ---
# radius: 0.1
# zeta_gl:   0.06   0.41   0.06
# xs:     -8.041e-02      3.017e-02     -5.924e-02
#
# WARNING: increase arrays: counter_t = 306
# --- Shift to another chart, t = 12.178 ---
# radius: 0.1
# zeta_gl:  -0.05   0.43   0.02
# xs:     -1.119e-01      2.198e-02     -4.163e-02
#
# WARNING: increase arrays: counter_t = 312
# --- Shift to another chart, t = 12.424 ---
# radius: 0.1
# zeta_gl:  -0.16   0.42   0.01
# xs:     -1.080e-01     -4.600e-03     -1.188e-02
#
# WARNING: increase arrays: counter_t = 318
# --- Shift to another chart, t = 12.669 ---
# radius: 0.1
# zeta_gl:  -0.26   0.39   0.00
# xs:     -1.021e-01     -3.139e-02     -2.791e-03
#
# WARNING: increase arrays: counter_t = 324
# --- Shift to another chart, t = 12.915 ---
# radius: 0.1
# zeta_gl:  -0.35   0.33   0.00
# xs:     -9.075e-02     -5.739e-02     -8.573e-04
#
# WARNING: increase arrays: counter_t = 330
# --- Shift to another chart, t = 13.161 ---
# radius: 0.1
# zeta_gl:  -0.42   0.25   0.00
# xs:     -7.353e-02     -8.110e-02     -4.283e-04
#
# WARNING: increase arrays: counter_t = 336
# --- Shift to another chart, t = 13.407 ---
# radius: 0.1
# zeta_gl:  -0.48   0.15   0.00
# xs:     -5.098e-02     -1.010e-01     -2.482e-04
#
# WARNING: increase arrays: counter_t = 342
# --- Shift to another chart, t = 13.652 ---
# radius: 0.1
# zeta_gl:  -0.50   0.04   0.00
# xs:     -2.420e-02     -1.156e-01     -1.223e-04
#
# WARNING: increase arrays: counter_t = 348
# --- Shift to another chart, t = 13.898 ---
# radius: 0.1
# zeta_gl:  -0.49  -0.09   0.00
# xs:      5.385e-03     -1.239e-01     -1.399e-05
#
# WARNING: increase arrays: counter_t = 354
# --- Shift to another chart, t = 14.144 ---
# radius: 0.1
# zeta_gl:  -0.46  -0.21   0.00
# xs:      3.610e-02     -1.250e-01      9.409e-05
#
# WARNING: increase arrays: counter_t = 360
# --- Shift to another chart, t = 14.389 ---
# radius: 0.1
# zeta_gl:  -0.39  -0.33   0.00
# xs:      6.612e-02     -1.184e-01      2.181e-04
#
# WARNING: increase arrays: counter_t = 366
# --- Shift to another chart, t = 14.635 ---
# radius: 0.1
# zeta_gl:  -0.30  -0.43   0.00
# xs:      9.355e-02     -1.042e-01      3.797e-04
#
# WARNING: increase arrays: counter_t = 372
# --- Shift to another chart, t = 14.881 ---
# radius: 0.1
# zeta_gl:  -0.18  -0.52   0.00
# xs:      1.165e-01     -8.290e-02      6.144e-04
#
# WARNING: increase arrays: counter_t = 378
# --- Shift to another chart, t = 15.126 ---
# radius: 0.1
# zeta_gl:  -0.05  -0.57   0.01
# xs:      1.335e-01     -5.547e-02      9.898e-04
#
# WARNING: increase arrays: counter_t = 384
# --- Shift to another chart, t = 15.372 ---
# radius: 0.1
# zeta_gl:   0.09  -0.60   0.01
# xs:      1.429e-01     -2.330e-02      1.648e-03
#
# WARNING: increase arrays: counter_t = 390
# --- Shift to another chart, t = 15.618 ---
# radius: 0.1
# zeta_gl:   0.24  -0.58   0.01
# xs:      1.438e-01      1.181e-02      2.917e-03
#
# WARNING: increase arrays: counter_t = 396
# --- Shift to another chart, t = 15.864 ---
# radius: 0.1
# zeta_gl:   0.37  -0.54   0.02
# xs:      1.355e-01      4.779e-02      5.618e-03
#
# WARNING: increase arrays: counter_t = 402
# --- Shift to another chart, t = 16.109 ---
# radius: 0.1
# zeta_gl:   0.49  -0.45   0.03
# xs:      1.174e-01      8.227e-02      1.197e-02
#
# WARNING: increase arrays: counter_t = 408
# --- Shift to another chart, t = 16.355 ---
# radius: 0.1
# zeta_gl:   0.58  -0.34   0.06
# xs:      8.874e-02      1.126e-01      2.803e-02
#
# WARNING: increase arrays: counter_t = 414
# --- Shift to another chart, t = 16.523 ---
# radius: 0.1
# zeta_gl:   0.62  -0.25   0.10
# xs:      3.753e-02      9.064e-02      3.994e-02
#
# WARNING: increase arrays: counter_t = 419
# --- Shift to another chart, t = 16.690 ---
# radius: 0.1
# zeta_gl:   0.63  -0.15   0.17
# xs:      1.251e-02      9.810e-02      7.198e-02
#
# WARNING: increase arrays: counter_t = 424
# --- Shift to another chart, t = 16.858 ---
# radius: 0.2
# zeta_gl:   0.61  -0.05   0.28
# xs:     -1.997e-02      1.009e-01      1.172e-01
#
# WARNING: increase arrays: counter_t = 429
# --- Shift to another chart, t = 17.025 ---
# radius: 0.2
# zeta_gl:   0.55   0.05   0.43
# xs:     -5.961e-02      9.769e-02      1.499e-01
#
# WARNING: increase arrays: counter_t = 434
# --- Shift to another chart, t = 17.193 ---
# radius: 0.2
# zeta_gl:   0.45   0.13   0.54
# xs:     -9.839e-02      8.746e-02      1.097e-01
#
# WARNING: increase arrays: counter_t = 439
# --- Shift to another chart, t = 17.360 ---
# radius: 0.1
# zeta_gl:   0.33   0.20   0.52
# xs:     -1.198e-01      7.150e-02     -2.370e-02
#
# WARNING: increase arrays: counter_t = 444
# --- Shift to another chart, t = 17.528 ---
# radius: 0.2
# zeta_gl:   0.22   0.26   0.37
# xs:     -1.149e-01      5.361e-02     -1.462e-01
#
# WARNING: increase arrays: counter_t = 449
# --- Shift to another chart, t = 17.617 ---
# radius: 0.1
# zeta_gl:   0.16   0.28   0.28
# xs:     -5.335e-02      2.179e-02     -9.138e-02
#
# WARNING: increase arrays: counter_t = 453
# --- Shift to another chart, t = 17.784 ---
# radius: 0.2
# zeta_gl:   0.08   0.31   0.14
# xs:     -8.444e-02      3.006e-02     -1.396e-01
#
# WARNING: increase arrays: counter_t = 458
# --- Shift to another chart, t = 17.952 ---
# radius: 0.1
# zeta_gl:   0.01   0.33   0.06
# xs:     -7.003e-02      1.803e-02     -8.052e-02
#
# WARNING: increase arrays: counter_t = 463
# --- Shift to another chart, t = 18.198 ---
# radius: 0.1
# zeta_gl:  -0.08   0.34   0.02
# xs:     -9.055e-02      7.419e-03     -4.523e-02
#
# WARNING: increase arrays: counter_t = 469
# --- Shift to another chart, t = 18.521 ---
# radius: 0.1
# zeta_gl:  -0.19   0.31   0.01
# xs:     -1.090e-01     -2.302e-02     -1.163e-02
#
# WARNING: increase arrays: counter_t = 476
# --- Shift to another chart, t = 18.845 ---
# radius: 0.1
# zeta_gl:  -0.28   0.25   0.00
# xs:     -9.409e-02     -5.880e-02     -1.632e-03
#
# WARNING: increase arrays: counter_t = 483
# --- Shift to another chart, t = 19.169 ---
# radius: 0.1
# zeta_gl:  -0.35   0.16   0.00
# xs:     -6.947e-02     -9.043e-02     -5.076e-04
#
# WARNING: increase arrays: counter_t = 490
# --- Shift to another chart, t = 19.493 ---
# radius: 0.1
# zeta_gl:  -0.39   0.05   0.00
# xs:     -3.593e-02     -1.144e-01     -2.285e-04
#
# WARNING: increase arrays: counter_t = 497
# --- Shift to another chart, t = 19.817 ---
# radius: 0.1
# zeta_gl:  -0.39  -0.08   0.00
# xs:      3.627e-03     -1.276e-01     -3.331e-05
#
# WARNING: increase arrays: counter_t = 504
# --- Shift to another chart, t = 20.063 ---
# radius: 0.1
# zeta_gl:  -0.36  -0.18   0.00
# xs:      3.064e-02     -9.784e-02      1.008e-04
#
# WARNING: increase arrays: counter_t = 510
# --- Shift to another chart, t = 20.308 ---
# radius: 0.1
# zeta_gl:  -0.30  -0.27   0.00
# xs:      5.406e-02     -9.209e-02      2.244e-04
#
# WARNING: increase arrays: counter_t = 516
# --- Shift to another chart, t = 20.554 ---
# radius: 0.1
# zeta_gl:  -0.23  -0.35   0.00
# xs:      7.530e-02     -8.040e-02      3.799e-04
#
# WARNING: increase arrays: counter_t = 522
# --- Shift to another chart, t = 20.800 ---
# radius: 0.1
# zeta_gl:  -0.13  -0.41   0.00
# xs:      9.293e-02     -6.320e-02      5.942e-04
#
# WARNING: increase arrays: counter_t = 528
# --- Shift to another chart, t = 21.046 ---
# radius: 0.1
# zeta_gl:  -0.03  -0.45   0.01
# xs:      1.057e-01     -4.127e-02      9.129e-04
#
# WARNING: increase arrays: counter_t = 534
# --- Shift to another chart, t = 21.291 ---
# radius: 0.1
# zeta_gl:   0.09  -0.47   0.01
# xs:      1.125e-01     -1.576e-02      1.419e-03
#
# WARNING: increase arrays: counter_t = 540
# --- Shift to another chart, t = 21.537 ---
# radius: 0.1
# zeta_gl:   0.20  -0.46   0.01
# xs:      1.125e-01      1.192e-02      2.273e-03
#
# WARNING: increase arrays: counter_t = 546
# --- Shift to another chart, t = 21.783 ---
# radius: 0.1
# zeta_gl:   0.30  -0.42   0.01
# xs:      1.054e-01      4.012e-02      3.789e-03
#
# WARNING: increase arrays: counter_t = 552
# --- Shift to another chart, t = 22.028 ---
# radius: 0.1
# zeta_gl:   0.39  -0.35   0.02
# xs:      9.093e-02      6.703e-02      6.581e-03
#
# WARNING: increase arrays: counter_t = 558
# --- Shift to another chart, t = 22.274 ---
# radius: 0.1
# zeta_gl:   0.46  -0.26   0.03
# xs:      6.928e-02      9.075e-02      1.173e-02
#
# WARNING: increase arrays: counter_t = 564
# --- Shift to another chart, t = 22.520 ---
# radius: 0.1
# zeta_gl:   0.50  -0.15   0.05
# xs:      4.069e-02      1.093e-01      2.058e-02
#
# WARNING: increase arrays: counter_t = 570
# --- Shift to another chart, t = 22.766 ---
# radius: 0.1
# zeta_gl:   0.51  -0.03   0.08
# xs:      5.738e-03      1.208e-01      3.257e-02
#
# WARNING: increase arrays: counter_t = 576
# --- Shift to another chart, t = 23.011 ---
# radius: 0.1
# zeta_gl:   0.48   0.09   0.12
# xs:     -3.358e-02      1.235e-01      3.928e-02
#
# WARNING: increase arrays: counter_t = 582
# --- Shift to another chart, t = 23.257 ---
# radius: 0.1
# zeta_gl:   0.40   0.21   0.15
# xs:     -7.152e-02      1.164e-01      2.274e-02
#
# WARNING: increase arrays: counter_t = 588
# --- Shift to another chart, t = 23.503 ---
# radius: 0.1
# zeta_gl:   0.31   0.31   0.13
# xs:     -9.903e-02      1.005e-01     -1.906e-02
#
# WARNING: increase arrays: counter_t = 594
# --- Shift to another chart, t = 23.748 ---
# radius: 0.1
# zeta_gl:   0.19   0.39   0.08
# xs:     -1.121e-01      7.877e-02     -4.936e-02
#
# WARNING: increase arrays: counter_t = 600
# --- Shift to another chart, t = 23.994 ---
# radius: 0.1
# zeta_gl:   0.08   0.44   0.04
# xs:     -1.164e-01      5.388e-02     -4.309e-02
#
# WARNING: increase arrays: counter_t = 606
# --- Shift to another chart, t = 24.240 ---
# radius: 0.1
# zeta_gl:  -0.04   0.47   0.01
# xs:     -1.185e-01      2.700e-02     -2.134e-02
#
# WARNING: increase arrays: counter_t = 612
# --- Shift to another chart, t = 24.485 ---
# radius: 0.1
# zeta_gl:  -0.16   0.47   0.01
# xs:     -1.183e-01     -1.532e-03     -7.133e-03
#
# WARNING: increase arrays: counter_t = 618
# --- Shift to another chart, t = 24.731 ---
# radius: 0.1
# zeta_gl:  -0.27   0.44   0.00
# xs:     -1.134e-01     -3.092e-02     -2.097e-03
#
# WARNING: increase arrays: counter_t = 624
# --- Shift to another chart, t = 24.977 ---
# radius: 0.1
# zeta_gl:  -0.37   0.38   0.00
# xs:     -1.019e-01     -5.973e-02     -8.164e-04
#
# WARNING: increase arrays: counter_t = 630
# --- Shift to another chart, t = 25.223 ---
# radius: 0.1
# zeta_gl:  -0.46   0.29   0.00
# xs:     -8.372e-02     -8.626e-02     -4.453e-04
#
# WARNING: increase arrays: counter_t = 636
# --- Shift to another chart, t = 25.468 ---
# radius: 0.1
# zeta_gl:  -0.52   0.18   0.00
# xs:     -5.958e-02     -1.088e-01     -2.622e-04
#
# WARNING: increase arrays: counter_t = 642
# --- Shift to another chart, t = 25.714 ---
# radius: 0.1
# zeta_gl:  -0.55   0.06   0.00
# xs:     -3.059e-02     -1.257e-01     -1.335e-04
#
# WARNING: increase arrays: counter_t = 648
# --- Shift to another chart, t = 25.960 ---
# radius: 0.1
# zeta_gl:  -0.55  -0.08   0.00
# xs:      1.716e-03     -1.358e-01     -2.528e-05
#
# WARNING: increase arrays: counter_t = 654
# --- Shift to another chart, t = 26.205 ---
# radius: 0.1
# zeta_gl:  -0.51  -0.22   0.00
# xs:      3.551e-02     -1.380e-01      8.091e-05
#
# WARNING: increase arrays: counter_t = 660
# --- Shift to another chart, t = 26.373 ---
# radius: 0.1
# zeta_gl:  -0.47  -0.31   0.00
# xs:      4.341e-02     -9.104e-02      1.228e-04
#
# WARNING: increase arrays: counter_t = 665
# --- Shift to another chart, t = 26.540 ---
# radius: 0.1
# zeta_gl:  -0.41  -0.39   0.00
# xs:      5.820e-02     -8.549e-02      1.887e-04
#
# WARNING: increase arrays: counter_t = 670
# --- Shift to another chart, t = 26.708 ---
# radius: 0.1
# zeta_gl:  -0.34  -0.47   0.00
# xs:      7.183e-02     -7.731e-02      2.710e-04
#
# WARNING: increase arrays: counter_t = 675
# --- Shift to another chart, t = 26.875 ---
# radius: 0.1
# zeta_gl:  -0.25  -0.54   0.00
# xs:      8.387e-02     -6.666e-02      3.795e-04
#
# WARNING: increase arrays: counter_t = 680
# --- Shift to another chart, t = 27.043 ---
# radius: 0.1
# zeta_gl:  -0.16  -0.59   0.00
# xs:      9.391e-02     -5.377e-02      5.293e-04
#
# WARNING: increase arrays: counter_t = 685
# --- Shift to another chart, t = 27.210 ---
# radius: 0.1
# zeta_gl:  -0.06  -0.63   0.01
# xs:      1.016e-01     -3.891e-02      7.463e-04
#
# WARNING: increase arrays: counter_t = 690
# --- Shift to another chart, t = 27.378 ---
# radius: 0.1
# zeta_gl:   0.05  -0.65   0.01
# xs:      1.066e-01     -2.247e-02      1.076e-03
#
# WARNING: increase arrays: counter_t = 695
# --- Shift to another chart, t = 27.545 ---
# radius: 0.1
# zeta_gl:   0.16  -0.66   0.01
# xs:      1.087e-01     -4.858e-03      1.602e-03
#
# WARNING: increase arrays: counter_t = 700
# --- Shift to another chart, t = 27.713 ---
# radius: 0.1
# zeta_gl:   0.26  -0.64   0.01
# xs:      1.076e-01      1.345e-02      2.490e-03
#
# WARNING: increase arrays: counter_t = 705
# --- Shift to another chart, t = 27.880 ---
# radius: 0.1
# zeta_gl:   0.37  -0.61   0.01
# xs:      1.033e-01      3.192e-02      4.077e-03
#
# WARNING: increase arrays: counter_t = 710
# --- Shift to another chart, t = 28.048 ---
# radius: 0.1
# zeta_gl:   0.46  -0.56   0.02
# xs:      9.552e-02      4.999e-02      7.089e-03
#
# WARNING: increase arrays: counter_t = 715
# --- Shift to another chart, t = 28.215 ---
# radius: 0.1
# zeta_gl:   0.55  -0.49   0.03
# xs:      8.406e-02      6.705e-02      1.314e-02
#
# WARNING: increase arrays: counter_t = 720
# --- Shift to another chart, t = 28.383 ---
# radius: 0.1
# zeta_gl:   0.62  -0.41   0.06
# xs:      6.839e-02      8.239e-02      2.585e-02
#
# WARNING: increase arrays: counter_t = 725
# --- Shift to another chart, t = 28.550 ---
# radius: 0.1
# zeta_gl:   0.66  -0.32   0.11
# xs:      4.716e-02      9.515e-02      5.291e-02
#
# WARNING: increase arrays: counter_t = 730
# --- Shift to another chart, t = 28.718 ---
# radius: 0.2
# zeta_gl:   0.68  -0.21   0.22
# xs:      1.746e-02      1.041e-01      1.075e-01
#
# WARNING: increase arrays: counter_t = 735
# --- Shift to another chart, t = 28.807 ---
# radius: 0.1
# zeta_gl:   0.67  -0.16   0.31
# xs:     -7.206e-03      5.722e-02      9.257e-02
#
# WARNING: increase arrays: counter_t = 739
# --- Shift to another chart, t = 28.897 ---
# radius: 0.1
# zeta_gl:   0.65  -0.10   0.44
# xs:     -2.187e-02      5.696e-02      1.214e-01
#
# WARNING: increase arrays: counter_t = 743
# --- Shift to another chart, t = 28.986 ---
# radius: 0.2
# zeta_gl:   0.61  -0.04   0.58
# xs:     -3.884e-02      5.527e-02      1.439e-01
#
# WARNING: increase arrays: counter_t = 747
# --- Shift to another chart, t = 29.072 ---
# radius: 0.2
# zeta_gl:   0.56   0.01   0.72
# xs:     -5.440e-02      5.017e-02      1.395e-01
#
# WARNING: increase arrays: counter_t = 751
# --- Shift to another chart, t = 29.157 ---
# radius: 0.1
# zeta_gl:   0.49   0.05   0.82
# xs:     -6.813e-02      4.493e-02      1.050e-01
#
# WARNING: increase arrays: counter_t = 755
# --- Shift to another chart, t = 29.315 ---
# radius: 0.2
# zeta_gl:   0.34   0.12   0.83
# xs:     -1.489e-01      6.884e-02      5.530e-03
#
# WARNING: increase arrays: counter_t = 760
# --- Shift to another chart, t = 29.396 ---
# radius: 0.1
# zeta_gl:   0.27   0.15   0.73
# xs:     -7.389e-02      2.657e-02     -9.890e-02
#
# WARNING: increase arrays: counter_t = 764
# --- Shift to another chart, t = 29.478 ---
# radius: 0.2
# zeta_gl:   0.20   0.17   0.59
# xs:     -6.775e-02      2.180e-02     -1.408e-01
#
# WARNING: increase arrays: counter_t = 768
# --- Shift to another chart, t = 29.560 ---
# radius: 0.2
# zeta_gl:   0.14   0.19   0.44
# xs:     -5.678e-02      1.682e-02     -1.459e-01
#
# WARNING: increase arrays: counter_t = 772
# --- Shift to another chart, t = 29.648 ---
# radius: 0.1
# zeta_gl:   0.09   0.20   0.31
# xs:     -4.968e-02      1.364e-02     -1.371e-01
#
# WARNING: increase arrays: counter_t = 776
# --- Shift to another chart, t = 29.737 ---
# radius: 0.1
# zeta_gl:   0.05   0.21   0.20
# xs:     -4.061e-02      1.005e-02     -1.068e-01
#
# WARNING: increase arrays: counter_t = 780
# --- Shift to another chart, t = 29.905 ---
# radius: 0.1
# zeta_gl:  -0.01   0.22   0.08
# xs:     -5.834e-02      1.081e-02     -1.182e-01
#
# WARNING: increase arrays: counter_t = 785
# --- Shift to another chart, t = 30.229 ---
# radius: 0.1
# zeta_gl:  -0.09   0.22   0.01
# xs:     -8.401e-02     -1.860e-03     -6.681e-02
#
# WARNING: increase arrays: counter_t = 792
# --- Shift to another chart, t = 30.709 ---
# radius: 0.1
# zeta_gl:  -0.19   0.17   0.01
# xs:     -9.886e-02     -4.918e-02     -9.412e-03
#
# WARNING: increase arrays: counter_t = 801
# --- Shift to another chart, t = 31.189 ---
# radius: 0.1
# zeta_gl:  -0.25   0.07   0.00
# xs:     -6.209e-02     -9.565e-02     -7.434e-04
#
# WARNING: increase arrays: counter_t = 810
# --- Shift to another chart, t = 31.592 ---
# radius: 0.1
# zeta_gl:  -0.26  -0.03   0.00
# xs:     -1.105e-02     -1.028e-01     -1.442e-04
#
# WARNING: increase arrays: counter_t = 818
# --- Shift to another chart, t = 31.994 ---
# radius: 0.1
# zeta_gl:  -0.23  -0.14   0.00
# xs:      3.174e-02     -1.072e-01      1.332e-04
#
# WARNING: increase arrays: counter_t = 826
# --- Shift to another chart, t = 32.396 ---
# radius: 0.1
# zeta_gl:  -0.16  -0.23   0.00
# xs:      7.272e-02     -9.426e-02      4.485e-04
#
# WARNING: increase arrays: counter_t = 834
# --- Shift to another chart, t = 32.798 ---
# radius: 0.1
# zeta_gl:  -0.05  -0.30   0.01
# xs:      1.049e-01     -6.463e-02      8.855e-04
#
# WARNING: increase arrays: counter_t = 842
# --- Shift to another chart, t = 33.122 ---
# radius: 0.1
# zeta_gl:   0.05  -0.32   0.01
# xs:      9.794e-02     -2.144e-02      1.198e-03
#
# WARNING: increase arrays: counter_t = 849
# --- Shift to another chart, t = 33.524 ---
# radius: 0.1
# zeta_gl:   0.17  -0.30   0.01
# xs:      1.223e-01      1.787e-02      2.463e-03
#
# WARNING: increase arrays: counter_t = 857
# --- Shift to another chart, t = 33.926 ---
# radius: 0.1
# zeta_gl:   0.27  -0.23   0.01
# xs:      1.037e-01      6.745e-02      4.188e-03
#
# WARNING: increase arrays: counter_t = 865
# --- Shift to another chart, t = 34.250 ---
# radius: 0.1
# zeta_gl:   0.33  -0.15   0.02
# xs:      5.664e-02      8.539e-02      5.046e-03
#
# WARNING: increase arrays: counter_t = 872
# --- Shift to another chart, t = 34.574 ---
# radius: 0.1
# zeta_gl:   0.35  -0.04   0.02
# xs:      2.375e-02      1.048e-01      6.070e-03
#
# WARNING: increase arrays: counter_t = 879
# --- Shift to another chart, t = 34.898 ---
# radius: 0.1
# zeta_gl:   0.34   0.07   0.03
# xs:     -1.378e-02      1.136e-01      4.687e-03
#
# WARNING: increase arrays: counter_t = 886
# --- Shift to another chart, t = 35.222 ---
# radius: 0.1
# zeta_gl:   0.29   0.18   0.03
# xs:     -5.114e-02      1.103e-01     -5.573e-04
#
# WARNING: increase arrays: counter_t = 893
# --- Shift to another chart, t = 35.546 ---
# radius: 0.1
# zeta_gl:   0.20   0.28   0.02
# xs:     -8.348e-02      9.507e-02     -6.721e-03
#
# WARNING: increase arrays: counter_t = 900
# --- Shift to another chart, t = 35.869 ---
# radius: 0.1
# zeta_gl:   0.10   0.35   0.01
# xs:     -1.078e-01      6.923e-02     -8.285e-03
#
# WARNING: increase arrays: counter_t = 907
# --- Shift to another chart, t = 36.193 ---
# radius: 0.1
# zeta_gl:  -0.03   0.38   0.01
# xs:     -1.226e-01      3.507e-02     -5.470e-03
#
# WARNING: increase arrays: counter_t = 914
# --- Shift to another chart, t = 36.517 ---
# radius: 0.1
# zeta_gl:  -0.15   0.38   0.01
# xs:     -1.263e-01     -4.547e-03     -2.624e-03
#
# WARNING: increase arrays: counter_t = 921
# --- Shift to another chart, t = 36.841 ---
# radius: 0.1
# zeta_gl:  -0.27   0.33   0.00
# xs:     -1.175e-01     -4.603e-02     -1.244e-03
#
# WARNING: increase arrays: counter_t = 928
# --- Shift to another chart, t = 37.165 ---
# radius: 0.1
# zeta_gl:  -0.37   0.25   0.00
# xs:     -9.587e-02     -8.521e-02     -6.580e-04
#
# WARNING: increase arrays: counter_t = 935
# --- Shift to another chart, t = 37.411 ---
# radius: 0.1
# zeta_gl:  -0.42   0.16   0.00
# xs:     -5.107e-02     -8.686e-02     -2.841e-04
#
# WARNING: increase arrays: counter_t = 941
# --- Shift to another chart, t = 37.656 ---
# radius: 0.1
# zeta_gl:  -0.45   0.06   0.00
# xs:     -2.780e-02     -1.013e-01     -1.528e-04
#
# WARNING: increase arrays: counter_t = 947
# --- Shift to another chart, t = 37.902 ---
# radius: 0.1
# zeta_gl:  -0.45  -0.05   0.00
# xs:     -1.679e-03     -1.102e-01     -4.153e-05
#
# WARNING: increase arrays: counter_t = 953
# --- Shift to another chart, t = 38.148 ---
# radius: 0.1
# zeta_gl:  -0.42  -0.16   0.00
# xs:      2.583e-02     -1.127e-01      6.586e-05
#
# WARNING: increase arrays: counter_t = 959
# --- Shift to another chart, t = 38.394 ---
# radius: 0.1
# zeta_gl:  -0.37  -0.27   0.00
# xs:      5.311e-02     -1.084e-01      1.841e-04
#
# WARNING: increase arrays: counter_t = 965
# --- Shift to another chart, t = 38.639 ---
# radius: 0.1
# zeta_gl:  -0.29  -0.37   0.00
# xs:      7.846e-02     -9.730e-02      3.312e-04
#
# WARNING: increase arrays: counter_t = 971
# --- Shift to another chart, t = 38.885 ---
# radius: 0.1
# zeta_gl:  -0.19  -0.45   0.00
# xs:      1.002e-01     -7.963e-02      5.345e-04
#
# WARNING: increase arrays: counter_t = 977
# --- Shift to another chart, t = 39.131 ---
# radius: 0.1
# zeta_gl:  -0.07  -0.51   0.01
# xs:      1.169e-01     -5.621e-02      8.420e-04
#
# WARNING: increase arrays: counter_t = 983
# --- Shift to another chart, t = 39.376 ---
# radius: 0.1
# zeta_gl:   0.05  -0.53   0.01
# xs:      1.270e-01     -2.819e-02      1.347e-03
#
# WARNING: increase arrays: counter_t = 989
# --- Shift to another chart, t = 39.622 ---
# radius: 0.1
# zeta_gl:   0.18  -0.53   0.01
# xs:      1.298e-01      2.889e-03      2.243e-03
#
# WARNING: increase arrays: counter_t = 995
# --- Shift to another chart, t = 39.868 ---
# radius: 0.1
# zeta_gl:   0.31  -0.50   0.01
# xs:      1.243e-01      3.521e-02      3.961e-03
#
# WARNING: increase arrays: counter_t = 1001
# --- Shift to another chart, t = 40.114 ---
# radius: 0.1
# zeta_gl:   0.42  -0.43   0.02
# xs:      1.104e-01      6.675e-02      7.508e-03
#
# WARNING: increase arrays: counter_t = 1007
# --- Shift to another chart, t = 40.359 ---
# radius: 0.1
# zeta_gl:   0.51  -0.33   0.04
# xs:      8.777e-02      9.527e-02      1.522e-02
#
# WARNING: increase arrays: counter_t = 1013
# --- Shift to another chart, t = 40.605 ---
# radius: 0.1
# zeta_gl:   0.56  -0.22   0.07
# xs:      5.585e-02      1.184e-01      3.191e-02
#
# WARNING: increase arrays: counter_t = 1019
# --- Shift to another chart, t = 40.851 ---
# radius: 0.1
# zeta_gl:   0.58  -0.08   0.13
# xs:      1.333e-02      1.334e-01      6.348e-02
#
# WARNING: increase arrays: counter_t = 1025
# --- Shift to another chart, t = 41.018 ---
# radius: 0.1
# zeta_gl:   0.55   0.01   0.20
# xs:     -2.123e-02      9.378e-02      6.563e-02
#
# WARNING: increase arrays: counter_t = 1030
# --- Shift to another chart, t = 41.186 ---
# radius: 0.1
# zeta_gl:   0.51   0.10   0.27
# xs:     -4.855e-02      9.105e-02      7.114e-02
#
# WARNING: increase arrays: counter_t = 1035
# --- Shift to another chart, t = 41.353 ---
# radius: 0.1
# zeta_gl:   0.43   0.19   0.31
# xs:     -7.348e-02      8.369e-02      4.461e-02
#
# WARNING: increase arrays: counter_t = 1040
# --- Shift to another chart, t = 41.521 ---
# radius: 0.1
# zeta_gl:   0.34   0.26   0.30
# xs:     -8.944e-02      7.251e-02     -1.406e-02
#
# WARNING: increase arrays: counter_t = 1045
# --- Shift to another chart, t = 41.688 ---
# radius: 0.1
# zeta_gl:   0.25   0.32   0.23
# xs:     -9.313e-02      5.927e-02     -6.938e-02
#
# WARNING: increase arrays: counter_t = 1050
# --- Shift to another chart, t = 41.856 ---
# radius: 0.1
# zeta_gl:   0.16   0.36   0.14
# xs:     -8.828e-02      4.576e-02     -8.619e-02
#
# WARNING: increase arrays: counter_t = 1055
# --- Shift to another chart, t = 42.023 ---
# radius: 0.1
# zeta_gl:   0.08   0.40   0.07
# xs:     -8.162e-02      3.286e-02     -6.803e-02
#
# WARNING: increase arrays: counter_t = 1060
# --- Shift to another chart, t = 42.269 ---
# radius: 0.1
# zeta_gl:  -0.03   0.42   0.02
# xs:     -1.121e-01      2.590e-02     -5.077e-02
#
# WARNING: increase arrays: counter_t = 1066
# --- Shift to another chart, t = 42.515 ---
# radius: 0.1
# zeta_gl:  -0.14   0.42   0.01
# xs:     -1.078e-01     -4.464e-04     -1.524e-02
#
# WARNING: increase arrays: counter_t = 1072
# --- Shift to another chart, t = 42.760 ---
# radius: 0.1
# zeta_gl:  -0.24   0.39   0.01
# xs:     -1.024e-01     -2.702e-02     -3.576e-03
#
# WARNING: increase arrays: counter_t = 1078
# --- Shift to another chart, t = 43.006 ---
# radius: 0.1
# zeta_gl:  -0.33   0.34   0.00
# xs:     -9.208e-02     -5.301e-02     -1.005e-03
#
# WARNING: increase arrays: counter_t = 1084
# --- Shift to another chart, t = 43.252 ---
# radius: 0.1
# zeta_gl:  -0.41   0.26   0.00
# xs:     -7.589e-02     -7.697e-02     -4.691e-04
#
# WARNING: increase arrays: counter_t = 1090
# --- Shift to another chart, t = 43.497 ---
# radius: 0.1
# zeta_gl:  -0.46   0.17   0.00
# xs:     -5.430e-02     -9.736e-02     -2.712e-04
#
# WARNING: increase arrays: counter_t = 1096
# --- Shift to another chart, t = 43.743 ---
# radius: 0.1
# zeta_gl:  -0.49   0.05   0.00
# xs:     -2.832e-02     -1.128e-01     -1.404e-04
#
# WARNING: increase arrays: counter_t = 1102
# --- Shift to another chart, t = 43.989 ---
# radius: 0.1
# zeta_gl:  -0.49  -0.07   0.00
# xs:      6.851e-04     -1.220e-01     -3.051e-05
#
# WARNING: increase arrays: counter_t = 1108
# --- Shift to another chart, t = 44.234 ---
# radius: 0.1
# zeta_gl:  -0.46  -0.19   0.00
# xs:      3.108e-02     -1.242e-01      7.667e-05
#
# WARNING: increase arrays: counter_t = 1114
# --- Shift to another chart, t = 44.480 ---
# radius: 0.1
# zeta_gl:  -0.40  -0.31   0.00
# xs:      6.106e-02     -1.189e-01      1.970e-04
#
# WARNING: increase arrays: counter_t = 1120
# --- Shift to another chart, t = 44.726 ---
# radius: 0.1
# zeta_gl:  -0.31  -0.42   0.00
# xs:      8.877e-02     -1.059e-01      3.507e-04
#
# WARNING: increase arrays: counter_t = 1126
# --- Shift to another chart, t = 44.972 ---
# radius: 0.1
# zeta_gl:  -0.20  -0.50   0.00
# xs:      1.124e-01     -8.587e-02      5.700e-04
#
# WARNING: increase arrays: counter_t = 1132
# --- Shift to another chart, t = 45.217 ---
# radius: 0.1
# zeta_gl:  -0.07  -0.56   0.01
# xs:      1.302e-01     -5.954e-02      9.147e-04
#
# WARNING: increase arrays: counter_t = 1138
# --- Shift to another chart, t = 45.463 ---
# radius: 0.1
# zeta_gl:   0.07  -0.59   0.01
# xs:      1.407e-01     -2.827e-02      1.508e-03
#
# WARNING: increase arrays: counter_t = 1144
# --- Shift to another chart, t = 45.709 ---
# radius: 0.1
# zeta_gl:   0.21  -0.58   0.01
# xs:      1.430e-01      6.215e-03      2.630e-03
#
# WARNING: increase arrays: counter_t = 1150
# --- Shift to another chart, t = 45.954 ---
# radius: 0.1
# zeta_gl:   0.35  -0.54   0.01
# xs:      1.362e-01      4.189e-02      4.964e-03
#
# WARNING: increase arrays: counter_t = 1156
# --- Shift to another chart, t = 46.200 ---
# radius: 0.1
# zeta_gl:   0.47  -0.47   0.02
# xs:      1.198e-01      7.646e-02      1.032e-02
#
# WARNING: increase arrays: counter_t = 1162
# --- Shift to another chart, t = 46.446 ---
# radius: 0.1
# zeta_gl:   0.56  -0.36   0.05
# xs:      9.322e-02      1.074e-01      2.360e-02
#
# WARNING: increase arrays: counter_t = 1168
# --- Shift to another chart, t = 46.613 ---
# radius: 0.1
# zeta_gl:   0.61  -0.27   0.08
# xs:      4.220e-02      8.771e-02      3.318e-02
#
# WARNING: increase arrays: counter_t = 1173
# --- Shift to another chart, t = 46.781 ---
# radius: 0.1
# zeta_gl:   0.63  -0.17   0.14
# xs:      1.916e-02      9.602e-02      5.991e-02
#
# WARNING: increase arrays: counter_t = 1178
# --- Shift to another chart, t = 46.948 ---
# radius: 0.1
# zeta_gl:   0.61  -0.07   0.24
# xs:     -1.058e-02      1.001e-01      1.001e-01
#
# WARNING: increase arrays: counter_t = 1183
# --- Shift to another chart, t = 47.116 ---
# radius: 0.2
# zeta_gl:   0.57   0.02   0.38
# xs:     -4.753e-02      9.870e-02      1.377e-01
#
# WARNING: increase arrays: counter_t = 1188
# --- Shift to another chart, t = 47.283 ---
# radius: 0.2
# zeta_gl:   0.48   0.11   0.50
# xs:     -8.651e-02      9.062e-02      1.233e-01
#
# WARNING: increase arrays: counter_t = 1193
# --- Shift to another chart, t = 47.451 ---
# radius: 0.1
# zeta_gl:   0.37   0.19   0.52
# xs:     -1.135e-01      7.640e-02      1.731e-02
#
# WARNING: increase arrays: counter_t = 1198
# --- Shift to another chart, t = 47.618 ---
# radius: 0.2
# zeta_gl:   0.25   0.25   0.41
# xs:     -1.162e-01      5.908e-02     -1.136e-01
#
# WARNING: increase arrays: counter_t = 1203
# --- Shift to another chart, t = 47.708 ---
# radius: 0.1
# zeta_gl:   0.19   0.28   0.32
# xs:     -5.594e-02      2.457e-02     -8.648e-02
#
# WARNING: increase arrays: counter_t = 1207
# --- Shift to another chart, t = 47.875 ---
# radius: 0.2
# zeta_gl:   0.11   0.31   0.17
# xs:     -8.979e-02      3.471e-02     -1.472e-01
#
# WARNING: increase arrays: counter_t = 1212
# --- Shift to another chart, t = 48.043 ---
# radius: 0.1
# zeta_gl:   0.03   0.33   0.08
# xs:     -7.415e-02      2.202e-02     -9.359e-02
#
# WARNING: increase arrays: counter_t = 1217
# --- Shift to another chart, t = 48.288 ---
# radius: 0.1
# zeta_gl:  -0.06   0.34   0.02
# xs:     -9.449e-02      1.250e-02     -5.677e-02
#
# WARNING: increase arrays: counter_t = 1223
# --- Shift to another chart, t = 48.612 ---
# radius: 0.1
# zeta_gl:  -0.18   0.33   0.01
# xs:     -1.136e-01     -1.728e-02     -1.554e-02
#
# WARNING: increase arrays: counter_t = 1230
# --- Shift to another chart, t = 48.936 ---
# radius: 0.1
# zeta_gl:  -0.28   0.27   0.00
# xs:     -9.976e-02     -5.438e-02     -2.102e-03
#
# WARNING: increase arrays: counter_t = 1237
# --- Shift to another chart, t = 49.260 ---
# radius: 0.1
# zeta_gl:  -0.35   0.18   0.00
# xs:     -7.624e-02     -8.779e-02     -5.802e-04
#
# WARNING: increase arrays: counter_t = 1244
# --- Shift to another chart, t = 49.584 ---
# radius: 0.1
# zeta_gl:  -0.40   0.07   0.00
# xs:     -4.319e-02     -1.139e-01     -2.649e-04
#
# WARNING: increase arrays: counter_t = 1251
# --- Shift to another chart, t = 49.908 ---
# radius: 0.1
# zeta_gl:  -0.40  -0.06   0.00
# xs:     -3.378e-03     -1.296e-01     -6.408e-05
#
# WARNING: increase arrays: counter_t = 1258
# --- Shift to another chart, t = 50.154 ---
# radius: 0.1
# zeta_gl:  -0.37  -0.16   0.00
# xs:      2.597e-02     -1.009e-01      7.645e-05
#
# WARNING: increase arrays: counter_t = 1264
# --- Shift to another chart, t = 50.399 ---
# radius: 0.1
# zeta_gl:  -0.32  -0.26   0.00
# xs:      5.029e-02     -9.635e-02      1.958e-04
#
# WARNING: increase arrays: counter_t = 1270
# --- Shift to another chart, t = 50.645 ---
# radius: 0.1
# zeta_gl:  -0.25  -0.34   0.00
# xs:      7.271e-02     -8.568e-02      3.435e-04
#
# WARNING: increase arrays: counter_t = 1276
# --- Shift to another chart, t = 50.891 ---
# radius: 0.1
# zeta_gl:  -0.16  -0.41   0.00
# xs:      9.175e-02     -6.922e-02      5.444e-04
#
# WARNING: increase arrays: counter_t = 1282
# --- Shift to another chart, t = 51.136 ---
# radius: 0.1
# zeta_gl:  -0.05  -0.46   0.01
# xs:      1.060e-01     -4.770e-02      8.408e-04
#
# WARNING: increase arrays: counter_t = 1288
# --- Shift to another chart, t = 51.382 ---
# radius: 0.1
# zeta_gl:   0.06  -0.48   0.01
# xs:      1.144e-01     -2.222e-02      1.310e-03
#
# WARNING: increase arrays: counter_t = 1294
# --- Shift to another chart, t = 51.628 ---
# radius: 0.1
# zeta_gl:   0.18  -0.47   0.01
# xs:      1.161e-01      5.835e-03      2.102e-03
#
# WARNING: increase arrays: counter_t = 1300
# --- Shift to another chart, t = 51.874 ---
# radius: 0.1
# zeta_gl:   0.29  -0.44   0.01
# xs:      1.104e-01      3.481e-02      3.518e-03
#
# WARNING: increase arrays: counter_t = 1306
# --- Shift to another chart, t = 52.119 ---
# radius: 0.1
# zeta_gl:   0.39  -0.38   0.02
# xs:      9.721e-02      6.288e-02      6.172e-03
#
# WARNING: increase arrays: counter_t = 1312
# --- Shift to another chart, t = 52.365 ---
# radius: 0.1
# zeta_gl:   0.46  -0.29   0.03
# xs:      7.651e-02      8.810e-02      1.124e-02
#
# WARNING: increase arrays: counter_t = 1318
# --- Shift to another chart, t = 52.611 ---
# radius: 0.1
# zeta_gl:   0.51  -0.18   0.05
# xs:      4.845e-02      1.085e-01      2.050e-02
#
# WARNING: increase arrays: counter_t = 1324
# --- Shift to another chart, t = 52.856 ---
# radius: 0.1
# zeta_gl:   0.52  -0.06   0.09
# xs:      1.329e-02      1.219e-01      3.467e-02
#
# WARNING: increase arrays: counter_t = 1330
# --- Shift to another chart, t = 53.102 ---
# radius: 0.1
# zeta_gl:   0.50   0.07   0.13
# xs:     -2.762e-02      1.263e-01      4.677e-02
#
# WARNING: increase arrays: counter_t = 1336
# --- Shift to another chart, t = 53.348 ---
# radius: 0.1
# zeta_gl:   0.43   0.19   0.17
# xs:     -6.899e-02      1.205e-01      3.532e-02
#
# WARNING: increase arrays: counter_t = 1342
# --- Shift to another chart, t = 53.593 ---
# radius: 0.1
# zeta_gl:   0.33   0.29   0.16
# xs:     -1.003e-01      1.049e-01     -1.171e-02
#
# WARNING: increase arrays: counter_t = 1348
# --- Shift to another chart, t = 53.761 ---
# radius: 0.1
# zeta_gl:   0.25   0.35   0.12
# xs:     -7.745e-02      5.912e-02     -3.549e-02
#
# WARNING: increase arrays: counter_t = 1353
# --- Shift to another chart, t = 53.928 ---
# radius: 0.1
# zeta_gl:   0.17   0.40   0.08
# xs:     -7.970e-02      4.771e-02     -4.178e-02
#
# WARNING: increase arrays: counter_t = 1358
# --- Shift to another chart, t = 54.174 ---
# radius: 0.1
# zeta_gl:   0.05   0.45   0.03
# xs:     -1.177e-01      4.813e-02     -4.564e-02
#
# WARNING: increase arrays: counter_t = 1364
# --- Shift to another chart, t = 54.420 ---
# radius: 0.1
# zeta_gl:  -0.07   0.47   0.01
# xs:     -1.183e-01      2.083e-02     -2.014e-02
#
# WARNING: increase arrays: counter_t = 1370
# --- Shift to another chart, t = 54.666 ---
# radius: 0.1
# zeta_gl:  -0.18   0.46   0.01
# xs:     -1.169e-01     -7.816e-03     -6.152e-03
#
# WARNING: increase arrays: counter_t = 1376
# --- Shift to another chart, t = 54.911 ---
# radius: 0.1
# zeta_gl:  -0.29   0.42   0.00
# xs:     -1.106e-01     -3.700e-02     -1.758e-03
#
# WARNING: increase arrays: counter_t = 1382
# --- Shift to another chart, t = 55.157 ---
# radius: 0.1
# zeta_gl:  -0.39   0.36   0.00
# xs:     -9.771e-02     -6.524e-02     -7.127e-04
#
# WARNING: increase arrays: counter_t = 1388
# --- Shift to another chart, t = 55.403 ---
# radius: 0.1
# zeta_gl:  -0.47   0.27   0.00
# xs:     -7.833e-02     -9.085e-02     -3.985e-04
#
# WARNING: increase arrays: counter_t = 1394
# --- Shift to another chart, t = 55.648 ---
# radius: 0.1
# zeta_gl:  -0.52   0.16   0.00
# xs:     -5.322e-02     -1.121e-01     -2.316e-04
#
# WARNING: increase arrays: counter_t = 1400
# --- Shift to another chart, t = 55.894 ---
# radius: 0.1
# zeta_gl:  -0.55   0.03   0.00
# xs:     -2.360e-02     -1.276e-01     -1.092e-04
#
# WARNING: increase arrays: counter_t = 1406
# --- Shift to another chart, t = 56.140 ---
# radius: 0.1
# zeta_gl:  -0.54  -0.11   0.00
# xs:      8.935e-03     -1.359e-01     -2.708e-06
#
# WARNING: increase arrays: counter_t = 1412
# --- Shift to another chart, t = 56.385 ---
# radius: 0.1
# zeta_gl:  -0.50  -0.24   0.00
# xs:      4.253e-02     -1.363e-01      1.053e-04
#
# WARNING: increase arrays: counter_t = 1418
# --- Shift to another chart, t = 56.553 ---
# radius: 0.1
# zeta_gl:  -0.45  -0.33   0.00
# xs:      4.785e-02     -8.886e-02      1.424e-04
#
# WARNING: increase arrays: counter_t = 1423
# --- Shift to another chart, t = 56.720 ---
# radius: 0.1
# zeta_gl:  -0.39  -0.42   0.00
# xs:      6.221e-02     -8.251e-02      2.127e-04
#
# WARNING: increase arrays: counter_t = 1428
# --- Shift to another chart, t = 56.888 ---
# radius: 0.1
# zeta_gl:  -0.31  -0.49   0.00
# xs:      7.528e-02     -7.360e-02      3.019e-04
#
# WARNING: increase arrays: counter_t = 1433
# --- Shift to another chart, t = 57.055 ---
# radius: 0.1
# zeta_gl:  -0.22  -0.55   0.00
# xs:      8.663e-02     -6.229e-02      4.211e-04
#
# WARNING: increase arrays: counter_t = 1438
# --- Shift to another chart, t = 57.223 ---
# radius: 0.1
# zeta_gl:  -0.13  -0.60   0.00
# xs:      9.588e-02     -4.884e-02      5.880e-04
#
# WARNING: increase arrays: counter_t = 1443
# --- Shift to another chart, t = 57.390 ---
# radius: 0.1
# zeta_gl:  -0.02  -0.63   0.01
# xs:      1.027e-01     -3.356e-02      8.328e-04
#
# WARNING: increase arrays: counter_t = 1448
# --- Shift to another chart, t = 57.558 ---
# radius: 0.1
# zeta_gl:   0.08  -0.65   0.01
# xs:      1.068e-01     -1.683e-02      1.209e-03
#
# WARNING: increase arrays: counter_t = 1453
# --- Shift to another chart, t = 57.725 ---
# radius: 0.1
# zeta_gl:   0.19  -0.65   0.01
# xs:      1.078e-01      9.207e-04      1.819e-03
#
# WARNING: increase arrays: counter_t = 1458
# --- Shift to another chart, t = 57.893 ---
# radius: 0.1
# zeta_gl:   0.30  -0.63   0.01
# xs:      1.058e-01      1.919e-02      2.862e-03
#
# WARNING: increase arrays: counter_t = 1463
# --- Shift to another chart, t = 58.061 ---
# radius: 0.1
# zeta_gl:   0.40  -0.59   0.02
# xs:      1.004e-01      3.746e-02      4.752e-03
#
# WARNING: increase arrays: counter_t = 1468
# --- Shift to another chart, t = 58.228 ---
# radius: 0.1
# zeta_gl:   0.49  -0.54   0.02
# xs:      9.158e-02      5.514e-02      8.384e-03
#
# WARNING: increase arrays: counter_t = 1473
# --- Shift to another chart, t = 58.396 ---
# radius: 0.1
# zeta_gl:   0.57  -0.47   0.04
# xs:      7.900e-02      7.161e-02      1.574e-02
#
# WARNING: increase arrays: counter_t = 1478
# --- Shift to another chart, t = 58.563 ---
# radius: 0.1
# zeta_gl:   0.63  -0.38   0.07
# xs:      6.198e-02      8.614e-02      3.120e-02
#
# WARNING: increase arrays: counter_t = 1483
# --- Shift to another chart, t = 58.731 ---
# radius: 0.1
# zeta_gl:   0.67  -0.28   0.14
# xs:      3.891e-02      9.778e-02      6.359e-02
#
# WARNING: increase arrays: counter_t = 1488
# --- Shift to another chart, t = 58.898 ---
# radius: 0.2
# zeta_gl:   0.67  -0.18   0.26
# xs:      6.473e-03      1.052e-01      1.259e-01
#
# WARNING: increase arrays: counter_t = 1493
# --- Shift to another chart, t = 58.987 ---
# radius: 0.1
# zeta_gl:   0.66  -0.12   0.36
# xs:     -1.448e-02      5.698e-02      1.039e-01
#
# WARNING: increase arrays: counter_t = 1497
# --- Shift to another chart, t = 59.077 ---
# radius: 0.1
# zeta_gl:   0.63  -0.06   0.49
# xs:     -2.999e-02      5.602e-02      1.293e-01
#
# WARNING: increase arrays: counter_t = 1501
# --- Shift to another chart, t = 59.166 ---
# radius: 0.2
# zeta_gl:   0.58  -0.01   0.64
# xs:     -4.714e-02      5.357e-02      1.415e-01
#
# WARNING: increase arrays: counter_t = 1505
# --- Shift to another chart, t = 59.252 ---
# radius: 0.1
# zeta_gl:   0.52   0.04   0.76
# xs:     -6.167e-02      4.804e-02      1.212e-01
#
# WARNING: increase arrays: counter_t = 1509
# --- Shift to another chart, t = 59.338 ---
# radius: 0.1
# zeta_gl:   0.45   0.08   0.83
# xs:     -7.341e-02      4.255e-02      6.994e-02
#
# WARNING: increase arrays: counter_t = 1513
# --- Shift to another chart, t = 59.494 ---
# radius: 0.2
# zeta_gl:   0.30   0.14   0.76
# xs:     -1.445e-01      6.195e-02     -6.817e-02
#
# WARNING: increase arrays: counter_t = 1518
# --- Shift to another chart, t = 59.577 ---
# radius: 0.1
# zeta_gl:   0.23   0.17   0.64
# xs:     -7.121e-02      2.474e-02     -1.219e-01
#
# WARNING: increase arrays: counter_t = 1522
# --- Shift to another chart, t = 59.661 ---
# radius: 0.2
# zeta_gl:   0.17   0.19   0.49
# xs:     -6.216e-02      1.967e-02     -1.437e-01
#
# WARNING: increase arrays: counter_t = 1526
# --- Shift to another chart, t = 59.747 ---
# radius: 0.2
# zeta_gl:   0.12   0.20   0.35
# xs:     -5.324e-02      1.561e-02     -1.398e-01
#
# WARNING: increase arrays: counter_t = 1530
# --- Shift to another chart, t = 59.837 ---
# radius: 0.1
# zeta_gl:   0.07   0.21   0.24
# xs:     -4.468e-02      1.202e-02     -1.173e-01
#
# WARNING: increase arrays: counter_t = 1534
# --- Shift to another chart, t = 60.004 ---
# radius: 0.2
# zeta_gl:   0.01   0.23   0.10
# xs:     -6.383e-02      1.375e-02     -1.369e-01
#
# WARNING: increase arrays: counter_t = 1539
# --- Shift to another chart, t = 60.250 ---
# radius: 0.1
# zeta_gl:  -0.06   0.23   0.03
# xs:     -7.014e-02      4.257e-03     -7.358e-02
#
# WARNING: increase arrays: counter_t = 1545
# --- Shift to another chart, t = 60.730 ---
# radius: 0.1
# zeta_gl:  -0.17   0.20   0.01
# xs:     -1.102e-01     -3.661e-02     -1.992e-02
#
# WARNING: increase arrays: counter_t = 1554
# --- Shift to another chart, t = 61.211 ---
# radius: 0.1
# zeta_gl:  -0.25   0.11   0.00
# xs:     -7.683e-02     -8.831e-02     -1.174e-03
#
# WARNING: increase arrays: counter_t = 1563
# --- Shift to another chart, t = 61.613 ---
# radius: 0.1
# zeta_gl:  -0.27   0.00   0.00
# xs:     -2.489e-02     -1.022e-01     -2.384e-04
#
# WARNING: increase arrays: counter_t = 1571
# --- Shift to another chart, t = 62.015 ---
# radius: 0.1
# zeta_gl:  -0.26  -0.11   0.00
# xs:      1.882e-02     -1.123e-01      4.633e-05
#
# WARNING: increase arrays: counter_t = 1579
# --- Shift to another chart, t = 62.417 ---
# radius: 0.1
# zeta_gl:  -0.19  -0.21   0.00
# xs:      6.295e-02     -1.045e-01      3.453e-04
#
# WARNING: increase arrays: counter_t = 1587
# --- Shift to another chart, t = 62.741 ---
# radius: 0.1
# zeta_gl:  -0.11  -0.28   0.01
# xs:      7.835e-02     -6.633e-02      5.585e-04
#
# WARNING: increase arrays: counter_t = 1594
# --- Shift to another chart, t = 63.065 ---
# radius: 0.1
# zeta_gl:  -0.02  -0.32   0.01
# xs:      9.576e-02     -4.144e-02      9.193e-04
#
# WARNING: increase arrays: counter_t = 1601
# --- Shift to another chart, t = 63.389 ---
# radius: 0.1
# zeta_gl:   0.09  -0.33   0.01
# xs:      1.039e-01     -1.053e-02      1.467e-03
#
# WARNING: increase arrays: counter_t = 1608
# --- Shift to another chart, t = 63.712 ---
# radius: 0.1
# zeta_gl:   0.19  -0.31   0.01
# xs:      1.013e-01      2.341e-02      2.326e-03
#
# WARNING: increase arrays: counter_t = 1615
# --- Shift to another chart, t = 64.036 ---
# radius: 0.1
# zeta_gl:   0.27  -0.25   0.01
# xs:      8.725e-02      5.686e-02      3.647e-03
#
# WARNING: increase arrays: counter_t = 1622
# --- Shift to another chart, t = 64.360 ---
# radius: 0.1
# zeta_gl:   0.34  -0.16   0.02
# xs:      6.248e-02      8.605e-02      5.438e-03
#
# WARNING: increase arrays: counter_t = 1629
# --- Shift to another chart, t = 64.684 ---
# radius: 0.1
# zeta_gl:   0.37  -0.06   0.03
# xs:      2.886e-02      1.074e-01      7.006e-03
#
# WARNING: increase arrays: counter_t = 1636
# --- Shift to another chart, t = 65.008 ---
# radius: 0.1
# zeta_gl:   0.35   0.06   0.03
# xs:     -1.017e-02      1.178e-01      6.185e-03
#
# WARNING: increase arrays: counter_t = 1643
# --- Shift to another chart, t = 65.332 ---
# radius: 0.1
# zeta_gl:   0.31   0.18   0.03
# xs:     -4.958e-02      1.157e-01      6.068e-04
#
# WARNING: increase arrays: counter_t = 1650
# --- Shift to another chart, t = 65.656 ---
# radius: 0.1
# zeta_gl:   0.22   0.28   0.03
# xs:     -8.390e-02      1.010e-01     -7.157e-03
#
# WARNING: increase arrays: counter_t = 1657
# --- Shift to another chart, t = 65.902 ---
# radius: 0.1
# zeta_gl:   0.14   0.34   0.02
# xs:     -8.138e-02      5.988e-02     -7.656e-03
#
# WARNING: increase arrays: counter_t = 1663
# --- Shift to another chart, t = 66.147 ---
# radius: 0.1
# zeta_gl:   0.05   0.38   0.01
# xs:     -9.209e-02      4.097e-02     -6.247e-03
#
# WARNING: increase arrays: counter_t = 1669
# --- Shift to another chart, t = 66.393 ---
# radius: 0.1
# zeta_gl:  -0.05   0.40   0.01
# xs:     -9.827e-02      1.897e-02     -3.823e-03
#
# WARNING: increase arrays: counter_t = 1675
# --- Shift to another chart, t = 66.717 ---
# radius: 0.1
# zeta_gl:  -0.18   0.39   0.01
# xs:     -1.302e-01     -1.188e-02     -2.456e-03
#
# WARNING: increase arrays: counter_t = 1682
# --- Shift to another chart, t = 67.041 ---
# radius: 0.1
# zeta_gl:  -0.30   0.33   0.00
# xs:     -1.189e-01     -5.475e-02     -1.134e-03
#
# WARNING: increase arrays: counter_t = 1689
# --- Shift to another chart, t = 67.287 ---
# radius: 0.1
# zeta_gl:  -0.37   0.26   0.00
# xs:     -7.443e-02     -6.836e-02     -4.841e-04
#
# WARNING: increase arrays: counter_t = 1695
# --- Shift to another chart, t = 67.532 ---
# radius: 0.1
# zeta_gl:  -0.43   0.17   0.00
# xs:     -5.502e-02     -8.822e-02     -2.985e-04
#
# WARNING: increase arrays: counter_t = 1701
# --- Shift to another chart, t = 67.778 ---
# radius: 0.1
# zeta_gl:  -0.46   0.07   0.00
# xs:     -3.129e-02     -1.036e-01     -1.636e-04
#
# WARNING: increase arrays: counter_t = 1707
# --- Shift to another chart, t = 68.024 ---
# radius: 0.1
# zeta_gl:  -0.46  -0.04   0.00
# xs:     -4.468e-03     -1.134e-01     -5.127e-05
#
# WARNING: increase arrays: counter_t = 1713
# --- Shift to another chart, t = 68.269 ---
# radius: 0.1
# zeta_gl:  -0.44  -0.16   0.00
# xs:      2.395e-02     -1.167e-01      5.570e-05
#
# WARNING: increase arrays: counter_t = 1719
# --- Shift to another chart, t = 68.515 ---
# radius: 0.1
# zeta_gl:  -0.39  -0.27   0.00
# xs:      5.230e-02     -1.130e-01      1.723e-04
#
# WARNING: increase arrays: counter_t = 1725
# --- Shift to another chart, t = 68.761 ---
# radius: 0.1
# zeta_gl:  -0.31  -0.37   0.00
# xs:      7.882e-02     -1.022e-01      3.165e-04
#
# WARNING: increase arrays: counter_t = 1731
# --- Shift to another chart, t = 69.006 ---
# radius: 0.1
# zeta_gl:  -0.21  -0.46   0.00
# xs:      1.018e-01     -8.452e-02      5.155e-04
#
# WARNING: increase arrays: counter_t = 1737
# --- Shift to another chart, t = 69.252 ---
# radius: 0.1
# zeta_gl:  -0.09  -0.52   0.01
# xs:      1.196e-01     -6.080e-02      8.171e-04
#
# WARNING: increase arrays: counter_t = 1743
# --- Shift to another chart, t = 69.498 ---
# radius: 0.1
# zeta_gl:   0.04  -0.55   0.01
# xs:      1.309e-01     -3.218e-02      1.315e-03
#
# WARNING: increase arrays: counter_t = 1749
# --- Shift to another chart, t = 69.744 ---
# radius: 0.1
# zeta_gl:   0.18  -0.55   0.01
# xs:      1.345e-01     -2.298e-04      2.209e-03
#
# WARNING: increase arrays: counter_t = 1755
# --- Shift to another chart, t = 69.989 ---
# radius: 0.1
# zeta_gl:   0.31  -0.52   0.01
# xs:      1.297e-01      3.321e-02      3.954e-03
#
# WARNING: increase arrays: counter_t = 1761
# --- Shift to another chart, t = 70.235 ---
# radius: 0.1
# zeta_gl:   0.42  -0.45   0.02
# xs:      1.161e-01      6.603e-02      7.650e-03
#
# WARNING: increase arrays: counter_t = 1767
# --- Shift to another chart, t = 70.481 ---
# radius: 0.1
# zeta_gl:   0.52  -0.36   0.04
# xs:      9.335e-02      9.595e-02      1.601e-02
#
# WARNING: increase arrays: counter_t = 1773
# --- Shift to another chart, t = 70.726 ---
# radius: 0.1
# zeta_gl:   0.58  -0.24   0.07
# xs:      6.065e-02      1.204e-01      3.516e-02
#
# WARNING: increase arrays: counter_t = 1779
# --- Shift to another chart, t = 70.894 ---
# radius: 0.1
# zeta_gl:   0.59  -0.14   0.12
# xs:      1.656e-02      9.196e-02      4.502e-02
#
# WARNING: increase arrays: counter_t = 1784
# --- Shift to another chart, t = 71.061 ---
# radius: 0.1
# zeta_gl:   0.58  -0.05   0.19
# xs:     -8.781e-03      9.583e-02      6.975e-02
#
# WARNING: increase arrays: counter_t = 1789
# --- Shift to another chart, t = 71.229 ---
# radius: 0.1
# zeta_gl:   0.55   0.05   0.28
# xs:     -3.847e-02      9.513e-02      9.048e-02
#
# WARNING: increase arrays: counter_t = 1794
# --- Shift to another chart, t = 71.396 ---
# radius: 0.1
# zeta_gl:   0.48   0.14   0.36
# xs:     -6.899e-02      8.920e-02      8.114e-02
#
# WARNING: increase arrays: counter_t = 1799
# --- Shift to another chart, t = 71.564 ---
# radius: 0.1
# zeta_gl:   0.38   0.21   0.38
# xs:     -9.231e-02      7.834e-02      2.095e-02
#
# WARNING: increase arrays: counter_t = 1804
# --- Shift to another chart, t = 71.731 ---
# radius: 0.1
# zeta_gl:   0.28   0.28   0.32
# xs:     -1.007e-01      6.434e-02     -6.178e-02
#
# WARNING: increase arrays: counter_t = 1809
# --- Shift to another chart, t = 71.899 ---
# radius: 0.2
# zeta_gl:   0.19   0.33   0.21
# xs:     -9.536e-02      4.969e-02     -1.065e-01
#
# WARNING: increase arrays: counter_t = 1814
# --- Shift to another chart, t = 72.066 ---
# radius: 0.1
# zeta_gl:   0.10   0.36   0.11
# xs:     -8.494e-02      3.601e-02     -9.598e-02
#
# WARNING: increase arrays: counter_t = 1819
# --- Shift to another chart, t = 72.234 ---
# radius: 0.1
# zeta_gl:   0.03   0.39   0.05
# xs:     -7.669e-02      2.353e-02     -6.082e-02
#
# WARNING: increase arrays: counter_t = 1824
# --- Shift to another chart, t = 72.480 ---
# radius: 0.1
# zeta_gl:  -0.08   0.40   0.02
# xs:     -1.050e-01      1.315e-02     -3.743e-02
#
# WARNING: increase arrays: counter_t = 1830
# --- Shift to another chart, t = 72.725 ---
# radius: 0.1
# zeta_gl:  -0.18   0.39   0.01
# xs:     -1.000e-01     -1.200e-02     -9.464e-03
#
# WARNING: increase arrays: counter_t = 1836
# --- Shift to another chart, t = 73.049 ---
# radius: 0.1
# zeta_gl:  -0.30   0.33   0.00
# xs:     -1.200e-01     -5.385e-02     -2.420e-03
#
# WARNING: increase arrays: counter_t = 1843
# --- Shift to another chart, t = 73.295 ---
# radius: 0.1
# zeta_gl:  -0.37   0.27   0.00
# xs:     -7.538e-02     -6.791e-02     -5.504e-04
#
# WARNING: increase arrays: counter_t = 1849
# --- Shift to another chart, t = 73.541 ---
# radius: 0.1
# zeta_gl:  -0.43   0.18   0.00
# xs:     -5.605e-02     -8.800e-02     -3.080e-04
#
# WARNING: increase arrays: counter_t = 1855
# --- Shift to another chart, t = 73.786 ---
# radius: 0.1
# zeta_gl:  -0.46   0.08   0.00
# xs:     -3.234e-02     -1.037e-01     -1.680e-04
#
# WARNING: increase arrays: counter_t = 1861
# --- Shift to another chart, t = 74.032 ---
# radius: 0.1
# zeta_gl:  -0.47  -0.04   0.00
# xs:     -5.480e-03     -1.137e-01     -5.498e-05
#
# WARNING: increase arrays: counter_t = 1867
# --- Shift to another chart, t = 74.278 ---
# radius: 0.1
# zeta_gl:  -0.44  -0.16   0.00
# xs:      2.304e-02     -1.173e-01      5.191e-05
#
# WARNING: increase arrays: counter_t = 1873
# --- Shift to another chart, t = 74.523 ---
# radius: 0.1
# zeta_gl:  -0.39  -0.27   0.00
# xs:      5.155e-02     -1.138e-01      1.679e-04
#
# WARNING: increase arrays: counter_t = 1879
# --- Shift to another chart, t = 74.769 ---
# radius: 0.1
# zeta_gl:  -0.31  -0.37   0.00
# xs:      7.830e-02     -1.032e-01      3.109e-04
#
# WARNING: increase arrays: counter_t = 1885
# --- Shift to another chart, t = 75.015 ---
# radius: 0.1
# zeta_gl:  -0.21  -0.46   0.00
# xs:      1.015e-01     -8.566e-02      5.076e-04
#
# WARNING: increase arrays: counter_t = 1891
# --- Shift to another chart, t = 75.261 ---
# radius: 0.1
# zeta_gl:  -0.09  -0.52   0.01
# xs:      1.196e-01     -6.202e-02      8.054e-04
#
# WARNING: increase arrays: counter_t = 1897
# --- Shift to another chart, t = 75.506 ---
# radius: 0.1
# zeta_gl:   0.04  -0.55   0.01
# xs:      1.312e-01     -3.342e-02      1.297e-03
#
# WARNING: increase arrays: counter_t = 1903
# --- Shift to another chart, t = 75.752 ---
# radius: 0.1
# zeta_gl:   0.17  -0.56   0.01
# xs:      1.351e-01     -1.404e-03      2.177e-03
#
# WARNING: increase arrays: counter_t = 1909
# --- Shift to another chart, t = 75.998 ---
# radius: 0.1
# zeta_gl:   0.30  -0.52   0.01
# xs:      1.306e-01      3.217e-02      3.897e-03
#
# WARNING: increase arrays: counter_t = 1915
# --- Shift to another chart, t = 76.243 ---
# radius: 0.1
# zeta_gl:   0.42  -0.46   0.02
# xs:      1.173e-01      6.521e-02      7.547e-03
#
# WARNING: increase arrays: counter_t = 1921
# --- Shift to another chart, t = 76.489 ---
# radius: 0.1
# zeta_gl:   0.52  -0.36   0.04
# xs:      9.472e-02      9.541e-02      1.583e-02
#
# WARNING: increase arrays: counter_t = 1927
# --- Shift to another chart, t = 76.735 ---
# radius: 0.1
# zeta_gl:   0.58  -0.24   0.07
# xs:      6.217e-02      1.202e-01      3.498e-02
#
# WARNING: increase arrays: counter_t = 1933
# --- Shift to another chart, t = 76.902 ---
# radius: 0.1
# zeta_gl:   0.60  -0.15   0.12
# xs:      1.761e-02      9.203e-02      4.514e-02
#
# WARNING: increase arrays: counter_t = 1938
# --- Shift to another chart, t = 77.070 ---
# radius: 0.1
# zeta_gl:   0.59  -0.05   0.19
# xs:     -7.831e-03      9.608e-02      7.064e-02
#
# WARNING: increase arrays: counter_t = 1943
# --- Shift to another chart, t = 77.237 ---
# radius: 0.1
# zeta_gl:   0.55   0.04   0.28
# xs:     -3.784e-02      9.553e-02      9.292e-02
#
# WARNING: increase arrays: counter_t = 1948
# --- Shift to another chart, t = 77.405 ---
# radius: 0.1
# zeta_gl:   0.48   0.13   0.36
# xs:     -6.899e-02      8.967e-02      8.515e-02
#
# WARNING: increase arrays: counter_t = 1953
# --- Shift to another chart, t = 77.572 ---
# radius: 0.1
# zeta_gl:   0.39   0.21   0.39
# xs:     -9.305e-02      7.877e-02      2.434e-02
#
# WARNING: increase arrays: counter_t = 1958
# --- Shift to another chart, t = 77.740 ---
# radius: 0.1
# zeta_gl:   0.29   0.27   0.33
# xs:     -1.018e-01      6.461e-02     -6.176e-02
#
# WARNING: increase arrays: counter_t = 1963
# --- Shift to another chart, t = 77.907 ---
# radius: 0.2
# zeta_gl:   0.19   0.32   0.22
# xs:     -9.622e-02      4.979e-02     -1.095e-01
#
# WARNING: increase arrays: counter_t = 1968
# --- Shift to another chart, t = 78.075 ---
# radius: 0.1
# zeta_gl:   0.10   0.36   0.12
# xs:     -8.526e-02      3.602e-02     -9.929e-02
#
# WARNING: increase arrays: counter_t = 1973
# --- Shift to another chart, t = 78.242 ---
# radius: 0.1
# zeta_gl:   0.03   0.38   0.06
# xs:     -7.654e-02      2.352e-02     -6.304e-02
#
# WARNING: increase arrays: counter_t = 1978
# --- Shift to another chart, t = 78.488 ---
# radius: 0.1
# zeta_gl:  -0.08   0.40   0.02
# xs:     -1.043e-01      1.324e-02     -3.881e-02
#
# WARNING: increase arrays: counter_t = 1984
# --- Shift to another chart, t = 78.734 ---
# radius: 0.1
# zeta_gl:  -0.18   0.39   0.01
# xs:     -9.923e-02     -1.171e-02     -9.807e-03
#
# WARNING: increase arrays: counter_t = 1990
# --- Shift to another chart, t = 79.058 ---
# radius: 0.1
# zeta_gl:  -0.29   0.33   0.00
# xs:     -1.191e-01     -5.315e-02     -2.487e-03
#
# WARNING: increase arrays: counter_t = 1997
# --- Shift to another chart, t = 79.303 ---
# radius: 0.1
# zeta_gl:  -0.37   0.27   0.00
# xs:     -7.482e-02     -6.715e-02     -5.554e-04
#
# WARNING: increase arrays: counter_t = 2003
# --- Shift to another chart, t = 79.549 ---
# radius: 0.1
# zeta_gl:  -0.43   0.18   0.00
# xs:     -5.570e-02     -8.708e-02     -3.095e-04
#
# WARNING: increase arrays: counter_t = 2009
# --- Shift to another chart, t = 79.795 ---
# radius: 0.1
# zeta_gl:  -0.46   0.08   0.00
# xs:     -3.223e-02     -1.026e-01     -1.691e-04
#
# WARNING: increase arrays: counter_t = 2015
# Done

# %%
# --------------------------------------------------------------------
# --- Compare trajectories ---
# --------------------------------------------------------------------
mix.reload_module(ca)
ca.compare_trajectory_cl_and_carleman(
    t_ref_, sol_ref_, t_emb_, sol_emb_,
    flag_save=False, path_save=path_save_, 
    case_title = "SoA", case_emb = case_emb_
)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
