# %%
# %matplotlib widget
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
import h5py

import os
import sys
sys.path.append(os.path.abspath("./"))

print(os.getpid())
# %cd ../../

import pylib.mix as mix
import carleman as ca
from matplotlib import colors
plt.rcParams.update({
    "text.usetex": True,
    'text.latex.preamble': r"\usepackage{amsmath} \boldmath"
})
# Out:
# 24704
# c:\Users\ivan9\Documents\work\codes\QuCF\scripts-py

# %%
path_save_ = "./jupyter-notebooks/Carleman/results/"
for i in range(100):
    plt.close()

colors_     = ["blue", "red", "green", "gray", "black"]
linestyles_ = ["-", "--", "--", ":"]

# %%
# ---------------------------------------------------------------
# --- Prepare the system: Lotka - Volterra 2D ---
# ---------------------------------------------------------------
mix.reload_module(ca)
mix.reload_module(mix)
def choose_case(N_nl, sel_case):
    Nx = 2  # the number of degrees of freedom
    F_terms, sys_coefs, return_sys, shift_coefs = None, None, None, None
    if sel_case == 0:
        x_init = np.array([0.5, 0.5])

        tmax, nt = 20, 8
        # tmax, nt = 3, 5  # for standard embedding

        aa, gg = 1.0, 0.475
        eta_x, eta_y = 1., 1. 
        xi_x, xi_y = 0., 0.

        sys_coefs = {}
        sys_coefs["aa"]    = aa
        sys_coefs["gg"]    = gg
        sys_coefs["eta_x"] = eta_x
        sys_coefs["eta_y"] = eta_y
        sys_coefs["xi_x"]  = xi_x
        sys_coefs["xi_y"]  = xi_y

        def return_sys(ss):
            aa    = ss["aa"]       
            gg    = ss["gg"]    
            eta_x = ss["eta_x"] 
            eta_y = ss["eta_y"] 
            xi_x  = ss["xi_x"]  
            xi_y  = ss["xi_y"]  

            F_terms = [None] * (N_nl + 1)
            for ii_nl in range(N_nl + 1):
                F_terms[ii_nl] = np.zeros((Nx,int(Nx**ii_nl)))
            
            F_terms[0][0,0] =   aa * xi_x - eta_y * aa * xi_x * xi_y
            F_terms[0][1,0] = - gg * xi_y + eta_x * gg * xi_x * xi_y

            F_terms[1][0, 0] = aa - eta_y * aa * xi_y
            F_terms[1][0, 1] =    - eta_y * aa * xi_x

            F_terms[1][1, 0] =        eta_x * gg * xi_y
            F_terms[1][1, 1] = - gg + eta_x * gg * xi_x 

            F_terms[2][0, 1] = - eta_y * aa
            F_terms[2][1, 1] =   eta_x * gg
            return F_terms
        
        def shift_coefs(ss, zeta):
            ss_new = dict(ss)
            ss_new["xi_x"] = ss_new["xi_x"] + zeta[0]
            ss_new["xi_y"] = ss_new["xi_y"] + zeta[1]
            if "xi_z" in ss_new:
                ss_new["xi_z"] = ss_new["xi_z"] + zeta[2]
            return ss_new
        
        print("\nSystem coefficients:")
        for key, value in sys_coefs.items():
            print("{:s} = {:0.3f}".format(key, value))
        print()

        F_terms = return_sys(sys_coefs)
        F = [
            lambda x: F_terms[0][0,0] + F_terms[1][0, 0] * x[0] + F_terms[1][0, 1] * x[1] + F_terms[2][0, 1] * x[0] * x[1],
            lambda x: F_terms[0][1,0] + F_terms[1][1, 0] * x[0] + F_terms[1][1, 1] * x[1] + F_terms[2][1, 1] * x[0] * x[1],
        ]

    # ----------------------------------------------------
    return F, tmax, nt, Nx, x_init, sys_coefs, return_sys, shift_coefs
# ------------------------------------------------------------------------------
sel_case_ = 0

N_nl_orig_ = 2 
F_, tmax_, nt_, Nx_, x_init_ref_, sys_coefs_, return_sys_, shift_coefs_ = choose_case(N_nl_orig_, sel_case = sel_case_)
Nt_ = 1 << nt_
t_ = np.linspace(0, tmax_, Nt_)
dt_ = np.diff(t_)[0]

print("Nt: {:d}".format(Nt_))
print("init. cond.: ", end = "")
mix.print_array(x_init_ref_, ff = [6, 2, "f"])

# --- Standard method (for reference) ---
sol_ref_, t_ref_ = ca.analyse_classical(x_init_ref_, t_, F_)

print(len(t_ref_))
# Out:
# System coefficients:
# aa = 1.000
# gg = 0.475
# eta_x = 1.000
# eta_y = 1.000
# xi_x = 0.000
# xi_y = 0.000
#
# Nt: 256
# init. cond.:   0.50   0.50
#
# WARNING: increase arrays: counter_t = 256
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 257

# %%
# --------------------------------------------------------------------
# --- Carleman linearization ---
# --------------------------------------------------------------------
mix.reload_module(ca)
N_nl = 6   
flag_max_error_ = False
case_sim_, step_t_ = "LV2D", 1

# # --- Standard embedding ---
# sol_emb_, t_emb_, case_emb_ = ca.solve_carleman_orig(x_init_ref_, N_nl, N_nl_orig_, t_, return_sys_(sys_coefs_))
# radii_emb_ = None

# # --- Piecewise embedding ---
# zeta_th = 0.1
# sol_emb_, t_emb_, case_emb_ = ca.solve_carleman_global(
#     x_init_ref_, N_nl, N_nl_orig_, t_, 
#     sys_coefs_, return_sys_, shift_coefs_,
#     zeta_th = zeta_th
# )
# radii_emb_ = None
# del zeta_th


# --- Piecewise adaptive embedding ---
flag_max_error_ = True

err_tol, zeta_max = 1.e-14, 1.0

sol_emb_, t_emb_, case_emb_, radii_emb_ = ca.solve_carleman_global_adaptive(
    x_init_ref_, N_nl, N_nl_orig_, t_, 
    sys_coefs_, return_sys_, shift_coefs_,
    zeta_init_ = zeta_max, 
    err_tolerance_ = err_tol,
    zeta_min_    = 1e-3,
    zeta_step_   = 0.02,
    zeta_thresh_ = 0.12,
    zeta_max_ = zeta_max
)
case_sim_ = "LV2D_max{:0.2f}_tol{:0.3e}".format(zeta_max, err_tol)
step_t_ = 1
del err_tol, zeta_max
# Out:
# Take a smaller chart: new zeta = 9.800e-01
# Take a smaller chart: new zeta = 9.600e-01
# Take a smaller chart: new zeta = 9.400e-01
# Take a smaller chart: new zeta = 9.200e-01
# Take a smaller chart: new zeta = 9.000e-01
# Take a smaller chart: new zeta = 8.800e-01
# Take a smaller chart: new zeta = 8.600e-01
# Take a smaller chart: new zeta = 8.400e-01
# Take a smaller chart: new zeta = 8.200e-01
# Take a smaller chart: new zeta = 8.000e-01
# Take a smaller chart: new zeta = 7.800e-01
# Take a smaller chart: new zeta = 7.600e-01
# Take a smaller chart: new zeta = 7.400e-01
# Take a smaller chart: new zeta = 7.200e-01
# Take a smaller chart: new zeta = 7.000e-01
# Take a smaller chart: new zeta = 6.800e-01
# Take a smaller chart: new zeta = 6.600e-01
# Take a smaller chart: new zeta = 6.400e-01
# Take a smaller chart: new zeta = 6.200e-01
# Take a smaller chart: new zeta = 6.000e-01
# Take a smaller chart: new zeta = 5.800e-01
# Take a smaller chart: new zeta = 5.600e-01
# Take a smaller chart: new zeta = 5.400e-01
# Take a smaller chart: new zeta = 5.200e-01
# Take a smaller chart: new zeta = 5.000e-01
# Take a smaller chart: new zeta = 4.800e-01
# Take a smaller chart: new zeta = 4.600e-01
# Take a smaller chart: new zeta = 4.400e-01
# Take a smaller chart: new zeta = 4.200e-01
# Take a smaller chart: new zeta = 4.000e-01
# Take a smaller chart: new zeta = 3.800e-01
# Take a smaller chart: new zeta = 3.600e-01
# Take a smaller chart: new zeta = 3.400e-01
# Take a smaller chart: new zeta = 3.200e-01
# Take a smaller chart: new zeta = 3.000e-01
# Take a smaller chart: new zeta = 2.800e-01
# Take a smaller chart: new zeta = 2.600e-01
# Take a smaller chart: new zeta = 2.400e-01
# Take a smaller chart: new zeta = 2.200e-01
# Take a smaller chart: new zeta = 2.000e-01
# Take a smaller chart: new zeta = 1.800e-01
# Take a smaller chart: new zeta = 1.600e-01
# Take a smaller chart: new zeta = 1.400e-01
# Take a smaller chart: new zeta = 1.200e-01
# Take a smaller chart: new zeta = 6.000e-02
# Take a smaller chart: new zeta = 3.000e-02
# Take a smaller chart: new zeta = 1.500e-02
#
# --- t, zeta: 1.110e-02, 1.500e-02 ---
#
# --- t, zeta: 1.006e-01, 1.500e-02 ---
#
# --- t, zeta: 1.902e-01, 1.500e-02 ---
#
# --- t, zeta: 2.797e-01, 1.500e-02 ---
#
# --- t, zeta: 3.692e-01, 1.500e-02 ---
# Take a larger chart: new zeta = 3.000e-02
#
# --- t, zeta: 4.588e-01, 3.000e-02 ---
# Take a smaller chart: new zeta = 1.500e-02
# Take a smaller chart: new zeta = 7.500e-03
# Take a smaller chart: new zeta = 3.750e-03
# Take a smaller chart: new zeta = 1.875e-03
#
# Warning: the minimal chart radius was achieved, zeta_comp, zeta_min: 9.375e-04, 1.000e-03.
#
#
# --- t, zeta: 4.599e-01, 1.875e-03 ---
#
# --- t, zeta: 4.610e-01, 1.875e-03 ---
#
# --- t, zeta: 4.621e-01, 1.875e-03 ---
#
# --- t, zeta: 4.632e-01, 1.875e-03 ---
#
# --- t, zeta: 4.643e-01, 1.875e-03 ---
#
# --- t, zeta: 4.654e-01, 1.875e-03 ---
#
# --- t, zeta: 4.665e-01, 1.875e-03 ---
#
# --- t, zeta: 4.676e-01, 1.875e-03 ---
#
# --- t, zeta: 4.687e-01, 1.875e-03 ---
#
# --- t, zeta: 4.698e-01, 1.875e-03 ---
#
# --- t, zeta: 4.709e-01, 1.875e-03 ---
#
# --- t, zeta: 4.720e-01, 1.875e-03 ---
#
# --- t, zeta: 4.731e-01, 1.875e-03 ---
#
# --- t, zeta: 4.742e-01, 1.875e-03 ---
#
# --- t, zeta: 4.753e-01, 1.875e-03 ---
#
# --- t, zeta: 4.764e-01, 1.875e-03 ---
#
# --- t, zeta: 4.775e-01, 1.875e-03 ---
#
# --- t, zeta: 4.786e-01, 1.875e-03 ---
#
# --- t, zeta: 4.797e-01, 1.875e-03 ---
#
# --- t, zeta: 4.808e-01, 1.875e-03 ---
#
# --- t, zeta: 4.819e-01, 1.875e-03 ---
#
# --- t, zeta: 4.830e-01, 1.875e-03 ---
#
# --- t, zeta: 4.841e-01, 1.875e-03 ---
#
# --- t, zeta: 4.852e-01, 1.875e-03 ---
#
# --- t, zeta: 4.863e-01, 1.875e-03 ---
#
# --- t, zeta: 4.874e-01, 1.875e-03 ---
#
# --- t, zeta: 4.885e-01, 1.875e-03 ---
#
# --- t, zeta: 4.896e-01, 1.875e-03 ---
#
# --- t, zeta: 4.907e-01, 1.875e-03 ---
#
# --- t, zeta: 4.918e-01, 1.875e-03 ---
#
# --- t, zeta: 4.929e-01, 1.875e-03 ---
#
# --- t, zeta: 4.940e-01, 1.875e-03 ---
#
# --- t, zeta: 4.951e-01, 1.875e-03 ---
#
# --- t, zeta: 4.962e-01, 1.875e-03 ---
#
# --- t, zeta: 4.973e-01, 1.875e-03 ---
#
# --- t, zeta: 4.984e-01, 1.875e-03 ---
#
# --- t, zeta: 4.995e-01, 1.875e-03 ---
#
# --- t, zeta: 5.006e-01, 1.875e-03 ---
#
# --- t, zeta: 5.017e-01, 1.875e-03 ---
#
# --- t, zeta: 5.028e-01, 1.875e-03 ---
#
# --- t, zeta: 5.039e-01, 1.875e-03 ---
#
# --- t, zeta: 5.050e-01, 1.875e-03 ---
#
# --- t, zeta: 5.061e-01, 1.875e-03 ---
#
# --- t, zeta: 5.072e-01, 1.875e-03 ---
#
# --- t, zeta: 5.083e-01, 1.875e-03 ---
#
# --- t, zeta: 5.094e-01, 1.875e-03 ---
#
# --- t, zeta: 5.105e-01, 1.875e-03 ---
#
# --- t, zeta: 5.116e-01, 1.875e-03 ---
#
# --- t, zeta: 5.127e-01, 1.875e-03 ---
#
# --- t, zeta: 5.138e-01, 1.875e-03 ---
#
# --- t, zeta: 5.149e-01, 1.875e-03 ---
#
# --- t, zeta: 5.160e-01, 1.875e-03 ---
#
# --- t, zeta: 5.171e-01, 1.875e-03 ---
#
# --- t, zeta: 5.182e-01, 1.875e-03 ---
#
# --- t, zeta: 5.193e-01, 1.875e-03 ---
#
# --- t, zeta: 5.204e-01, 1.875e-03 ---
#
# --- t, zeta: 5.215e-01, 1.875e-03 ---
#
# --- t, zeta: 5.226e-01, 1.875e-03 ---
#
# --- t, zeta: 5.237e-01, 1.875e-03 ---
#
# --- t, zeta: 5.248e-01, 1.875e-03 ---
#
# --- t, zeta: 5.259e-01, 1.875e-03 ---
#
# --- t, zeta: 5.270e-01, 1.875e-03 ---
#
# --- t, zeta: 5.281e-01, 1.875e-03 ---
#
# --- t, zeta: 5.292e-01, 1.875e-03 ---
#
# --- t, zeta: 5.303e-01, 1.875e-03 ---
#
# --- t, zeta: 5.314e-01, 1.875e-03 ---
#
# --- t, zeta: 5.325e-01, 1.875e-03 ---
#
# --- t, zeta: 5.336e-01, 1.875e-03 ---
#
# --- t, zeta: 5.347e-01, 1.875e-03 ---
#
# --- t, zeta: 5.358e-01, 1.875e-03 ---
#
# --- t, zeta: 5.369e-01, 1.875e-03 ---
#
# --- t, zeta: 5.380e-01, 1.875e-03 ---
#
# --- t, zeta: 5.391e-01, 1.875e-03 ---
#
# --- t, zeta: 5.402e-01, 1.875e-03 ---
#
# --- t, zeta: 5.413e-01, 1.875e-03 ---
#
# --- t, zeta: 5.424e-01, 1.875e-03 ---
#
# --- t, zeta: 5.435e-01, 1.875e-03 ---
#
# --- t, zeta: 5.446e-01, 1.875e-03 ---
#
# --- t, zeta: 5.457e-01, 1.875e-03 ---
#
# --- t, zeta: 5.468e-01, 1.875e-03 ---
#
# --- t, zeta: 5.479e-01, 1.875e-03 ---
#
# --- t, zeta: 5.490e-01, 1.875e-03 ---
#
# --- t, zeta: 5.501e-01, 1.875e-03 ---
#
# --- t, zeta: 5.512e-01, 1.875e-03 ---
#
# --- t, zeta: 5.523e-01, 1.875e-03 ---
#
# --- t, zeta: 5.534e-01, 1.875e-03 ---
#
# --- t, zeta: 5.545e-01, 1.875e-03 ---
#
# --- t, zeta: 5.556e-01, 1.875e-03 ---
#
# --- t, zeta: 5.567e-01, 1.875e-03 ---
#
# --- t, zeta: 5.578e-01, 1.875e-03 ---
#
# --- t, zeta: 5.589e-01, 1.875e-03 ---
#
# --- t, zeta: 5.600e-01, 1.875e-03 ---
#
# --- t, zeta: 5.611e-01, 1.875e-03 ---
#
# --- t, zeta: 5.622e-01, 1.875e-03 ---
#
# --- t, zeta: 5.633e-01, 1.875e-03 ---
#
# --- t, zeta: 5.644e-01, 1.875e-03 ---
#
# --- t, zeta: 5.655e-01, 1.875e-03 ---
#
# --- t, zeta: 5.666e-01, 1.875e-03 ---
#
# --- t, zeta: 5.677e-01, 1.875e-03 ---
#
# --- t, zeta: 5.688e-01, 1.875e-03 ---
#
# --- t, zeta: 5.699e-01, 1.875e-03 ---
#
# --- t, zeta: 5.710e-01, 1.875e-03 ---
#
# --- t, zeta: 5.721e-01, 1.875e-03 ---
#
# --- t, zeta: 5.732e-01, 1.875e-03 ---
#
# --- t, zeta: 5.743e-01, 1.875e-03 ---
#
# --- t, zeta: 5.754e-01, 1.875e-03 ---
#
# --- t, zeta: 5.765e-01, 1.875e-03 ---
#
# --- t, zeta: 5.776e-01, 1.875e-03 ---
#
# --- t, zeta: 5.787e-01, 1.875e-03 ---
#
# --- t, zeta: 5.798e-01, 1.875e-03 ---
#
# --- t, zeta: 5.809e-01, 1.875e-03 ---
#
# --- t, zeta: 5.820e-01, 1.875e-03 ---
#
# --- t, zeta: 5.831e-01, 1.875e-03 ---
#
# --- t, zeta: 5.842e-01, 1.875e-03 ---
#
# --- t, zeta: 5.853e-01, 1.875e-03 ---
#
# --- t, zeta: 5.864e-01, 1.875e-03 ---
#
# --- t, zeta: 5.875e-01, 1.875e-03 ---
#
# --- t, zeta: 5.886e-01, 1.875e-03 ---
#
# --- t, zeta: 5.897e-01, 1.875e-03 ---
#
# --- t, zeta: 5.908e-01, 1.875e-03 ---
#
# --- t, zeta: 5.919e-01, 1.875e-03 ---
#
# --- t, zeta: 5.930e-01, 1.875e-03 ---
#
# --- t, zeta: 5.941e-01, 1.875e-03 ---
#
# --- t, zeta: 5.952e-01, 1.875e-03 ---
#
# --- t, zeta: 5.963e-01, 1.875e-03 ---
#
# --- t, zeta: 5.974e-01, 1.875e-03 ---
#
# --- t, zeta: 5.985e-01, 1.875e-03 ---
#
# --- t, zeta: 5.996e-01, 1.875e-03 ---
#
# --- t, zeta: 6.007e-01, 1.875e-03 ---
#
# --- t, zeta: 6.018e-01, 1.875e-03 ---
#
# --- t, zeta: 6.029e-01, 1.875e-03 ---
#
# --- t, zeta: 6.040e-01, 1.875e-03 ---
#
# --- t, zeta: 6.051e-01, 1.875e-03 ---
#
# --- t, zeta: 6.062e-01, 1.875e-03 ---
#
# --- t, zeta: 6.073e-01, 1.875e-03 ---
#
# --- t, zeta: 6.084e-01, 1.875e-03 ---
#
# --- t, zeta: 6.095e-01, 1.875e-03 ---
#
# --- t, zeta: 6.106e-01, 1.875e-03 ---
#
# --- t, zeta: 6.117e-01, 1.875e-03 ---
#
# --- t, zeta: 6.128e-01, 1.875e-03 ---
#
# --- t, zeta: 6.139e-01, 1.875e-03 ---
#
# --- t, zeta: 6.150e-01, 1.875e-03 ---
#
# --- t, zeta: 6.161e-01, 1.875e-03 ---
#
# --- t, zeta: 6.172e-01, 1.875e-03 ---
#
# --- t, zeta: 6.183e-01, 1.875e-03 ---
#
# --- t, zeta: 6.194e-01, 1.875e-03 ---
#
# --- t, zeta: 6.205e-01, 1.875e-03 ---
#
# --- t, zeta: 6.216e-01, 1.875e-03 ---
#
# --- t, zeta: 6.227e-01, 1.875e-03 ---
#
# --- t, zeta: 6.238e-01, 1.875e-03 ---
#
# --- t, zeta: 6.249e-01, 1.875e-03 ---
#
# --- t, zeta: 6.260e-01, 1.875e-03 ---
#
# --- t, zeta: 6.271e-01, 1.875e-03 ---
#
# --- t, zeta: 6.282e-01, 1.875e-03 ---
#
# --- t, zeta: 6.293e-01, 1.875e-03 ---
#
# --- t, zeta: 6.304e-01, 1.875e-03 ---
#
# --- t, zeta: 6.315e-01, 1.875e-03 ---
#
# --- t, zeta: 6.326e-01, 1.875e-03 ---
#
# --- t, zeta: 6.337e-01, 1.875e-03 ---
#
# --- t, zeta: 6.348e-01, 1.875e-03 ---
#
# --- t, zeta: 6.359e-01, 1.875e-03 ---
#
# --- t, zeta: 6.370e-01, 1.875e-03 ---
#
# --- t, zeta: 6.381e-01, 1.875e-03 ---
#
# --- t, zeta: 6.392e-01, 1.875e-03 ---
#
# --- t, zeta: 6.403e-01, 1.875e-03 ---
#
# --- t, zeta: 6.414e-01, 1.875e-03 ---
#
# --- t, zeta: 6.425e-01, 1.875e-03 ---
#
# --- t, zeta: 6.436e-01, 1.875e-03 ---
#
# --- t, zeta: 6.447e-01, 1.875e-03 ---
#
# --- t, zeta: 6.458e-01, 1.875e-03 ---
#
# --- t, zeta: 6.469e-01, 1.875e-03 ---
#
# --- t, zeta: 6.480e-01, 1.875e-03 ---
#
# --- t, zeta: 6.491e-01, 1.875e-03 ---
#
# --- t, zeta: 6.502e-01, 1.875e-03 ---
#
# --- t, zeta: 6.513e-01, 1.875e-03 ---
#
# --- t, zeta: 6.524e-01, 1.875e-03 ---
#
# --- t, zeta: 6.535e-01, 1.875e-03 ---
#
# --- t, zeta: 6.546e-01, 1.875e-03 ---
#
# --- t, zeta: 6.557e-01, 1.875e-03 ---
#
# --- t, zeta: 6.568e-01, 1.875e-03 ---
#
# --- t, zeta: 6.579e-01, 1.875e-03 ---
#
# --- t, zeta: 6.590e-01, 1.875e-03 ---
#
# --- t, zeta: 6.601e-01, 1.875e-03 ---
#
# --- t, zeta: 6.612e-01, 1.875e-03 ---
#
# --- t, zeta: 6.623e-01, 1.875e-03 ---
#
# --- t, zeta: 6.634e-01, 1.875e-03 ---
#
# --- t, zeta: 6.645e-01, 1.875e-03 ---
#
# --- t, zeta: 6.656e-01, 1.875e-03 ---
#
# --- t, zeta: 6.667e-01, 1.875e-03 ---
#
# --- t, zeta: 6.678e-01, 1.875e-03 ---
#
# --- t, zeta: 6.689e-01, 1.875e-03 ---
#
# --- t, zeta: 6.700e-01, 1.875e-03 ---
#
# --- t, zeta: 6.711e-01, 1.875e-03 ---
#
# --- t, zeta: 6.722e-01, 1.875e-03 ---
#
# --- t, zeta: 6.733e-01, 1.875e-03 ---
#
# --- t, zeta: 6.744e-01, 1.875e-03 ---
#
# --- t, zeta: 6.755e-01, 1.875e-03 ---
#
# --- t, zeta: 6.766e-01, 1.875e-03 ---
#
# --- t, zeta: 6.777e-01, 1.875e-03 ---
#
# --- t, zeta: 6.788e-01, 1.875e-03 ---
#
# --- t, zeta: 6.799e-01, 1.875e-03 ---
#
# --- t, zeta: 6.810e-01, 1.875e-03 ---
#
# --- t, zeta: 6.821e-01, 1.875e-03 ---
#
# --- t, zeta: 6.832e-01, 1.875e-03 ---
#
# --- t, zeta: 6.843e-01, 1.875e-03 ---
#
# --- t, zeta: 6.854e-01, 1.875e-03 ---
#
# --- t, zeta: 6.865e-01, 1.875e-03 ---
#
# --- t, zeta: 6.876e-01, 1.875e-03 ---
#
# --- t, zeta: 6.887e-01, 1.875e-03 ---
#
# --- t, zeta: 6.898e-01, 1.875e-03 ---
#
# --- t, zeta: 6.909e-01, 1.875e-03 ---
#
# --- t, zeta: 6.920e-01, 1.875e-03 ---
#
# --- t, zeta: 6.931e-01, 1.875e-03 ---
#
# --- t, zeta: 6.942e-01, 1.875e-03 ---
#
# --- t, zeta: 6.953e-01, 1.875e-03 ---
#
# --- t, zeta: 6.964e-01, 1.875e-03 ---
#
# --- t, zeta: 6.975e-01, 1.875e-03 ---
#
# --- t, zeta: 6.986e-01, 1.875e-03 ---
#
# --- t, zeta: 6.997e-01, 1.875e-03 ---
#
# --- t, zeta: 7.008e-01, 1.875e-03 ---
#
# --- t, zeta: 7.019e-01, 1.875e-03 ---
#
# --- t, zeta: 7.030e-01, 1.875e-03 ---
#
# --- t, zeta: 7.041e-01, 1.875e-03 ---
#
# --- t, zeta: 7.052e-01, 1.875e-03 ---
#
# --- t, zeta: 7.063e-01, 1.875e-03 ---
#
# --- t, zeta: 7.074e-01, 1.875e-03 ---
#
# --- t, zeta: 7.085e-01, 1.875e-03 ---
#
# --- t, zeta: 7.096e-01, 1.875e-03 ---
#
# --- t, zeta: 7.107e-01, 1.875e-03 ---
#
# --- t, zeta: 7.118e-01, 1.875e-03 ---
#
# --- t, zeta: 7.129e-01, 1.875e-03 ---
#
# --- t, zeta: 7.140e-01, 1.875e-03 ---
#
# --- t, zeta: 7.151e-01, 1.875e-03 ---
#
# --- t, zeta: 7.162e-01, 1.875e-03 ---
#
# --- t, zeta: 7.173e-01, 1.875e-03 ---
#
# --- t, zeta: 7.184e-01, 1.875e-03 ---
#
# --- t, zeta: 7.195e-01, 1.875e-03 ---
#
# --- t, zeta: 7.206e-01, 1.875e-03 ---
#
# --- t, zeta: 7.217e-01, 1.875e-03 ---
#
# --- t, zeta: 7.228e-01, 1.875e-03 ---
#
# --- t, zeta: 7.239e-01, 1.875e-03 ---
#
# --- t, zeta: 7.250e-01, 1.875e-03 ---
#
# --- t, zeta: 7.261e-01, 1.875e-03 ---
#
# --- t, zeta: 7.272e-01, 1.875e-03 ---
#
# --- t, zeta: 7.283e-01, 1.875e-03 ---
#
# --- t, zeta: 7.294e-01, 1.875e-03 ---
#
# --- t, zeta: 7.305e-01, 1.875e-03 ---
#
# --- t, zeta: 7.316e-01, 1.875e-03 ---
#
# --- t, zeta: 7.327e-01, 1.875e-03 ---
#
# --- t, zeta: 7.338e-01, 1.875e-03 ---
#
# --- t, zeta: 7.349e-01, 1.875e-03 ---
#
# --- t, zeta: 7.360e-01, 1.875e-03 ---
#
# --- t, zeta: 7.371e-01, 1.875e-03 ---
#
# --- t, zeta: 7.382e-01, 1.875e-03 ---
#
# --- t, zeta: 7.393e-01, 1.875e-03 ---
#
# --- t, zeta: 7.404e-01, 1.875e-03 ---
#
# --- t, zeta: 7.415e-01, 1.875e-03 ---
#
# --- t, zeta: 7.426e-01, 1.875e-03 ---
#
# --- t, zeta: 7.437e-01, 1.875e-03 ---
#
# --- t, zeta: 7.448e-01, 1.875e-03 ---
#
# --- t, zeta: 7.459e-01, 1.875e-03 ---
#
# --- t, zeta: 7.470e-01, 1.875e-03 ---
#
# --- t, zeta: 7.481e-01, 1.875e-03 ---
#
# --- t, zeta: 7.492e-01, 1.875e-03 ---
#
# --- t, zeta: 7.503e-01, 1.875e-03 ---
#
# --- t, zeta: 7.514e-01, 1.875e-03 ---
#
# --- t, zeta: 7.525e-01, 1.875e-03 ---
#
# --- t, zeta: 7.536e-01, 1.875e-03 ---
#
# --- t, zeta: 7.547e-01, 1.875e-03 ---
#
# --- t, zeta: 7.558e-01, 1.875e-03 ---
#
# --- t, zeta: 7.569e-01, 1.875e-03 ---
#
# --- t, zeta: 7.580e-01, 1.875e-03 ---
#
# --- t, zeta: 7.591e-01, 1.875e-03 ---
#
# --- t, zeta: 7.602e-01, 1.875e-03 ---
#
# --- t, zeta: 7.613e-01, 1.875e-03 ---
#
# --- t, zeta: 7.624e-01, 1.875e-03 ---
#
# --- t, zeta: 7.635e-01, 1.875e-03 ---
#
# --- t, zeta: 7.646e-01, 1.875e-03 ---
#
# --- t, zeta: 7.657e-01, 1.875e-03 ---
#
# --- t, zeta: 7.668e-01, 1.875e-03 ---
#
# --- t, zeta: 7.679e-01, 1.875e-03 ---
#
# --- t, zeta: 7.690e-01, 1.875e-03 ---
#
# --- t, zeta: 7.701e-01, 1.875e-03 ---
#
# --- t, zeta: 7.712e-01, 1.875e-03 ---
#
# --- t, zeta: 7.723e-01, 1.875e-03 ---
#
# --- t, zeta: 7.734e-01, 1.875e-03 ---
#
# --- t, zeta: 7.745e-01, 1.875e-03 ---
#
# --- t, zeta: 7.756e-01, 1.875e-03 ---
#
# --- t, zeta: 7.767e-01, 1.875e-03 ---
#
# --- t, zeta: 7.778e-01, 1.875e-03 ---
#
# --- t, zeta: 7.789e-01, 1.875e-03 ---
#
# --- t, zeta: 7.800e-01, 1.875e-03 ---
#
# --- t, zeta: 7.811e-01, 1.875e-03 ---
#
# --- t, zeta: 7.822e-01, 1.875e-03 ---
#
# --- t, zeta: 7.833e-01, 1.875e-03 ---
#
# --- t, zeta: 7.844e-01, 1.875e-03 ---
#
# --- t, zeta: 7.855e-01, 1.875e-03 ---
#
# --- t, zeta: 7.866e-01, 1.875e-03 ---
#
# --- t, zeta: 7.877e-01, 1.875e-03 ---
#
# --- t, zeta: 7.888e-01, 1.875e-03 ---
#
# --- t, zeta: 7.899e-01, 1.875e-03 ---
#
# --- t, zeta: 7.910e-01, 1.875e-03 ---
#
# --- t, zeta: 7.921e-01, 1.875e-03 ---
#
# --- t, zeta: 7.932e-01, 1.875e-03 ---
#
# --- t, zeta: 7.943e-01, 1.875e-03 ---
#
# --- t, zeta: 7.954e-01, 1.875e-03 ---
#
# --- t, zeta: 7.965e-01, 1.875e-03 ---
#
# --- t, zeta: 7.976e-01, 1.875e-03 ---
#
# --- t, zeta: 7.987e-01, 1.875e-03 ---
#
# --- t, zeta: 7.998e-01, 1.875e-03 ---
#
# --- t, zeta: 8.009e-01, 1.875e-03 ---
#
# --- t, zeta: 8.020e-01, 1.875e-03 ---
#
# --- t, zeta: 8.031e-01, 1.875e-03 ---
#
# --- t, zeta: 8.042e-01, 1.875e-03 ---
#
# --- t, zeta: 8.053e-01, 1.875e-03 ---
#
# --- t, zeta: 8.064e-01, 1.875e-03 ---
#
# --- t, zeta: 8.075e-01, 1.875e-03 ---
#
# --- t, zeta: 8.086e-01, 1.875e-03 ---
#
# --- t, zeta: 8.097e-01, 1.875e-03 ---
#
# --- t, zeta: 8.108e-01, 1.875e-03 ---
#
# --- t, zeta: 8.119e-01, 1.875e-03 ---
#
# --- t, zeta: 8.130e-01, 1.875e-03 ---
#
# --- t, zeta: 8.141e-01, 1.875e-03 ---
#
# --- t, zeta: 8.152e-01, 1.875e-03 ---
#
# --- t, zeta: 8.163e-01, 1.875e-03 ---
#
# --- t, zeta: 8.174e-01, 1.875e-03 ---
#
# --- t, zeta: 8.185e-01, 1.875e-03 ---
#
# --- t, zeta: 8.196e-01, 1.875e-03 ---
#
# --- t, zeta: 8.207e-01, 1.875e-03 ---
#
# --- t, zeta: 8.218e-01, 1.875e-03 ---
#
# --- t, zeta: 8.229e-01, 1.875e-03 ---
#
# --- t, zeta: 8.240e-01, 1.875e-03 ---
#
# --- t, zeta: 8.251e-01, 1.875e-03 ---
#
# --- t, zeta: 8.262e-01, 1.875e-03 ---
#
# --- t, zeta: 8.273e-01, 1.875e-03 ---
#
# --- t, zeta: 8.284e-01, 1.875e-03 ---
#
# --- t, zeta: 8.295e-01, 1.875e-03 ---
#
# --- t, zeta: 8.306e-01, 1.875e-03 ---
#
# --- t, zeta: 8.317e-01, 1.875e-03 ---
#
# --- t, zeta: 8.328e-01, 1.875e-03 ---
#
# --- t, zeta: 8.339e-01, 1.875e-03 ---
#
# --- t, zeta: 8.350e-01, 1.875e-03 ---
#
# --- t, zeta: 8.361e-01, 1.875e-03 ---
#
# --- t, zeta: 8.372e-01, 1.875e-03 ---
#
# --- t, zeta: 8.383e-01, 1.875e-03 ---
#
# --- t, zeta: 8.394e-01, 1.875e-03 ---
#
# --- t, zeta: 8.405e-01, 1.875e-03 ---
#
# --- t, zeta: 8.416e-01, 1.875e-03 ---
#
# --- t, zeta: 8.427e-01, 1.875e-03 ---
#
# --- t, zeta: 8.438e-01, 1.875e-03 ---
#
# --- t, zeta: 8.449e-01, 1.875e-03 ---
#
# --- t, zeta: 8.460e-01, 1.875e-03 ---
#
# --- t, zeta: 8.471e-01, 1.875e-03 ---
#
# --- t, zeta: 8.482e-01, 1.875e-03 ---
#
# --- t, zeta: 8.493e-01, 1.875e-03 ---
#
# --- t, zeta: 8.504e-01, 1.875e-03 ---
#
# --- t, zeta: 8.515e-01, 1.875e-03 ---
#
# --- t, zeta: 8.526e-01, 1.875e-03 ---
#
# --- t, zeta: 8.537e-01, 1.875e-03 ---
#
# --- t, zeta: 8.548e-01, 1.875e-03 ---
#
# --- t, zeta: 8.559e-01, 1.875e-03 ---
#
# --- t, zeta: 8.570e-01, 1.875e-03 ---
#
# --- t, zeta: 8.581e-01, 1.875e-03 ---
#
# --- t, zeta: 8.592e-01, 1.875e-03 ---
#
# --- t, zeta: 8.603e-01, 1.875e-03 ---
#
# --- t, zeta: 8.614e-01, 1.875e-03 ---
#
# --- t, zeta: 8.625e-01, 1.875e-03 ---
#
# --- t, zeta: 8.636e-01, 1.875e-03 ---
#
# --- t, zeta: 8.647e-01, 1.875e-03 ---
#
# --- t, zeta: 8.658e-01, 1.875e-03 ---
#
# --- t, zeta: 8.669e-01, 1.875e-03 ---
#
# --- t, zeta: 8.680e-01, 1.875e-03 ---
#
# --- t, zeta: 8.691e-01, 1.875e-03 ---
#
# --- t, zeta: 8.702e-01, 1.875e-03 ---
#
# --- t, zeta: 8.713e-01, 1.875e-03 ---
#
# --- t, zeta: 8.724e-01, 1.875e-03 ---
#
# --- t, zeta: 8.735e-01, 1.875e-03 ---
#
# --- t, zeta: 8.746e-01, 1.875e-03 ---
#
# --- t, zeta: 8.757e-01, 1.875e-03 ---
#
# --- t, zeta: 8.768e-01, 1.875e-03 ---
#
# --- t, zeta: 8.779e-01, 1.875e-03 ---
#
# --- t, zeta: 8.790e-01, 1.875e-03 ---
#
# --- t, zeta: 8.801e-01, 1.875e-03 ---
#
# --- t, zeta: 8.812e-01, 1.875e-03 ---
#
# --- t, zeta: 8.823e-01, 1.875e-03 ---
#
# --- t, zeta: 8.834e-01, 1.875e-03 ---
#
# --- t, zeta: 8.845e-01, 1.875e-03 ---
#
# --- t, zeta: 8.856e-01, 1.875e-03 ---
#
# --- t, zeta: 8.867e-01, 1.875e-03 ---
#
# --- t, zeta: 8.878e-01, 1.875e-03 ---
#
# --- t, zeta: 8.889e-01, 1.875e-03 ---
#
# --- t, zeta: 8.900e-01, 1.875e-03 ---
#
# --- t, zeta: 8.911e-01, 1.875e-03 ---
#
# --- t, zeta: 8.922e-01, 1.875e-03 ---
#
# --- t, zeta: 8.933e-01, 1.875e-03 ---
#
# --- t, zeta: 8.944e-01, 1.875e-03 ---
#
# --- t, zeta: 8.955e-01, 1.875e-03 ---
#
# --- t, zeta: 8.966e-01, 1.875e-03 ---
#
# --- t, zeta: 8.977e-01, 1.875e-03 ---
#
# --- t, zeta: 8.988e-01, 1.875e-03 ---
#
# --- t, zeta: 8.999e-01, 1.875e-03 ---
#
# --- t, zeta: 9.010e-01, 1.875e-03 ---
#
# --- t, zeta: 9.021e-01, 1.875e-03 ---
#
# --- t, zeta: 9.032e-01, 1.875e-03 ---
#
# --- t, zeta: 9.043e-01, 1.875e-03 ---
#
# --- t, zeta: 9.054e-01, 1.875e-03 ---
#
# --- t, zeta: 9.065e-01, 1.875e-03 ---
#
# --- t, zeta: 9.076e-01, 1.875e-03 ---
#
# --- t, zeta: 9.087e-01, 1.875e-03 ---
#
# --- t, zeta: 9.098e-01, 1.875e-03 ---
#
# --- t, zeta: 9.109e-01, 1.875e-03 ---
#
# --- t, zeta: 9.120e-01, 1.875e-03 ---
#
# --- t, zeta: 9.131e-01, 1.875e-03 ---
#
# --- t, zeta: 9.142e-01, 1.875e-03 ---
#
# --- t, zeta: 9.153e-01, 1.875e-03 ---
#
# --- t, zeta: 9.164e-01, 1.875e-03 ---
#
# --- t, zeta: 9.175e-01, 1.875e-03 ---
#
# --- t, zeta: 9.186e-01, 1.875e-03 ---
#
# --- t, zeta: 9.197e-01, 1.875e-03 ---
#
# --- t, zeta: 9.208e-01, 1.875e-03 ---
#
# --- t, zeta: 9.219e-01, 1.875e-03 ---
#
# --- t, zeta: 9.230e-01, 1.875e-03 ---
#
# --- t, zeta: 9.241e-01, 1.875e-03 ---
#
# --- t, zeta: 9.252e-01, 1.875e-03 ---
#
# --- t, zeta: 9.263e-01, 1.875e-03 ---
#
# --- t, zeta: 9.274e-01, 1.875e-03 ---
#
# --- t, zeta: 9.285e-01, 1.875e-03 ---
#
# --- t, zeta: 9.296e-01, 1.875e-03 ---
#
# --- t, zeta: 9.307e-01, 1.875e-03 ---
#
# --- t, zeta: 9.318e-01, 1.875e-03 ---
#
# --- t, zeta: 9.329e-01, 1.875e-03 ---
#
# --- t, zeta: 9.340e-01, 1.875e-03 ---
#
# --- t, zeta: 9.351e-01, 1.875e-03 ---
#
# --- t, zeta: 9.362e-01, 1.875e-03 ---
#
# --- t, zeta: 9.373e-01, 1.875e-03 ---
#
# --- t, zeta: 9.384e-01, 1.875e-03 ---
#
# --- t, zeta: 9.395e-01, 1.875e-03 ---
#
# --- t, zeta: 9.406e-01, 1.875e-03 ---
#
# --- t, zeta: 9.417e-01, 1.875e-03 ---
#
# --- t, zeta: 9.428e-01, 1.875e-03 ---
#
# --- t, zeta: 9.439e-01, 1.875e-03 ---
#
# --- t, zeta: 9.450e-01, 1.875e-03 ---
#
# --- t, zeta: 9.461e-01, 1.875e-03 ---
#
# --- t, zeta: 9.472e-01, 1.875e-03 ---
#
# --- t, zeta: 9.483e-01, 1.875e-03 ---
#
# --- t, zeta: 9.494e-01, 1.875e-03 ---
#
# --- t, zeta: 9.505e-01, 1.875e-03 ---
#
# --- t, zeta: 9.516e-01, 1.875e-03 ---
#
# --- t, zeta: 9.527e-01, 1.875e-03 ---
#
# --- t, zeta: 9.538e-01, 1.875e-03 ---
#
# --- t, zeta: 9.549e-01, 1.875e-03 ---
#
# --- t, zeta: 9.560e-01, 1.875e-03 ---
#
# --- t, zeta: 9.571e-01, 1.875e-03 ---
#
# --- t, zeta: 9.582e-01, 1.875e-03 ---
#
# --- t, zeta: 9.593e-01, 1.875e-03 ---
#
# --- t, zeta: 9.604e-01, 1.875e-03 ---
#
# --- t, zeta: 9.615e-01, 1.875e-03 ---
#
# --- t, zeta: 9.626e-01, 1.875e-03 ---
#
# --- t, zeta: 9.637e-01, 1.875e-03 ---
#
# --- t, zeta: 9.648e-01, 1.875e-03 ---
#
# --- t, zeta: 9.659e-01, 1.875e-03 ---
#
# --- t, zeta: 9.670e-01, 1.875e-03 ---
#
# --- t, zeta: 9.681e-01, 1.875e-03 ---
#
# --- t, zeta: 9.692e-01, 1.875e-03 ---
#
# --- t, zeta: 9.703e-01, 1.875e-03 ---
#
# --- t, zeta: 9.714e-01, 1.875e-03 ---
#
# --- t, zeta: 9.725e-01, 1.875e-03 ---
#
# --- t, zeta: 9.736e-01, 1.875e-03 ---
#
# --- t, zeta: 9.747e-01, 1.875e-03 ---
#
# --- t, zeta: 9.758e-01, 1.875e-03 ---
#
# --- t, zeta: 9.769e-01, 1.875e-03 ---
#
# --- t, zeta: 9.780e-01, 1.875e-03 ---
#
# --- t, zeta: 9.791e-01, 1.875e-03 ---
#
# --- t, zeta: 9.802e-01, 1.875e-03 ---
#
# --- t, zeta: 9.813e-01, 1.875e-03 ---
#
# --- t, zeta: 9.824e-01, 1.875e-03 ---
#
# --- t, zeta: 9.835e-01, 1.875e-03 ---
#
# --- t, zeta: 9.846e-01, 1.875e-03 ---
#
# --- t, zeta: 9.857e-01, 1.875e-03 ---
#
# --- t, zeta: 9.868e-01, 1.875e-03 ---
#
# --- t, zeta: 9.879e-01, 1.875e-03 ---
#
# --- t, zeta: 9.890e-01, 1.875e-03 ---
#
# --- t, zeta: 9.901e-01, 1.875e-03 ---
#
# --- t, zeta: 9.912e-01, 1.875e-03 ---
#
# --- t, zeta: 9.923e-01, 1.875e-03 ---
#
# --- t, zeta: 9.934e-01, 1.875e-03 ---
#
# --- t, zeta: 9.945e-01, 1.875e-03 ---
#
# --- t, zeta: 9.956e-01, 1.875e-03 ---
#
# --- t, zeta: 9.967e-01, 1.875e-03 ---
#
# --- t, zeta: 9.978e-01, 1.875e-03 ---
#
# --- t, zeta: 9.989e-01, 1.875e-03 ---
#
# --- t, zeta: 1.000e+00, 1.875e-03 ---
#
# --- t, zeta: 1.001e+00, 1.875e-03 ---
#
# --- t, zeta: 1.002e+00, 1.875e-03 ---
#
# --- t, zeta: 1.003e+00, 1.875e-03 ---
#
# --- t, zeta: 1.004e+00, 1.875e-03 ---
#
# --- t, zeta: 1.005e+00, 1.875e-03 ---
#
# --- t, zeta: 1.007e+00, 1.875e-03 ---
#
# --- t, zeta: 1.008e+00, 1.875e-03 ---
#
# --- t, zeta: 1.009e+00, 1.875e-03 ---
#
# --- t, zeta: 1.010e+00, 1.875e-03 ---
#
# --- t, zeta: 1.011e+00, 1.875e-03 ---
#
# --- t, zeta: 1.012e+00, 1.875e-03 ---
#
# --- t, zeta: 1.013e+00, 1.875e-03 ---
#
# --- t, zeta: 1.014e+00, 1.875e-03 ---
#
# --- t, zeta: 1.015e+00, 1.875e-03 ---
#
# --- t, zeta: 1.016e+00, 1.875e-03 ---
#
# --- t, zeta: 1.018e+00, 1.875e-03 ---
#
# --- t, zeta: 1.019e+00, 1.875e-03 ---
#
# --- t, zeta: 1.020e+00, 1.875e-03 ---
#
# --- t, zeta: 1.021e+00, 1.875e-03 ---
#
# --- t, zeta: 1.022e+00, 1.875e-03 ---
#
# --- t, zeta: 1.023e+00, 1.875e-03 ---
#
# --- t, zeta: 1.024e+00, 1.875e-03 ---
#
# --- t, zeta: 1.025e+00, 1.875e-03 ---
#
# --- t, zeta: 1.026e+00, 1.875e-03 ---
#
# --- t, zeta: 1.027e+00, 1.875e-03 ---
#
# --- t, zeta: 1.029e+00, 1.875e-03 ---
#
# --- t, zeta: 1.030e+00, 1.875e-03 ---
#
# --- t, zeta: 1.031e+00, 1.875e-03 ---
#
# --- t, zeta: 1.032e+00, 1.875e-03 ---
#
# --- t, zeta: 1.033e+00, 1.875e-03 ---
#
# --- t, zeta: 1.034e+00, 1.875e-03 ---
#
# --- t, zeta: 1.035e+00, 1.875e-03 ---
#
# --- t, zeta: 1.036e+00, 1.875e-03 ---
#
# --- t, zeta: 1.037e+00, 1.875e-03 ---
#
# --- t, zeta: 1.038e+00, 1.875e-03 ---
#
# --- t, zeta: 1.040e+00, 1.875e-03 ---
#
# --- t, zeta: 1.041e+00, 1.875e-03 ---
#
# --- t, zeta: 1.042e+00, 1.875e-03 ---
#
# --- t, zeta: 1.043e+00, 1.875e-03 ---
#
# --- t, zeta: 1.044e+00, 1.875e-03 ---
#
# --- t, zeta: 1.045e+00, 1.875e-03 ---
#
# --- t, zeta: 1.046e+00, 1.875e-03 ---
#
# --- t, zeta: 1.047e+00, 1.875e-03 ---
#
# --- t, zeta: 1.048e+00, 1.875e-03 ---
#
# --- t, zeta: 1.049e+00, 1.875e-03 ---
#
# --- t, zeta: 1.051e+00, 1.875e-03 ---
#
# --- t, zeta: 1.052e+00, 1.875e-03 ---
#
# --- t, zeta: 1.053e+00, 1.875e-03 ---
#
# --- t, zeta: 1.054e+00, 1.875e-03 ---
#
# --- t, zeta: 1.055e+00, 1.875e-03 ---
#
# --- t, zeta: 1.056e+00, 1.875e-03 ---
#
# --- t, zeta: 1.057e+00, 1.875e-03 ---
#
# --- t, zeta: 1.058e+00, 1.875e-03 ---
#
# --- t, zeta: 1.059e+00, 1.875e-03 ---
#
# --- t, zeta: 1.060e+00, 1.875e-03 ---
#
# --- t, zeta: 1.062e+00, 1.875e-03 ---
#
# --- t, zeta: 1.063e+00, 1.875e-03 ---
#
# --- t, zeta: 1.064e+00, 1.875e-03 ---
#
# --- t, zeta: 1.065e+00, 1.875e-03 ---
#
# --- t, zeta: 1.066e+00, 1.875e-03 ---
#
# --- t, zeta: 1.067e+00, 1.875e-03 ---
#
# --- t, zeta: 1.068e+00, 1.875e-03 ---
#
# --- t, zeta: 1.069e+00, 1.875e-03 ---
#
# --- t, zeta: 1.070e+00, 1.875e-03 ---
#
# --- t, zeta: 1.071e+00, 1.875e-03 ---
#
# --- t, zeta: 1.073e+00, 1.875e-03 ---
#
# --- t, zeta: 1.074e+00, 1.875e-03 ---
#
# --- t, zeta: 1.075e+00, 1.875e-03 ---
#
# --- t, zeta: 1.076e+00, 1.875e-03 ---
#
# --- t, zeta: 1.077e+00, 1.875e-03 ---
#
# --- t, zeta: 1.078e+00, 1.875e-03 ---
#
# --- t, zeta: 1.079e+00, 1.875e-03 ---
#
# --- t, zeta: 1.080e+00, 1.875e-03 ---
#
# --- t, zeta: 1.081e+00, 1.875e-03 ---
#
# --- t, zeta: 1.082e+00, 1.875e-03 ---
#
# --- t, zeta: 1.084e+00, 1.875e-03 ---
#
# --- t, zeta: 1.085e+00, 1.875e-03 ---
#
# --- t, zeta: 1.086e+00, 1.875e-03 ---
#
# --- t, zeta: 1.087e+00, 1.875e-03 ---
#
# --- t, zeta: 1.088e+00, 1.875e-03 ---
#
# --- t, zeta: 1.089e+00, 1.875e-03 ---
#
# --- t, zeta: 1.090e+00, 1.875e-03 ---
#
# --- t, zeta: 1.091e+00, 1.875e-03 ---
#
# --- t, zeta: 1.092e+00, 1.875e-03 ---
#
# --- t, zeta: 1.093e+00, 1.875e-03 ---
#
# --- t, zeta: 1.095e+00, 1.875e-03 ---
#
# --- t, zeta: 1.096e+00, 1.875e-03 ---
#
# --- t, zeta: 1.097e+00, 1.875e-03 ---
#
# --- t, zeta: 1.098e+00, 1.875e-03 ---
#
# --- t, zeta: 1.099e+00, 1.875e-03 ---
#
# --- t, zeta: 1.100e+00, 1.875e-03 ---
#
# --- t, zeta: 1.101e+00, 1.875e-03 ---
#
# --- t, zeta: 1.102e+00, 1.875e-03 ---
#
# --- t, zeta: 1.103e+00, 1.875e-03 ---
#
# --- t, zeta: 1.104e+00, 1.875e-03 ---
#
# --- t, zeta: 1.106e+00, 1.875e-03 ---
#
# --- t, zeta: 1.107e+00, 1.875e-03 ---
#
# --- t, zeta: 1.108e+00, 1.875e-03 ---
#
# --- t, zeta: 1.109e+00, 1.875e-03 ---
#
# --- t, zeta: 1.110e+00, 1.875e-03 ---
#
# --- t, zeta: 1.111e+00, 1.875e-03 ---
#
# --- t, zeta: 1.112e+00, 1.875e-03 ---
#
# --- t, zeta: 1.113e+00, 1.875e-03 ---
#
# --- t, zeta: 1.114e+00, 1.875e-03 ---
#
# --- t, zeta: 1.115e+00, 1.875e-03 ---
#
# --- t, zeta: 1.117e+00, 1.875e-03 ---
#
# --- t, zeta: 1.118e+00, 1.875e-03 ---
#
# --- t, zeta: 1.119e+00, 1.875e-03 ---
#
# --- t, zeta: 1.120e+00, 1.875e-03 ---
#
# --- t, zeta: 1.121e+00, 1.875e-03 ---
#
# --- t, zeta: 1.122e+00, 1.875e-03 ---
#
# --- t, zeta: 1.123e+00, 1.875e-03 ---
#
# --- t, zeta: 1.124e+00, 1.875e-03 ---
#
# --- t, zeta: 1.125e+00, 1.875e-03 ---
#
# --- t, zeta: 1.126e+00, 1.875e-03 ---
#
# --- t, zeta: 1.128e+00, 1.875e-03 ---
#
# --- t, zeta: 1.129e+00, 1.875e-03 ---
#
# --- t, zeta: 1.130e+00, 1.875e-03 ---
#
# --- t, zeta: 1.131e+00, 1.875e-03 ---
#
# --- t, zeta: 1.132e+00, 1.875e-03 ---
#
# --- t, zeta: 1.133e+00, 1.875e-03 ---
#
# --- t, zeta: 1.134e+00, 1.875e-03 ---
#
# --- t, zeta: 1.135e+00, 1.875e-03 ---
#
# --- t, zeta: 1.136e+00, 1.875e-03 ---
#
# --- t, zeta: 1.137e+00, 1.875e-03 ---
#
# --- t, zeta: 1.139e+00, 1.875e-03 ---
#
# --- t, zeta: 1.140e+00, 1.875e-03 ---
#
# --- t, zeta: 1.141e+00, 1.875e-03 ---
#
# --- t, zeta: 1.142e+00, 1.875e-03 ---
#
# --- t, zeta: 1.143e+00, 1.875e-03 ---
#
# --- t, zeta: 1.144e+00, 1.875e-03 ---
#
# --- t, zeta: 1.145e+00, 1.875e-03 ---
#
# --- t, zeta: 1.146e+00, 1.875e-03 ---
#
# --- t, zeta: 1.147e+00, 1.875e-03 ---
#
# --- t, zeta: 1.148e+00, 1.875e-03 ---
#
# --- t, zeta: 1.150e+00, 1.875e-03 ---
#
# --- t, zeta: 1.151e+00, 1.875e-03 ---
#
# --- t, zeta: 1.152e+00, 1.875e-03 ---
#
# --- t, zeta: 1.153e+00, 1.875e-03 ---
#
# --- t, zeta: 1.154e+00, 1.875e-03 ---
#
# --- t, zeta: 1.155e+00, 1.875e-03 ---
#
# --- t, zeta: 1.156e+00, 1.875e-03 ---
#
# --- t, zeta: 1.157e+00, 1.875e-03 ---
#
# --- t, zeta: 1.158e+00, 1.875e-03 ---
#
# --- t, zeta: 1.159e+00, 1.875e-03 ---
#
# --- t, zeta: 1.161e+00, 1.875e-03 ---
#
# --- t, zeta: 1.162e+00, 1.875e-03 ---
#
# --- t, zeta: 1.163e+00, 1.875e-03 ---
#
# --- t, zeta: 1.164e+00, 1.875e-03 ---
#
# --- t, zeta: 1.165e+00, 1.875e-03 ---
#
# --- t, zeta: 1.166e+00, 1.875e-03 ---
#
# --- t, zeta: 1.167e+00, 1.875e-03 ---
#
# --- t, zeta: 1.168e+00, 1.875e-03 ---
#
# --- t, zeta: 1.169e+00, 1.875e-03 ---
#
# --- t, zeta: 1.170e+00, 1.875e-03 ---
#
# --- t, zeta: 1.172e+00, 1.875e-03 ---
#
# --- t, zeta: 1.173e+00, 1.875e-03 ---
#
# --- t, zeta: 1.174e+00, 1.875e-03 ---
#
# --- t, zeta: 1.175e+00, 1.875e-03 ---
#
# --- t, zeta: 1.176e+00, 1.875e-03 ---
#
# --- t, zeta: 1.177e+00, 1.875e-03 ---
#
# --- t, zeta: 1.178e+00, 1.875e-03 ---
#
# --- t, zeta: 1.179e+00, 1.875e-03 ---
#
# --- t, zeta: 1.180e+00, 1.875e-03 ---
#
# --- t, zeta: 1.181e+00, 1.875e-03 ---
#
# --- t, zeta: 1.183e+00, 1.875e-03 ---
#
# --- t, zeta: 1.184e+00, 1.875e-03 ---
#
# --- t, zeta: 1.185e+00, 1.875e-03 ---
#
# --- t, zeta: 1.186e+00, 1.875e-03 ---
#
# --- t, zeta: 1.187e+00, 1.875e-03 ---
#
# --- t, zeta: 1.188e+00, 1.875e-03 ---
#
# --- t, zeta: 1.189e+00, 1.875e-03 ---
#
# --- t, zeta: 1.190e+00, 1.875e-03 ---
#
# --- t, zeta: 1.191e+00, 1.875e-03 ---
#
# --- t, zeta: 1.192e+00, 1.875e-03 ---
#
# --- t, zeta: 1.194e+00, 1.875e-03 ---
#
# --- t, zeta: 1.195e+00, 1.875e-03 ---
#
# --- t, zeta: 1.196e+00, 1.875e-03 ---
#
# --- t, zeta: 1.197e+00, 1.875e-03 ---
#
# --- t, zeta: 1.198e+00, 1.875e-03 ---
#
# --- t, zeta: 1.199e+00, 1.875e-03 ---
#
# --- t, zeta: 1.200e+00, 1.875e-03 ---
#
# --- t, zeta: 1.201e+00, 1.875e-03 ---
#
# --- t, zeta: 1.202e+00, 1.875e-03 ---
#
# --- t, zeta: 1.203e+00, 1.875e-03 ---
#
# --- t, zeta: 1.205e+00, 1.875e-03 ---
#
# --- t, zeta: 1.206e+00, 1.875e-03 ---
#
# --- t, zeta: 1.207e+00, 1.875e-03 ---
#
# --- t, zeta: 1.208e+00, 1.875e-03 ---
#
# --- t, zeta: 1.209e+00, 1.875e-03 ---
#
# --- t, zeta: 1.210e+00, 1.875e-03 ---
#
# --- t, zeta: 1.211e+00, 1.875e-03 ---
#
# --- t, zeta: 1.212e+00, 1.875e-03 ---
#
# --- t, zeta: 1.213e+00, 1.875e-03 ---
#
# --- t, zeta: 1.214e+00, 1.875e-03 ---
#
# --- t, zeta: 1.216e+00, 1.875e-03 ---
#
# --- t, zeta: 1.217e+00, 1.875e-03 ---
#
# --- t, zeta: 1.218e+00, 1.875e-03 ---
#
# --- t, zeta: 1.219e+00, 1.875e-03 ---
#
# --- t, zeta: 1.220e+00, 1.875e-03 ---
#
# --- t, zeta: 1.221e+00, 1.875e-03 ---
#
# --- t, zeta: 1.222e+00, 1.875e-03 ---
#
# --- t, zeta: 1.223e+00, 1.875e-03 ---
#
# --- t, zeta: 1.224e+00, 1.875e-03 ---
#
# --- t, zeta: 1.225e+00, 1.875e-03 ---
#
# --- t, zeta: 1.227e+00, 1.875e-03 ---
#
# --- t, zeta: 1.228e+00, 1.875e-03 ---
#
# --- t, zeta: 1.229e+00, 1.875e-03 ---
#
# --- t, zeta: 1.230e+00, 1.875e-03 ---
#
# --- t, zeta: 1.231e+00, 1.875e-03 ---
#
# --- t, zeta: 1.232e+00, 1.875e-03 ---
#
# --- t, zeta: 1.233e+00, 1.875e-03 ---
#
# --- t, zeta: 1.234e+00, 1.875e-03 ---
#
# --- t, zeta: 1.235e+00, 1.875e-03 ---
#
# --- t, zeta: 1.236e+00, 1.875e-03 ---
#
# --- t, zeta: 1.238e+00, 1.875e-03 ---
#
# --- t, zeta: 1.239e+00, 1.875e-03 ---
#
# --- t, zeta: 1.240e+00, 1.875e-03 ---
#
# --- t, zeta: 1.241e+00, 1.875e-03 ---
#
# --- t, zeta: 1.242e+00, 1.875e-03 ---
#
# --- t, zeta: 1.243e+00, 1.875e-03 ---
#
# --- t, zeta: 1.244e+00, 1.875e-03 ---
#
# --- t, zeta: 1.245e+00, 1.875e-03 ---
#
# --- t, zeta: 1.246e+00, 1.875e-03 ---
#
# --- t, zeta: 1.247e+00, 1.875e-03 ---
#
# --- t, zeta: 1.249e+00, 1.875e-03 ---
#
# --- t, zeta: 1.250e+00, 1.875e-03 ---
#
# --- t, zeta: 1.251e+00, 1.875e-03 ---
#
# --- t, zeta: 1.252e+00, 1.875e-03 ---
#
# --- t, zeta: 1.253e+00, 1.875e-03 ---
#
# --- t, zeta: 1.254e+00, 1.875e-03 ---
#
# --- t, zeta: 1.255e+00, 1.875e-03 ---
#
# --- t, zeta: 1.256e+00, 1.875e-03 ---
#
# --- t, zeta: 1.257e+00, 1.875e-03 ---
#
# --- t, zeta: 1.258e+00, 1.875e-03 ---
#
# --- t, zeta: 1.260e+00, 1.875e-03 ---
#
# --- t, zeta: 1.261e+00, 1.875e-03 ---
#
# --- t, zeta: 1.262e+00, 1.875e-03 ---
#
# --- t, zeta: 1.263e+00, 1.875e-03 ---
#
# --- t, zeta: 1.264e+00, 1.875e-03 ---
#
# --- t, zeta: 1.265e+00, 1.875e-03 ---
#
# --- t, zeta: 1.266e+00, 1.875e-03 ---
#
# --- t, zeta: 1.267e+00, 1.875e-03 ---
#
# --- t, zeta: 1.268e+00, 1.875e-03 ---
#
# --- t, zeta: 1.269e+00, 1.875e-03 ---
#
# --- t, zeta: 1.271e+00, 1.875e-03 ---
#
# --- t, zeta: 1.272e+00, 1.875e-03 ---
#
# --- t, zeta: 1.273e+00, 1.875e-03 ---
#
# --- t, zeta: 1.274e+00, 1.875e-03 ---
#
# --- t, zeta: 1.275e+00, 1.875e-03 ---
#
# --- t, zeta: 1.276e+00, 1.875e-03 ---
#
# --- t, zeta: 1.277e+00, 1.875e-03 ---
#
# --- t, zeta: 1.278e+00, 1.875e-03 ---
#
# --- t, zeta: 1.279e+00, 1.875e-03 ---
#
# --- t, zeta: 1.280e+00, 1.875e-03 ---
#
# --- t, zeta: 1.282e+00, 1.875e-03 ---
#
# --- t, zeta: 1.283e+00, 1.875e-03 ---
#
# --- t, zeta: 1.284e+00, 1.875e-03 ---
#
# --- t, zeta: 1.285e+00, 1.875e-03 ---
#
# --- t, zeta: 1.286e+00, 1.875e-03 ---
#
# --- t, zeta: 1.287e+00, 1.875e-03 ---
#
# --- t, zeta: 1.288e+00, 1.875e-03 ---
#
# --- t, zeta: 1.289e+00, 1.875e-03 ---
#
# --- t, zeta: 1.290e+00, 1.875e-03 ---
#
# --- t, zeta: 1.291e+00, 1.875e-03 ---
#
# --- t, zeta: 1.293e+00, 1.875e-03 ---
#
# --- t, zeta: 1.294e+00, 1.875e-03 ---
#
# --- t, zeta: 1.295e+00, 1.875e-03 ---
#
# --- t, zeta: 1.296e+00, 1.875e-03 ---
#
# --- t, zeta: 1.297e+00, 1.875e-03 ---
#
# --- t, zeta: 1.298e+00, 1.875e-03 ---
#
# --- t, zeta: 1.299e+00, 1.875e-03 ---
#
# --- t, zeta: 1.300e+00, 1.875e-03 ---
#
# --- t, zeta: 1.301e+00, 1.875e-03 ---
#
# --- t, zeta: 1.302e+00, 1.875e-03 ---
#
# --- t, zeta: 1.304e+00, 1.875e-03 ---
#
# --- t, zeta: 1.305e+00, 1.875e-03 ---
#
# --- t, zeta: 1.306e+00, 1.875e-03 ---
#
# --- t, zeta: 1.307e+00, 1.875e-03 ---
#
# --- t, zeta: 1.308e+00, 1.875e-03 ---
#
# --- t, zeta: 1.309e+00, 1.875e-03 ---
#
# --- t, zeta: 1.310e+00, 1.875e-03 ---
#
# --- t, zeta: 1.311e+00, 1.875e-03 ---
#
# --- t, zeta: 1.312e+00, 1.875e-03 ---
#
# --- t, zeta: 1.313e+00, 1.875e-03 ---
#
# --- t, zeta: 1.315e+00, 1.875e-03 ---
#
# --- t, zeta: 1.316e+00, 1.875e-03 ---
#
# --- t, zeta: 1.317e+00, 1.875e-03 ---
#
# --- t, zeta: 1.318e+00, 1.875e-03 ---
#
# --- t, zeta: 1.319e+00, 1.875e-03 ---
#
# --- t, zeta: 1.320e+00, 1.875e-03 ---
#
# --- t, zeta: 1.321e+00, 1.875e-03 ---
#
# --- t, zeta: 1.322e+00, 1.875e-03 ---
#
# --- t, zeta: 1.323e+00, 1.875e-03 ---
#
# --- t, zeta: 1.324e+00, 1.875e-03 ---
#
# --- t, zeta: 1.326e+00, 1.875e-03 ---
#
# --- t, zeta: 1.327e+00, 1.875e-03 ---
#
# --- t, zeta: 1.328e+00, 1.875e-03 ---
#
# --- t, zeta: 1.329e+00, 1.875e-03 ---
#
# --- t, zeta: 1.330e+00, 1.875e-03 ---
#
# --- t, zeta: 1.331e+00, 1.875e-03 ---
#
# --- t, zeta: 1.332e+00, 1.875e-03 ---
#
# --- t, zeta: 1.333e+00, 1.875e-03 ---
#
# --- t, zeta: 1.334e+00, 1.875e-03 ---
#
# --- t, zeta: 1.335e+00, 1.875e-03 ---
#
# --- t, zeta: 1.337e+00, 1.875e-03 ---
#
# --- t, zeta: 1.338e+00, 1.875e-03 ---
#
# --- t, zeta: 1.339e+00, 1.875e-03 ---
#
# --- t, zeta: 1.340e+00, 1.875e-03 ---
#
# --- t, zeta: 1.341e+00, 1.875e-03 ---
#
# --- t, zeta: 1.342e+00, 1.875e-03 ---
#
# --- t, zeta: 1.343e+00, 1.875e-03 ---
#
# --- t, zeta: 1.344e+00, 1.875e-03 ---
#
# --- t, zeta: 1.345e+00, 1.875e-03 ---
#
# --- t, zeta: 1.346e+00, 1.875e-03 ---
#
# --- t, zeta: 1.348e+00, 1.875e-03 ---
#
# --- t, zeta: 1.349e+00, 1.875e-03 ---
#
# --- t, zeta: 1.350e+00, 1.875e-03 ---
#
# --- t, zeta: 1.351e+00, 1.875e-03 ---
#
# --- t, zeta: 1.352e+00, 1.875e-03 ---
#
# --- t, zeta: 1.353e+00, 1.875e-03 ---
#
# --- t, zeta: 1.354e+00, 1.875e-03 ---
#
# --- t, zeta: 1.355e+00, 1.875e-03 ---
#
# --- t, zeta: 1.356e+00, 1.875e-03 ---
#
# --- t, zeta: 1.357e+00, 1.875e-03 ---
#
# --- t, zeta: 1.359e+00, 1.875e-03 ---
#
# --- t, zeta: 1.360e+00, 1.875e-03 ---
#
# --- t, zeta: 1.361e+00, 1.875e-03 ---
#
# --- t, zeta: 1.362e+00, 1.875e-03 ---
#
# --- t, zeta: 1.363e+00, 1.875e-03 ---
#
# --- t, zeta: 1.364e+00, 1.875e-03 ---
#
# --- t, zeta: 1.365e+00, 1.875e-03 ---
#
# --- t, zeta: 1.366e+00, 1.875e-03 ---
#
# --- t, zeta: 1.367e+00, 1.875e-03 ---
#
# --- t, zeta: 1.368e+00, 1.875e-03 ---
#
# --- t, zeta: 1.370e+00, 1.875e-03 ---
#
# --- t, zeta: 1.371e+00, 1.875e-03 ---
#
# --- t, zeta: 1.372e+00, 1.875e-03 ---
#
# --- t, zeta: 1.373e+00, 1.875e-03 ---
#
# --- t, zeta: 1.374e+00, 1.875e-03 ---
#
# --- t, zeta: 1.375e+00, 1.875e-03 ---
#
# --- t, zeta: 1.376e+00, 1.875e-03 ---
#
# --- t, zeta: 1.377e+00, 1.875e-03 ---
#
# --- t, zeta: 1.378e+00, 1.875e-03 ---
#
# --- t, zeta: 1.379e+00, 1.875e-03 ---
#
# --- t, zeta: 1.381e+00, 1.875e-03 ---
#
# --- t, zeta: 1.382e+00, 1.875e-03 ---
#
# --- t, zeta: 1.383e+00, 1.875e-03 ---
#
# --- t, zeta: 1.384e+00, 1.875e-03 ---
#
# --- t, zeta: 1.385e+00, 1.875e-03 ---
#
# --- t, zeta: 1.386e+00, 1.875e-03 ---
#
# --- t, zeta: 1.387e+00, 1.875e-03 ---
#
# --- t, zeta: 1.388e+00, 1.875e-03 ---
#
# --- t, zeta: 1.389e+00, 1.875e-03 ---
#
# --- t, zeta: 1.390e+00, 1.875e-03 ---
#
# --- t, zeta: 1.392e+00, 1.875e-03 ---
#
# --- t, zeta: 1.393e+00, 1.875e-03 ---
#
# --- t, zeta: 1.394e+00, 1.875e-03 ---
#
# --- t, zeta: 1.395e+00, 1.875e-03 ---
#
# --- t, zeta: 1.396e+00, 1.875e-03 ---
#
# --- t, zeta: 1.397e+00, 1.875e-03 ---
#
# --- t, zeta: 1.398e+00, 1.875e-03 ---
#
# --- t, zeta: 1.399e+00, 1.875e-03 ---
#
# --- t, zeta: 1.400e+00, 1.875e-03 ---
#
# --- t, zeta: 1.401e+00, 1.875e-03 ---
#
# --- t, zeta: 1.403e+00, 1.875e-03 ---
#
# --- t, zeta: 1.404e+00, 1.875e-03 ---
#
# --- t, zeta: 1.405e+00, 1.875e-03 ---
#
# --- t, zeta: 1.406e+00, 1.875e-03 ---
#
# --- t, zeta: 1.407e+00, 1.875e-03 ---
#
# --- t, zeta: 1.408e+00, 1.875e-03 ---
#
# --- t, zeta: 1.409e+00, 1.875e-03 ---
#
# --- t, zeta: 1.410e+00, 1.875e-03 ---
#
# --- t, zeta: 1.411e+00, 1.875e-03 ---
#
# --- t, zeta: 1.412e+00, 1.875e-03 ---
#
# --- t, zeta: 1.414e+00, 1.875e-03 ---
#
# --- t, zeta: 1.415e+00, 1.875e-03 ---
#
# --- t, zeta: 1.416e+00, 1.875e-03 ---
#
# --- t, zeta: 1.417e+00, 1.875e-03 ---
#
# --- t, zeta: 1.418e+00, 1.875e-03 ---
#
# --- t, zeta: 1.419e+00, 1.875e-03 ---
#
# --- t, zeta: 1.420e+00, 1.875e-03 ---
#
# --- t, zeta: 1.421e+00, 1.875e-03 ---
#
# --- t, zeta: 1.422e+00, 1.875e-03 ---
#
# --- t, zeta: 1.423e+00, 1.875e-03 ---
#
# --- t, zeta: 1.425e+00, 1.875e-03 ---
#
# --- t, zeta: 1.426e+00, 1.875e-03 ---
#
# --- t, zeta: 1.427e+00, 1.875e-03 ---
#
# --- t, zeta: 1.428e+00, 1.875e-03 ---
#
# --- t, zeta: 1.429e+00, 1.875e-03 ---
#
# --- t, zeta: 1.430e+00, 1.875e-03 ---
#
# --- t, zeta: 1.431e+00, 1.875e-03 ---
#
# --- t, zeta: 1.432e+00, 1.875e-03 ---
#
# --- t, zeta: 1.433e+00, 1.875e-03 ---
#
# --- t, zeta: 1.434e+00, 1.875e-03 ---
#
# --- t, zeta: 1.436e+00, 1.875e-03 ---
#
# --- t, zeta: 1.437e+00, 1.875e-03 ---
#
# --- t, zeta: 1.438e+00, 1.875e-03 ---
#
# --- t, zeta: 1.439e+00, 1.875e-03 ---
#
# --- t, zeta: 1.440e+00, 1.875e-03 ---
#
# --- t, zeta: 1.441e+00, 1.875e-03 ---
#
# --- t, zeta: 1.442e+00, 1.875e-03 ---
#
# --- t, zeta: 1.443e+00, 1.875e-03 ---
#
# --- t, zeta: 1.444e+00, 1.875e-03 ---
#
# --- t, zeta: 1.445e+00, 1.875e-03 ---
#
# --- t, zeta: 1.447e+00, 1.875e-03 ---
#
# --- t, zeta: 1.448e+00, 1.875e-03 ---
#
# --- t, zeta: 1.449e+00, 1.875e-03 ---
#
# --- t, zeta: 1.450e+00, 1.875e-03 ---
#
# --- t, zeta: 1.451e+00, 1.875e-03 ---
#
# --- t, zeta: 1.452e+00, 1.875e-03 ---
#
# --- t, zeta: 1.453e+00, 1.875e-03 ---
#
# --- t, zeta: 1.454e+00, 1.875e-03 ---
#
# --- t, zeta: 1.455e+00, 1.875e-03 ---
#
# --- t, zeta: 1.456e+00, 1.875e-03 ---
#
# --- t, zeta: 1.458e+00, 1.875e-03 ---
#
# --- t, zeta: 1.459e+00, 1.875e-03 ---
#
# --- t, zeta: 1.460e+00, 1.875e-03 ---
#
# --- t, zeta: 1.461e+00, 1.875e-03 ---
#
# --- t, zeta: 1.462e+00, 1.875e-03 ---
#
# --- t, zeta: 1.463e+00, 1.875e-03 ---
#
# --- t, zeta: 1.464e+00, 1.875e-03 ---
#
# --- t, zeta: 1.465e+00, 1.875e-03 ---
#
# --- t, zeta: 1.466e+00, 1.875e-03 ---
#
# --- t, zeta: 1.467e+00, 1.875e-03 ---
#
# --- t, zeta: 1.469e+00, 1.875e-03 ---
#
# --- t, zeta: 1.470e+00, 1.875e-03 ---
#
# --- t, zeta: 1.471e+00, 1.875e-03 ---
#
# --- t, zeta: 1.472e+00, 1.875e-03 ---
#
# --- t, zeta: 1.473e+00, 1.875e-03 ---
#
# --- t, zeta: 1.474e+00, 1.875e-03 ---
#
# --- t, zeta: 1.475e+00, 1.875e-03 ---
#
# --- t, zeta: 1.476e+00, 1.875e-03 ---
#
# --- t, zeta: 1.477e+00, 1.875e-03 ---
#
# --- t, zeta: 1.478e+00, 1.875e-03 ---
#
# --- t, zeta: 1.480e+00, 1.875e-03 ---
#
# --- t, zeta: 1.481e+00, 1.875e-03 ---
#
# --- t, zeta: 1.482e+00, 1.875e-03 ---
#
# --- t, zeta: 1.483e+00, 1.875e-03 ---
#
# --- t, zeta: 1.484e+00, 1.875e-03 ---
#
# --- t, zeta: 1.485e+00, 1.875e-03 ---
#
# --- t, zeta: 1.486e+00, 1.875e-03 ---
#
# --- t, zeta: 1.487e+00, 1.875e-03 ---
#
# --- t, zeta: 1.488e+00, 1.875e-03 ---
#
# --- t, zeta: 1.489e+00, 1.875e-03 ---
#
# --- t, zeta: 1.491e+00, 1.875e-03 ---
#
# --- t, zeta: 1.492e+00, 1.875e-03 ---
#
# --- t, zeta: 1.493e+00, 1.875e-03 ---
#
# --- t, zeta: 1.494e+00, 1.875e-03 ---
#
# --- t, zeta: 1.495e+00, 1.875e-03 ---
#
# --- t, zeta: 1.496e+00, 1.875e-03 ---
#
# --- t, zeta: 1.497e+00, 1.875e-03 ---
#
# --- t, zeta: 1.498e+00, 1.875e-03 ---
#
# --- t, zeta: 1.499e+00, 1.875e-03 ---
#
# --- t, zeta: 1.500e+00, 1.875e-03 ---
#
# --- t, zeta: 1.502e+00, 1.875e-03 ---
#
# --- t, zeta: 1.503e+00, 1.875e-03 ---
#
# --- t, zeta: 1.504e+00, 1.875e-03 ---
#
# --- t, zeta: 1.505e+00, 1.875e-03 ---
#
# --- t, zeta: 1.506e+00, 1.875e-03 ---
#
# --- t, zeta: 1.507e+00, 1.875e-03 ---
#
# --- t, zeta: 1.508e+00, 1.875e-03 ---
#
# --- t, zeta: 1.509e+00, 1.875e-03 ---
#
# --- t, zeta: 1.510e+00, 1.875e-03 ---
#
# --- t, zeta: 1.511e+00, 1.875e-03 ---
#
# --- t, zeta: 1.513e+00, 1.875e-03 ---
#
# --- t, zeta: 1.514e+00, 1.875e-03 ---
#
# --- t, zeta: 1.515e+00, 1.875e-03 ---
#
# --- t, zeta: 1.516e+00, 1.875e-03 ---
#
# --- t, zeta: 1.517e+00, 1.875e-03 ---
#
# --- t, zeta: 1.518e+00, 1.875e-03 ---
#
# --- t, zeta: 1.519e+00, 1.875e-03 ---
#
# --- t, zeta: 1.520e+00, 1.875e-03 ---
#
# --- t, zeta: 1.521e+00, 1.875e-03 ---
#
# --- t, zeta: 1.522e+00, 1.875e-03 ---
#
# --- t, zeta: 1.524e+00, 1.875e-03 ---
#
# --- t, zeta: 1.525e+00, 1.875e-03 ---
#
# --- t, zeta: 1.526e+00, 1.875e-03 ---
#
# --- t, zeta: 1.527e+00, 1.875e-03 ---
#
# --- t, zeta: 1.528e+00, 1.875e-03 ---
#
# --- t, zeta: 1.529e+00, 1.875e-03 ---
#
# --- t, zeta: 1.530e+00, 1.875e-03 ---
#
# --- t, zeta: 1.531e+00, 1.875e-03 ---
#
# --- t, zeta: 1.532e+00, 1.875e-03 ---
#
# --- t, zeta: 1.533e+00, 1.875e-03 ---
#
# --- t, zeta: 1.535e+00, 1.875e-03 ---
#
# --- t, zeta: 1.536e+00, 1.875e-03 ---
#
# --- t, zeta: 1.537e+00, 1.875e-03 ---
#
# --- t, zeta: 1.538e+00, 1.875e-03 ---
#
# --- t, zeta: 1.539e+00, 1.875e-03 ---
#
# --- t, zeta: 1.540e+00, 1.875e-03 ---
#
# --- t, zeta: 1.541e+00, 1.875e-03 ---
#
# --- t, zeta: 1.542e+00, 1.875e-03 ---
#
# --- t, zeta: 1.543e+00, 1.875e-03 ---
#
# --- t, zeta: 1.544e+00, 1.875e-03 ---
#
# --- t, zeta: 1.546e+00, 1.875e-03 ---
#
# --- t, zeta: 1.547e+00, 1.875e-03 ---
#
# --- t, zeta: 1.548e+00, 1.875e-03 ---
#
# --- t, zeta: 1.549e+00, 1.875e-03 ---
#
# --- t, zeta: 1.550e+00, 1.875e-03 ---
#
# --- t, zeta: 1.551e+00, 1.875e-03 ---
#
# --- t, zeta: 1.552e+00, 1.875e-03 ---
#
# --- t, zeta: 1.553e+00, 1.875e-03 ---
#
# --- t, zeta: 1.554e+00, 1.875e-03 ---
#
# --- t, zeta: 1.555e+00, 1.875e-03 ---
#
# --- t, zeta: 1.557e+00, 1.875e-03 ---
#
# --- t, zeta: 1.558e+00, 1.875e-03 ---
#
# --- t, zeta: 1.559e+00, 1.875e-03 ---
#
# --- t, zeta: 1.560e+00, 1.875e-03 ---
#
# --- t, zeta: 1.561e+00, 1.875e-03 ---
#
# --- t, zeta: 1.562e+00, 1.875e-03 ---
#
# --- t, zeta: 1.563e+00, 1.875e-03 ---
#
# --- t, zeta: 1.564e+00, 1.875e-03 ---
#
# --- t, zeta: 1.565e+00, 1.875e-03 ---
#
# --- t, zeta: 1.566e+00, 1.875e-03 ---
#
# --- t, zeta: 1.568e+00, 1.875e-03 ---
#
# --- t, zeta: 1.569e+00, 1.875e-03 ---
#
# --- t, zeta: 1.570e+00, 1.875e-03 ---
#
# --- t, zeta: 1.571e+00, 1.875e-03 ---
#
# --- t, zeta: 1.572e+00, 1.875e-03 ---
#
# --- t, zeta: 1.573e+00, 1.875e-03 ---
#
# --- t, zeta: 1.574e+00, 1.875e-03 ---
#
# --- t, zeta: 1.575e+00, 1.875e-03 ---
#
# --- t, zeta: 1.576e+00, 1.875e-03 ---
#
# --- t, zeta: 1.577e+00, 1.875e-03 ---
#
# --- t, zeta: 1.579e+00, 1.875e-03 ---
#
# --- t, zeta: 1.580e+00, 1.875e-03 ---
#
# --- t, zeta: 1.581e+00, 1.875e-03 ---
#
# --- t, zeta: 1.582e+00, 1.875e-03 ---
#
# --- t, zeta: 1.583e+00, 1.875e-03 ---
#
# --- t, zeta: 1.584e+00, 1.875e-03 ---
#
# --- t, zeta: 1.585e+00, 1.875e-03 ---
#
# --- t, zeta: 1.586e+00, 1.875e-03 ---
#
# --- t, zeta: 1.587e+00, 1.875e-03 ---
#
# --- t, zeta: 1.588e+00, 1.875e-03 ---
#
# --- t, zeta: 1.590e+00, 1.875e-03 ---
#
# --- t, zeta: 1.591e+00, 1.875e-03 ---
#
# --- t, zeta: 1.592e+00, 1.875e-03 ---
#
# --- t, zeta: 1.593e+00, 1.875e-03 ---
#
# --- t, zeta: 1.594e+00, 1.875e-03 ---
#
# --- t, zeta: 1.595e+00, 1.875e-03 ---
#
# --- t, zeta: 1.596e+00, 1.875e-03 ---
#
# --- t, zeta: 1.597e+00, 1.875e-03 ---
#
# --- t, zeta: 1.598e+00, 1.875e-03 ---
#
# --- t, zeta: 1.599e+00, 1.875e-03 ---
#
# --- t, zeta: 1.601e+00, 1.875e-03 ---
#
# --- t, zeta: 1.602e+00, 1.875e-03 ---
#
# --- t, zeta: 1.603e+00, 1.875e-03 ---
#
# --- t, zeta: 1.604e+00, 1.875e-03 ---
#
# --- t, zeta: 1.605e+00, 1.875e-03 ---
#
# --- t, zeta: 1.606e+00, 1.875e-03 ---
#
# --- t, zeta: 1.607e+00, 1.875e-03 ---
#
# --- t, zeta: 1.608e+00, 1.875e-03 ---
#
# --- t, zeta: 1.609e+00, 1.875e-03 ---
#
# --- t, zeta: 1.610e+00, 1.875e-03 ---
#
# --- t, zeta: 1.612e+00, 1.875e-03 ---
#
# --- t, zeta: 1.613e+00, 1.875e-03 ---
#
# --- t, zeta: 1.614e+00, 1.875e-03 ---
#
# --- t, zeta: 1.615e+00, 1.875e-03 ---
#
# --- t, zeta: 1.616e+00, 1.875e-03 ---
#
# --- t, zeta: 1.617e+00, 1.875e-03 ---
#
# --- t, zeta: 1.618e+00, 1.875e-03 ---
#
# --- t, zeta: 1.619e+00, 1.875e-03 ---
#
# --- t, zeta: 1.620e+00, 1.875e-03 ---
#
# --- t, zeta: 1.621e+00, 1.875e-03 ---
#
# --- t, zeta: 1.623e+00, 1.875e-03 ---
#
# --- t, zeta: 1.624e+00, 1.875e-03 ---
#
# --- t, zeta: 1.625e+00, 1.875e-03 ---
#
# --- t, zeta: 1.626e+00, 1.875e-03 ---
#
# --- t, zeta: 1.627e+00, 1.875e-03 ---
#
# --- t, zeta: 1.628e+00, 1.875e-03 ---
#
# --- t, zeta: 1.629e+00, 1.875e-03 ---
#
# --- t, zeta: 1.630e+00, 1.875e-03 ---
#
# --- t, zeta: 1.631e+00, 1.875e-03 ---
#
# --- t, zeta: 1.632e+00, 1.875e-03 ---
#
# --- t, zeta: 1.634e+00, 1.875e-03 ---
#
# --- t, zeta: 1.635e+00, 1.875e-03 ---
#
# --- t, zeta: 1.636e+00, 1.875e-03 ---
#
# --- t, zeta: 1.637e+00, 1.875e-03 ---
#
# --- t, zeta: 1.638e+00, 1.875e-03 ---
#
# --- t, zeta: 1.639e+00, 1.875e-03 ---
#
# --- t, zeta: 1.640e+00, 1.875e-03 ---
#
# --- t, zeta: 1.641e+00, 1.875e-03 ---
#
# --- t, zeta: 1.642e+00, 1.875e-03 ---
#
# --- t, zeta: 1.643e+00, 1.875e-03 ---
#
# --- t, zeta: 1.645e+00, 1.875e-03 ---
#
# --- t, zeta: 1.646e+00, 1.875e-03 ---
#
# --- t, zeta: 1.647e+00, 1.875e-03 ---
#
# --- t, zeta: 1.648e+00, 1.875e-03 ---
#
# --- t, zeta: 1.649e+00, 1.875e-03 ---
#
# --- t, zeta: 1.650e+00, 1.875e-03 ---
#
# --- t, zeta: 1.651e+00, 1.875e-03 ---
#
# --- t, zeta: 1.652e+00, 1.875e-03 ---
#
# --- t, zeta: 1.653e+00, 1.875e-03 ---
#
# --- t, zeta: 1.654e+00, 1.875e-03 ---
#
# --- t, zeta: 1.656e+00, 1.875e-03 ---
#
# --- t, zeta: 1.657e+00, 1.875e-03 ---
#
# --- t, zeta: 1.658e+00, 1.875e-03 ---
#
# --- t, zeta: 1.659e+00, 1.875e-03 ---
#
# --- t, zeta: 1.660e+00, 1.875e-03 ---
#
# --- t, zeta: 1.661e+00, 1.875e-03 ---
#
# --- t, zeta: 1.662e+00, 1.875e-03 ---
#
# --- t, zeta: 1.663e+00, 1.875e-03 ---
#
# --- t, zeta: 1.664e+00, 1.875e-03 ---
#
# --- t, zeta: 1.665e+00, 1.875e-03 ---
#
# --- t, zeta: 1.667e+00, 1.875e-03 ---
#
# --- t, zeta: 1.668e+00, 1.875e-03 ---
#
# --- t, zeta: 1.669e+00, 1.875e-03 ---
#
# --- t, zeta: 1.670e+00, 1.875e-03 ---
#
# --- t, zeta: 1.671e+00, 1.875e-03 ---
#
# --- t, zeta: 1.672e+00, 1.875e-03 ---
#
# --- t, zeta: 1.673e+00, 1.875e-03 ---
#
# --- t, zeta: 1.674e+00, 1.875e-03 ---
#
# --- t, zeta: 1.675e+00, 1.875e-03 ---
#
# --- t, zeta: 1.676e+00, 1.875e-03 ---
#
# --- t, zeta: 1.678e+00, 1.875e-03 ---
#
# --- t, zeta: 1.679e+00, 1.875e-03 ---
#
# --- t, zeta: 1.680e+00, 1.875e-03 ---
#
# --- t, zeta: 1.681e+00, 1.875e-03 ---
#
# --- t, zeta: 1.682e+00, 1.875e-03 ---
#
# --- t, zeta: 1.683e+00, 1.875e-03 ---
#
# --- t, zeta: 1.684e+00, 1.875e-03 ---
#
# --- t, zeta: 1.685e+00, 1.875e-03 ---
#
# --- t, zeta: 1.686e+00, 1.875e-03 ---
#
# --- t, zeta: 1.687e+00, 1.875e-03 ---
#
# --- t, zeta: 1.689e+00, 1.875e-03 ---
#
# --- t, zeta: 1.690e+00, 1.875e-03 ---
#
# --- t, zeta: 1.691e+00, 1.875e-03 ---
#
# --- t, zeta: 1.692e+00, 1.875e-03 ---
#
# --- t, zeta: 1.693e+00, 1.875e-03 ---
#
# --- t, zeta: 1.694e+00, 1.875e-03 ---
#
# --- t, zeta: 1.695e+00, 1.875e-03 ---
#
# --- t, zeta: 1.696e+00, 1.875e-03 ---
#
# --- t, zeta: 1.697e+00, 1.875e-03 ---
#
# --- t, zeta: 1.698e+00, 1.875e-03 ---
#
# --- t, zeta: 1.700e+00, 1.875e-03 ---
#
# --- t, zeta: 1.701e+00, 1.875e-03 ---
#
# --- t, zeta: 1.702e+00, 1.875e-03 ---
#
# --- t, zeta: 1.703e+00, 1.875e-03 ---
#
# --- t, zeta: 1.704e+00, 1.875e-03 ---
#
# --- t, zeta: 1.705e+00, 1.875e-03 ---
#
# --- t, zeta: 1.706e+00, 1.875e-03 ---
#
# --- t, zeta: 1.707e+00, 1.875e-03 ---
#
# --- t, zeta: 1.708e+00, 1.875e-03 ---
#
# --- t, zeta: 1.709e+00, 1.875e-03 ---
#
# --- t, zeta: 1.711e+00, 1.875e-03 ---
#
# --- t, zeta: 1.712e+00, 1.875e-03 ---
#
# --- t, zeta: 1.713e+00, 1.875e-03 ---
#
# --- t, zeta: 1.714e+00, 1.875e-03 ---
#
# --- t, zeta: 1.715e+00, 1.875e-03 ---
#
# --- t, zeta: 1.716e+00, 1.875e-03 ---
#
# --- t, zeta: 1.717e+00, 1.875e-03 ---
#
# --- t, zeta: 1.718e+00, 1.875e-03 ---
#
# --- t, zeta: 1.719e+00, 1.875e-03 ---
#
# --- t, zeta: 1.720e+00, 1.875e-03 ---
#
# --- t, zeta: 1.722e+00, 1.875e-03 ---
#
# --- t, zeta: 1.723e+00, 1.875e-03 ---
#
# --- t, zeta: 1.724e+00, 1.875e-03 ---
#
# --- t, zeta: 1.725e+00, 1.875e-03 ---
#
# --- t, zeta: 1.726e+00, 1.875e-03 ---
#
# --- t, zeta: 1.727e+00, 1.875e-03 ---
#
# --- t, zeta: 1.728e+00, 1.875e-03 ---
#
# --- t, zeta: 1.729e+00, 1.875e-03 ---
#
# --- t, zeta: 1.730e+00, 1.875e-03 ---
#
# --- t, zeta: 1.731e+00, 1.875e-03 ---
#
# --- t, zeta: 1.733e+00, 1.875e-03 ---
#
# --- t, zeta: 1.734e+00, 1.875e-03 ---
#
# --- t, zeta: 1.735e+00, 1.875e-03 ---
#
# --- t, zeta: 1.736e+00, 1.875e-03 ---
#
# --- t, zeta: 1.737e+00, 1.875e-03 ---
#
# --- t, zeta: 1.738e+00, 1.875e-03 ---
#
# --- t, zeta: 1.739e+00, 1.875e-03 ---
#
# --- t, zeta: 1.740e+00, 1.875e-03 ---
#
# ...
#
# --- t, zeta: 1.951e+01, 1.875e-03 ---
#
# --- t, zeta: 1.951e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.952e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.953e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.954e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.955e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.956e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.957e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.958e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.959e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.960e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.961e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.962e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.963e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.964e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.965e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.966e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.967e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.968e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.969e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.970e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.971e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.972e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.973e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.974e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.975e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.976e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.977e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.978e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.979e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.980e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.981e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.982e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.983e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.984e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.985e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.986e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.987e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.988e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.989e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.990e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.991e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.992e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.993e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.994e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.995e+01, 1.875e-03 ---
#
# --- t, zeta: 1.996e+01, 1.875e-03 ---
#
# --- t, zeta: 1.996e+01, 1.875e-03 ---
#
# --- t, zeta: 1.996e+01, 1.875e-03 ---
# Take a larger chart: new zeta = 3.750e-03
# Take a larger chart: new zeta = 7.500e-03
# Take a larger chart: new zeta = 1.500e-02
#
# --- t, zeta: 2.000e+01, 1.500e-02 ---
# Done

# %%
# step_t_ = 1
step_t_ = 4 # for err_tol = 1e-14

# %%
# --------------------------------------------------------------------
# --- Compare trajectories ---
# --------------------------------------------------------------------
mix.reload_module(ca)
ca.compare_trajectory_cl_and_carleman(
    t_ref_, sol_ref_, t_emb_, sol_emb_,
    flag_save=True, 
    path_save=path_save_, 
    case_title = case_sim_, case_emb = case_emb_,
    fontsize = 20, fig_size = (10,9),
    radii_emb = radii_emb_,
    flag_var_semilogy = False,
    step_t = step_t_,
    flag_max_error = flag_max_error_
)
# Out:
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_LV2D_max1.00_tol1.000e-14_PAE_max_err.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_LV2D_max1.00_tol1.000e-14_PAE_radius.dat
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
xx = np.array([-2, -0.2, -0.3, 4, 6])
xx = np.array([-0.2, -0.2, -0.3, 0.4, 0.6])

len(xx[np.abs(xx) > 1.])
# Out:
# 0

# %%
np.full(4, 0.2)
# Out:
# array([0.2, 0.2, 0.2, 0.2])
