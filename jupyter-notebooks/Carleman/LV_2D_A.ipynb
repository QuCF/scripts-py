# %%
# %matplotlib widget
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import scipy
import h5py

import os
import sys
sys.path.append(os.path.abspath("./"))

print(os.getpid())
# %cd ../../

import pylib.mix as mix
import carleman as ca
from matplotlib import colors
plt.rcParams.update({
    "text.usetex": True,
    'text.latex.preamble': r"\usepackage{amsmath} \boldmath"
})
# Out:
# 24292
# c:\Users\ivan9\Documents\work\codes\QuCF\scripts-py

# %%
path_save_ = "./jupyter-notebooks/Carleman/results/"
for i in range(100):
    plt.close()

colors_     = ["blue", "red", "green", "gray", "black"]
linestyles_ = ["-", "--", "--", ":"]

# %%
# ---------------------------------------------------------------
# --- Prepare the system: Lotka - Volterra 2D ---
# ---------------------------------------------------------------
mix.reload_module(ca)
mix.reload_module(mix)
def choose_case(N_nl, sel_case):
    Nx = 2  # the number of degrees of freedom
    F_terms, sys_coefs, return_sys, shift_coefs = None, None, None, None
    if sel_case == 0:
        x_init = np.array([0.5, 0.5])

        tmax, nt = 20, 8
        # tmax, nt = 3, 5  # for standard embedding

        aa, gg = 1.0, 0.475
        eta_x, eta_y = 1., 1. 
        xi_x, xi_y = 0., 0.

        sys_coefs = {}
        sys_coefs["aa"]    = aa
        sys_coefs["gg"]    = gg
        sys_coefs["eta_x"] = eta_x
        sys_coefs["eta_y"] = eta_y
        sys_coefs["xi_x"]  = xi_x
        sys_coefs["xi_y"]  = xi_y

        def return_sys(ss):
            aa    = ss["aa"]       
            gg    = ss["gg"]    
            eta_x = ss["eta_x"] 
            eta_y = ss["eta_y"] 
            xi_x  = ss["xi_x"]  
            xi_y  = ss["xi_y"]  

            F_terms = [None] * (N_nl + 1)
            for ii_nl in range(N_nl + 1):
                F_terms[ii_nl] = np.zeros((Nx,int(Nx**ii_nl)))
            
            F_terms[0][0,0] =   aa * xi_x - eta_y * aa * xi_x * xi_y
            F_terms[0][1,0] = - gg * xi_y + eta_x * gg * xi_x * xi_y

            F_terms[1][0, 0] = aa - eta_y * aa * xi_y
            F_terms[1][0, 1] =    - eta_y * aa * xi_x

            F_terms[1][1, 0] =        eta_x * gg * xi_y
            F_terms[1][1, 1] = - gg + eta_x * gg * xi_x 

            F_terms[2][0, 1] = - eta_y * aa
            F_terms[2][1, 1] =   eta_x * gg
            return F_terms
        
        def shift_coefs(ss, zeta):
            ss_new = dict(ss)
            ss_new["xi_x"] = ss_new["xi_x"] + zeta[0]
            ss_new["xi_y"] = ss_new["xi_y"] + zeta[1]
            if "xi_z" in ss_new:
                ss_new["xi_z"] = ss_new["xi_z"] + zeta[2]
            return ss_new
        
        print("\nSystem coefficients:")
        for key, value in sys_coefs.items():
            print("{:s} = {:0.3f}".format(key, value))
        print()

        F_terms = return_sys(sys_coefs)
        F = [
            lambda x: F_terms[0][0,0] + F_terms[1][0, 0] * x[0] + F_terms[1][0, 1] * x[1] + F_terms[2][0, 1] * x[0] * x[1],
            lambda x: F_terms[0][1,0] + F_terms[1][1, 0] * x[0] + F_terms[1][1, 1] * x[1] + F_terms[2][1, 1] * x[0] * x[1],
        ]

    # ----------------------------------------------------
    return F, tmax, nt, Nx, x_init, sys_coefs, return_sys, shift_coefs
# ------------------------------------------------------------------------------
sel_case_ = 0

N_nl_orig_ = 2 
F_, tmax_, nt_, Nx_, x_init_ref_, sys_coefs_, return_sys_, shift_coefs_ = choose_case(N_nl_orig_, sel_case = sel_case_)
Nt_ = 1 << nt_
t_ = np.linspace(0, tmax_, Nt_)
dt_ = np.diff(t_)[0]

print("Nt: {:d}".format(Nt_))
print("init. cond.: ", end = "")
mix.print_array(x_init_ref_, ff = [6, 2, "f"])

# --- Standard method (for reference) ---
sol_ref_, t_ref_ = ca.analyse_classical(x_init_ref_, t_, F_)

print(len(t_ref_))
# Out:
# System coefficients:
# aa = 1.000
# gg = 0.475
# eta_x = 1.000
# eta_y = 1.000
# xi_x = 0.000
# xi_y = 0.000
#
# Nt: 256
# init. cond.:   0.50   0.50
#
# WARNING: increase arrays: counter_t = 256
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 257

# %%
# --------------------------------------------------------------------
# --- Carleman linearization ---
# --------------------------------------------------------------------
mix.reload_module(ca)
N_nl = 6   
flag_max_error_ = False
case_sim_, step_t_ = "LV2D", 1

# # --- Standard embedding ---
# sol_emb_, t_emb_, case_emb_ = ca.solve_carleman_orig(x_init_ref_, N_nl, N_nl_orig_, t_, return_sys_(sys_coefs_))
# radii_emb_ = None

# # --- Piecewise embedding ---
# zeta_th = 0.1
# sol_emb_, t_emb_, case_emb_ = ca.solve_carleman_global(
#     x_init_ref_, N_nl, N_nl_orig_, t_, 
#     sys_coefs_, return_sys_, shift_coefs_,
#     zeta_th = 0.1
# )
# radii_emb_ = None
# del zeta_th


# --- Piecewise adaptive embedding ---
flag_max_error_ = True

err_tol, zeta_max = 1.e-10, 1.0

sol_emb_, t_emb_, case_emb_, radii_emb_ = ca.solve_carleman_global_adaptive(
    x_init_ref_, N_nl, N_nl_orig_, t_, 
    sys_coefs_, return_sys_, shift_coefs_,
    zeta_init_ = zeta_max, 
    err_tolerance_ = err_tol,
    zeta_min_    = 1e-3,
    zeta_step_   = 0.02,
    zeta_thresh_ = 0.12,
    zeta_max_ = zeta_max
)
case_sim_ = "LV2D_max{:0.2f}_tol{:0.3e}".format(zeta_max, err_tol)
step_t_ = 1
del err_tol, zeta_max
# Out:
# --- t, zeta: 1.893e+00, 1.000e+00 ---
# Take a smaller chart: new zeta = 9.800e-01
# Take a smaller chart: new zeta = 9.600e-01
# Take a smaller chart: new zeta = 9.400e-01
# Take a smaller chart: new zeta = 9.200e-01
# Take a smaller chart: new zeta = 9.000e-01
# Take a smaller chart: new zeta = 8.800e-01
# Take a smaller chart: new zeta = 8.600e-01
# Take a smaller chart: new zeta = 8.400e-01
# Take a smaller chart: new zeta = 8.200e-01
# Take a smaller chart: new zeta = 8.000e-01
# Take a smaller chart: new zeta = 7.800e-01
# Take a smaller chart: new zeta = 7.600e-01
# Take a smaller chart: new zeta = 7.400e-01
# Take a smaller chart: new zeta = 7.200e-01
# Take a smaller chart: new zeta = 7.000e-01
# Take a smaller chart: new zeta = 6.800e-01
# Take a smaller chart: new zeta = 6.600e-01
# Take a smaller chart: new zeta = 6.400e-01
# Take a smaller chart: new zeta = 6.200e-01
# Take a smaller chart: new zeta = 6.000e-01
# Take a smaller chart: new zeta = 5.800e-01
# Take a smaller chart: new zeta = 5.600e-01
#
# --- t, zeta: 2.532e+00, 5.600e-01 ---
# Take a smaller chart: new zeta = 5.400e-01
# Take a smaller chart: new zeta = 5.200e-01
# Take a smaller chart: new zeta = 5.000e-01
# Take a smaller chart: new zeta = 4.800e-01
# Take a smaller chart: new zeta = 4.600e-01
# Take a smaller chart: new zeta = 4.400e-01
# Take a smaller chart: new zeta = 4.200e-01
# Take a smaller chart: new zeta = 4.000e-01
# Take a smaller chart: new zeta = 3.800e-01
# Take a smaller chart: new zeta = 3.600e-01
# Take a smaller chart: new zeta = 3.400e-01
# Take a smaller chart: new zeta = 3.200e-01
# Take a smaller chart: new zeta = 3.000e-01
# Take a smaller chart: new zeta = 2.800e-01
# Take a smaller chart: new zeta = 2.600e-01
# Take a smaller chart: new zeta = 2.400e-01
# Take a smaller chart: new zeta = 2.200e-01
# Take a smaller chart: new zeta = 2.000e-01
# Take a smaller chart: new zeta = 1.800e-01
# Take a smaller chart: new zeta = 1.600e-01
# Take a smaller chart: new zeta = 1.400e-01
# Take a smaller chart: new zeta = 1.200e-01
#
# --- t, zeta: 2.622e+00, 1.200e-01 ---
#
# --- t, zeta: 2.711e+00, 1.200e-01 ---
#
# --- t, zeta: 2.801e+00, 1.200e-01 ---
#
# --- t, zeta: 2.890e+00, 1.200e-01 ---
#
# --- t, zeta: 2.980e+00, 1.200e-01 ---
#
# --- t, zeta: 3.069e+00, 1.200e-01 ---
#
# --- t, zeta: 3.159e+00, 1.200e-01 ---
#
# --- t, zeta: 3.327e+00, 1.200e-01 ---
#
# --- t, zeta: 3.495e+00, 1.200e-01 ---
#
# --- t, zeta: 3.584e+00, 1.200e-01 ---
#
# --- t, zeta: 3.674e+00, 1.200e-01 ---
#
# --- t, zeta: 3.763e+00, 1.200e-01 ---
#
# --- t, zeta: 3.853e+00, 1.200e-01 ---
#
# --- t, zeta: 3.942e+00, 1.200e-01 ---
#
# --- t, zeta: 4.032e+00, 1.200e-01 ---
# Take a larger chart: new zeta = 2.400e-01
#
# --- t, zeta: 4.200e+00, 2.400e-01 ---
# Take a smaller chart: new zeta = 2.200e-01
# Take a smaller chart: new zeta = 2.000e-01
# Take a smaller chart: new zeta = 1.800e-01
# Take a smaller chart: new zeta = 1.600e-01
# Take a smaller chart: new zeta = 1.400e-01
#
# --- t, zeta: 4.289e+00, 1.400e-01 ---
#
# --- t, zeta: 4.379e+00, 1.400e-01 ---
#
# --- t, zeta: 4.468e+00, 1.400e-01 ---
#
# --- t, zeta: 4.558e+00, 1.400e-01 ---
#
# --- t, zeta: 4.647e+00, 1.400e-01 ---
# Take a smaller chart: new zeta = 1.200e-01
#
# --- t, zeta: 4.737e+00, 1.200e-01 ---
#
# --- t, zeta: 4.827e+00, 1.200e-01 ---
#
# --- t, zeta: 4.916e+00, 1.200e-01 ---
#
# --- t, zeta: 5.006e+00, 1.200e-01 ---
#
# --- t, zeta: 5.095e+00, 1.200e-01 ---
#
# --- t, zeta: 5.185e+00, 1.200e-01 ---
#
# --- t, zeta: 5.274e+00, 1.200e-01 ---
#
# --- t, zeta: 5.364e+00, 1.200e-01 ---
#
# --- t, zeta: 5.532e+00, 1.200e-01 ---
# Take a smaller chart: new zeta = 6.000e-02
#
# --- t, zeta: 5.621e+00, 6.000e-02 ---
#
# --- t, zeta: 5.711e+00, 6.000e-02 ---
#
# --- t, zeta: 5.800e+00, 6.000e-02 ---
#
# --- t, zeta: 5.890e+00, 6.000e-02 ---
# Take a larger chart: new zeta = 1.200e-01
# Take a larger chart: new zeta = 2.400e-01
# Take a larger chart: new zeta = 2.600e-01
# Take a larger chart: new zeta = 2.800e-01
# Take a larger chart: new zeta = 3.000e-01
# Take a larger chart: new zeta = 3.200e-01
# Take a larger chart: new zeta = 3.400e-01
# Take a larger chart: new zeta = 3.600e-01
# Take a larger chart: new zeta = 3.800e-01
# Take a larger chart: new zeta = 4.000e-01
# Take a larger chart: new zeta = 4.200e-01
# Take a larger chart: new zeta = 4.400e-01
# Take a larger chart: new zeta = 4.600e-01
# Take a larger chart: new zeta = 4.800e-01
# Take a larger chart: new zeta = 5.000e-01
# Take a larger chart: new zeta = 5.200e-01
# Take a larger chart: new zeta = 5.400e-01
# Take a larger chart: new zeta = 5.600e-01
# Take a larger chart: new zeta = 5.800e-01
# Take a larger chart: new zeta = 6.000e-01
# Take a larger chart: new zeta = 6.200e-01
# Take a larger chart: new zeta = 6.400e-01
# Take a larger chart: new zeta = 6.600e-01
# Take a larger chart: new zeta = 6.800e-01
# Take a larger chart: new zeta = 7.000e-01
# Take a larger chart: new zeta = 7.200e-01
# Take a larger chart: new zeta = 7.400e-01
# Take a larger chart: new zeta = 7.600e-01
# Take a larger chart: new zeta = 7.800e-01
# Take a larger chart: new zeta = 8.000e-01
# Take a larger chart: new zeta = 8.200e-01
# Take a larger chart: new zeta = 8.400e-01
# Take a larger chart: new zeta = 8.600e-01
#
# --- t, zeta: 7.940e+00, 8.600e-01 ---
# Take a smaller chart: new zeta = 8.400e-01
# Take a smaller chart: new zeta = 8.200e-01
# Take a smaller chart: new zeta = 8.000e-01
# Take a smaller chart: new zeta = 7.800e-01
# Take a smaller chart: new zeta = 7.600e-01
# Take a smaller chart: new zeta = 7.400e-01
# Take a smaller chart: new zeta = 7.200e-01
# Take a smaller chart: new zeta = 7.000e-01
# Take a smaller chart: new zeta = 6.800e-01
# Take a smaller chart: new zeta = 6.600e-01
# Take a smaller chart: new zeta = 6.400e-01
# Take a smaller chart: new zeta = 6.200e-01
# Take a smaller chart: new zeta = 6.000e-01
# Take a smaller chart: new zeta = 5.800e-01
#
# --- t, zeta: 1.023e+01, 5.800e-01 ---
# Take a larger chart: new zeta = 6.000e-01
# Take a larger chart: new zeta = 6.200e-01
# Take a larger chart: new zeta = 6.400e-01
# Take a larger chart: new zeta = 6.600e-01
# Take a larger chart: new zeta = 6.800e-01
# Take a larger chart: new zeta = 7.000e-01
# Take a larger chart: new zeta = 7.200e-01
# Take a larger chart: new zeta = 7.400e-01
# Take a larger chart: new zeta = 7.600e-01
# Take a larger chart: new zeta = 7.800e-01
# Take a larger chart: new zeta = 8.000e-01
# Take a larger chart: new zeta = 8.200e-01
# Take a larger chart: new zeta = 8.400e-01
# Take a larger chart: new zeta = 8.600e-01
# Take a larger chart: new zeta = 8.800e-01
# Take a larger chart: new zeta = 9.000e-01
# Take a larger chart: new zeta = 9.200e-01
# Take a larger chart: new zeta = 9.400e-01
# Take a larger chart: new zeta = 9.600e-01
# >>> The non-shifted chart is unstable
#
# --- t, zeta: 1.188e+01, 9.600e-01 ---
# Take a smaller chart: new zeta = 9.400e-01
# Take a smaller chart: new zeta = 9.200e-01
# Take a smaller chart: new zeta = 9.000e-01
# Take a smaller chart: new zeta = 8.800e-01
# Take a smaller chart: new zeta = 8.600e-01
# Take a smaller chart: new zeta = 8.400e-01
# Take a smaller chart: new zeta = 8.200e-01
# Take a smaller chart: new zeta = 8.000e-01
# Take a smaller chart: new zeta = 7.800e-01
# Take a smaller chart: new zeta = 7.600e-01
# Take a smaller chart: new zeta = 7.400e-01
# Take a smaller chart: new zeta = 7.200e-01
# Take a smaller chart: new zeta = 7.000e-01
# Take a smaller chart: new zeta = 6.800e-01
# Take a smaller chart: new zeta = 6.600e-01
# Take a smaller chart: new zeta = 6.400e-01
# Take a smaller chart: new zeta = 6.200e-01
# Take a smaller chart: new zeta = 6.000e-01
# Take a smaller chart: new zeta = 5.800e-01
# Take a smaller chart: new zeta = 5.600e-01
# Take a smaller chart: new zeta = 5.400e-01
# Take a smaller chart: new zeta = 5.200e-01
# Take a smaller chart: new zeta = 5.000e-01
# Take a smaller chart: new zeta = 4.800e-01
# Take a smaller chart: new zeta = 4.600e-01
# Take a smaller chart: new zeta = 4.400e-01
# Take a smaller chart: new zeta = 4.200e-01
# Take a smaller chart: new zeta = 4.000e-01
# Take a smaller chart: new zeta = 3.800e-01
#
# --- t, zeta: 1.229e+01, 3.800e-01 ---
# Take a smaller chart: new zeta = 3.600e-01
# Take a smaller chart: new zeta = 3.400e-01
# Take a smaller chart: new zeta = 3.200e-01
# Take a smaller chart: new zeta = 3.000e-01
# Take a smaller chart: new zeta = 2.800e-01
# Take a smaller chart: new zeta = 2.600e-01
# Take a smaller chart: new zeta = 2.400e-01
# Take a smaller chart: new zeta = 2.200e-01
# Take a smaller chart: new zeta = 2.000e-01
# Take a smaller chart: new zeta = 1.800e-01
# Take a smaller chart: new zeta = 1.600e-01
# Take a smaller chart: new zeta = 1.400e-01
# Take a smaller chart: new zeta = 1.200e-01
#
# --- t, zeta: 1.238e+01, 1.200e-01 ---
#
# --- t, zeta: 1.247e+01, 1.200e-01 ---
#
# --- t, zeta: 1.256e+01, 1.200e-01 ---
#
# --- t, zeta: 1.265e+01, 1.200e-01 ---
#
# --- t, zeta: 1.273e+01, 1.200e-01 ---
#
# --- t, zeta: 1.282e+01, 1.200e-01 ---
#
# --- t, zeta: 1.291e+01, 1.200e-01 ---
#
# --- t, zeta: 1.300e+01, 1.200e-01 ---
#
# --- t, zeta: 1.317e+01, 1.200e-01 ---
#
# --- t, zeta: 1.326e+01, 1.200e-01 ---
#
# --- t, zeta: 1.335e+01, 1.200e-01 ---
#
# --- t, zeta: 1.344e+01, 1.200e-01 ---
#
# --- t, zeta: 1.353e+01, 1.200e-01 ---
#
# --- t, zeta: 1.362e+01, 1.200e-01 ---
#
# --- t, zeta: 1.371e+01, 1.200e-01 ---
#
# --- t, zeta: 1.380e+01, 1.200e-01 ---
# Take a larger chart: new zeta = 2.400e-01
#
# --- t, zeta: 1.397e+01, 2.400e-01 ---
# Take a smaller chart: new zeta = 2.200e-01
# Take a smaller chart: new zeta = 2.000e-01
# Take a smaller chart: new zeta = 1.800e-01
# Take a smaller chart: new zeta = 1.600e-01
# Take a smaller chart: new zeta = 1.400e-01
#
# --- t, zeta: 1.406e+01, 1.400e-01 ---
#
# --- t, zeta: 1.415e+01, 1.400e-01 ---
#
# --- t, zeta: 1.423e+01, 1.400e-01 ---
#
# --- t, zeta: 1.432e+01, 1.400e-01 ---
#
# --- t, zeta: 1.441e+01, 1.400e-01 ---
# Take a smaller chart: new zeta = 1.200e-01
#
# --- t, zeta: 1.450e+01, 1.200e-01 ---
#
# --- t, zeta: 1.459e+01, 1.200e-01 ---
#
# --- t, zeta: 1.468e+01, 1.200e-01 ---
#
# --- t, zeta: 1.477e+01, 1.200e-01 ---
#
# --- t, zeta: 1.486e+01, 1.200e-01 ---
#
# --- t, zeta: 1.495e+01, 1.200e-01 ---
#
# --- t, zeta: 1.504e+01, 1.200e-01 ---
#
# --- t, zeta: 1.513e+01, 1.200e-01 ---
#
# --- t, zeta: 1.530e+01, 1.200e-01 ---
# Take a smaller chart: new zeta = 6.000e-02
#
# --- t, zeta: 1.539e+01, 6.000e-02 ---
#
# --- t, zeta: 1.548e+01, 6.000e-02 ---
#
# --- t, zeta: 1.557e+01, 6.000e-02 ---
#
# --- t, zeta: 1.566e+01, 6.000e-02 ---
# Take a larger chart: new zeta = 1.200e-01
# Take a larger chart: new zeta = 2.400e-01
# Take a larger chart: new zeta = 2.600e-01
# Take a larger chart: new zeta = 2.800e-01
# Take a larger chart: new zeta = 3.000e-01
# Take a larger chart: new zeta = 3.200e-01
# Take a larger chart: new zeta = 3.400e-01
# Take a larger chart: new zeta = 3.600e-01
# Take a larger chart: new zeta = 3.800e-01
# Take a larger chart: new zeta = 4.000e-01
# Take a larger chart: new zeta = 4.200e-01
# Take a larger chart: new zeta = 4.400e-01
# Take a larger chart: new zeta = 4.600e-01
# Take a larger chart: new zeta = 4.800e-01
# Take a larger chart: new zeta = 5.000e-01
# Take a larger chart: new zeta = 5.200e-01
# Take a larger chart: new zeta = 5.400e-01
# Take a larger chart: new zeta = 5.600e-01
# Take a larger chart: new zeta = 5.800e-01
# Take a larger chart: new zeta = 6.000e-01
# Take a larger chart: new zeta = 6.200e-01
# Take a larger chart: new zeta = 6.400e-01
# Take a larger chart: new zeta = 6.600e-01
# Take a larger chart: new zeta = 6.800e-01
# Take a larger chart: new zeta = 7.000e-01
# Take a larger chart: new zeta = 7.200e-01
# Take a larger chart: new zeta = 7.400e-01
# Take a larger chart: new zeta = 7.600e-01
# Take a larger chart: new zeta = 7.800e-01
# Take a larger chart: new zeta = 8.000e-01
# Take a larger chart: new zeta = 8.200e-01
# Take a larger chart: new zeta = 8.400e-01
# Take a larger chart: new zeta = 8.600e-01
#
# --- t, zeta: 1.771e+01, 8.600e-01 ---
#
# --- t, zeta: 2.000e+01, 8.600e-01 ---
# Done

# %%
step_t_ = 1

# %%
# --------------------------------------------------------------------
# --- Compare trajectories ---
# --------------------------------------------------------------------
mix.reload_module(ca)
ca.compare_trajectory_cl_and_carleman(
    t_ref_, sol_ref_, t_emb_, sol_emb_,
    flag_save=True, path_save=path_save_, 
    case_title = case_sim_, case_emb = case_emb_,
    fontsize = 20, fig_size = (10,9),
    radii_emb = radii_emb_,
    flag_var_semilogy = False,
    step_t = step_t_,
    flag_max_error = flag_max_error_
)
# Out:
# write data to a file: ./jupyter-notebooks/Carleman/results//REF_LV2D_max1.00_tol1.000e-10_xy.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_LV2D_max1.00_tol1.000e-10_PAE_xy.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//REF_LV2D_max1.00_tol1.000e-10_x.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_LV2D_max1.00_tol1.000e-10_PAE_x.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//REF_LV2D_max1.00_tol1.000e-10_y.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_LV2D_max1.00_tol1.000e-10_PAE_y.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_LV2D_max1.00_tol1.000e-10_PAE_max_err.dat
# write data to a file: ./jupyter-notebooks/Carleman/results//EMB_LV2D_max1.00_tol1.000e-10_PAE_radius.dat
# c:\Users\ivan9\Documents\work\codes\QuCF\scripts-py\jupyter-notebooks\Carleman\carleman.py:1121: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
xx = np.array([-2, -0.2, -0.3, 4, 6])
xx = np.array([-0.2, -0.2, -0.3, 0.4, 0.6])

len(xx[np.abs(xx) > 1.])
# Out:
# 0

# %%
np.full(4, 0.2)
# Out:
# array([0.2, 0.2, 0.2, 0.2])
